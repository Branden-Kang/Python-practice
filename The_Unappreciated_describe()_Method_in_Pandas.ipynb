# %% [markdown]
# [Reference](https://python.plainenglish.io/describe-method-in-pandas-5fa44998a752)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0,100,size=(15, 2)), columns=list('AB'))

df.head(15)
# Out:
#      A   B
# 0   58  69
# 1   19  23
# 2   76  88
# 3   77  68
# 4   96  24
# 5   89  45
# 6   16  36
# 7   91  93
# 8   74   8
# 9   44  24
# 10   0  13
# 11  60   3
# 12  98  57
# 13  41  72
# 14  81  45

# %%
df.describe()
# Out:
#                A          B
# count  15.000000  15.000000
# mean   61.333333  44.533333
# std    31.093561  28.947901
# min     0.000000   3.000000
# 25%    42.500000  23.500000
# 50%    74.000000  45.000000
# 75%    85.000000  68.500000
# max    98.000000  93.000000

# %%
sorted = df['B'].sort_values()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['A'], vert = False)
plt.title('Distribution of Values');
