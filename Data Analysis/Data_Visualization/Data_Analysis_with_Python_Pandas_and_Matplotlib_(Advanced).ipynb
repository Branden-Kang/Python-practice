# %% [markdown]
# [Reference](https://medium.com/@khouloud.haddad/data-analysis-with-python-pandas-and-matplotlib-advanced-a9615a3dff6f)

# %%
import pandas as pd

# Creating a Series
data = [10, 20, 30, 40]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {'Name': ['John', 'Jane', 'Mike'], 'Age': [23, 25, 30]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age
# 0  John   23
# 1  Jane   25
# 2  Mike   30

# %%
# Fill missing values with 0
df = df.fillna(0)

# %%
df = df.dropna()

# %%
ages = df['Age']
print(ages)
# Out:
# 0    23
# 1    25
# 2    30
# Name: Age, dtype: int64

# %%
adults = df[df['Age'] > 25]
print(adults)
# Out:
#    Name  Age
# 2  Mike   30

# %%
sorted_df = df.sort_values(by='Age')
print(sorted_df)
# Out:
#    Name  Age
# 0  John   23
# 1  Jane   25
# 2  Mike   30

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Age'])
plt.title('Age Distribution')
plt.xlabel('Index')
plt.ylabel('Age')
plt.show()

# %%
df['Age'].value_counts().plot(kind='bar')
plt.title('Age Frequency')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['Age'].plot(kind='hist', bins=5)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create Employee Dataset
data = {
    'Employee_ID': range(1001, 1011),
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace', 'Helen', 'Isaac', 'Julia'],
    'Age': [25, 28, 35, 40, 22, 30, 45, 50, 29, 38],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'Marketing', 'HR', 'Finance'],
    'Salary': [50000, 70000, 85000, 92000, 48000, 78000, 110000, 65000, 52000, 88000],
    'Experience_Years': [2, 4, 10, 15, 1, 8, 20, 12, 3, 11],
    'Performance_Score': [3.2, 4.5, 4.8, 3.7, 2.9, 4.2, 4.9, 3.8, 3.5, 4.1]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display first few rows
print(df.head())
# Out:
#    Employee_ID     Name  Age Department  Salary  Experience_Years  \
# 0         1001    Alice   25         HR   50000                 2
# 1         1002      Bob   28         IT   70000                 4
# 2         1003  Charlie   35         IT   85000                10
# 3         1004    David   40    Finance   92000                15
# 4         1005     Emma   22         HR   48000                 1
#
#    Performance_Score
# 0                3.2
# 1                4.5
# 2                4.8
# 3                3.7
# 4                2.9

# %%
# Check for missing values
print(df.isnull().sum())

# Check data types
print(df.dtypes)

# Convert categorical columns to category type
df['Department'] = df['Department'].astype('category')

# Add an Experience Level column
df['Experience_Level'] = pd.cut(df['Experience_Years'], bins=[0, 5, 10, 20], labels=['Junior', 'Mid', 'Senior'])

# Show the updated DataFrame
print(df.head())
# Out:
# Employee_ID          0
# Name                 0
# Age                  0
# Department           0
# Salary               0
# Experience_Years     0
# Performance_Score    0
# dtype: int64
# Employee_ID            int64
# Name                  object
# Age                    int64
# Department            object
# Salary                 int64
# Experience_Years       int64
# Performance_Score    float64
# dtype: object
#    Employee_ID     Name  Age Department  Salary  Experience_Years  \
# 0         1001    Alice   25         HR   50000                 2
# 1         1002      Bob   28         IT   70000                 4
# 2         1003  Charlie   35         IT   85000                10
# 3         1004    David   40    Finance   92000                15
# 4         1005     Emma   22         HR   48000                 1
#
#    Performance_Score Experience_Level
# 0                3.2           Junior
# 1                4.5           Junior
# 2                4.8              Mid
# 3                3.7           Senior
# 4                2.9           Junior

# %%
high_salary_df = df[df['Salary'] > 80000]
print(high_salary_df)
# Out:
#    Employee_ID     Name  Age Department  Salary  Experience_Years  \
# 2         1003  Charlie   35         IT   85000                10
# 3         1004    David   40    Finance   92000                15
# 6         1007    Grace   45         IT  110000                20
# 9         1010    Julia   38    Finance   88000                11
#
#    Performance_Score Experience_Level
# 2                4.8              Mid
# 3                3.7           Senior
# 6                4.9           Senior
# 9                4.1           Senior

# %%
avg_salary_by_dept = df.groupby('Department')['Salary'].mean()
print(avg_salary_by_dept)
# Out:
# Department
# Finance      86000.000000
# HR           50000.000000
# IT           88333.333333
# Marketing    65000.000000
# Name: Salary, dtype: float64
# <ipython-input-15-6eb2efb527e0>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_salary_by_dept = df.groupby('Department')['Salary'].mean()

# %%
best_department = df.groupby('Department')['Performance_Score'].mean().idxmax()
print(f'Highest Performing Department: {best_department}')
# Out:
# Highest Performing Department: IT
# <ipython-input-16-9ca08704df90>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   best_department = df.groupby('Department')['Performance_Score'].mean().idxmax()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=df['Department'], y=df['Salary'], estimator=np.mean, palette="coolwarm")
plt.title('Average Salary by Department', fontsize=14)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Average Salary', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-17-e67ceee84f86>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Department'], y=df['Salary'], estimator=np.mean, palette="coolwarm")

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Experience_Years'], y=df['Salary'], hue=df['Department'], palette="Dark2", s=100)
plt.title('Salary vs Experience', fontsize=14)
plt.xlabel('Years of Experience', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend(title="Department", bbox_to_anchor=(1, 1))
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Salary'], bins=5, color='blue', alpha=0.7, edgecolor='black')
plt.title('Salary Distribution', fontsize=14)
plt.xlabel('Salary', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df['Department'], y=df['Salary'], palette="pastel")
plt.title('Salary Distribution by Department', fontsize=14)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-20-e7356134eea6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Department'], y=df['Salary'], palette="pastel")
