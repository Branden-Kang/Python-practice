# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd

# %%
# Import the gapminder dataset from plotly express and select data for European countries
df = px.data.gapminder().query("continent== ['Europe']")

# Plot a line chart using plotly express
fig = px.line(df, x="year", y="gdpPercap", color='country', title='GDP per capita <br> 1952-2007')
 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c95e6420-e7eb-43ed-9210-8e5dc1acbc3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c95e6420-e7eb-43ed-9210-8e5dc1acbc3c")) {
#                     Plotly.newPlot(
#                         'c95e6420-e7eb-43ed-9210-8e5dc1acbc3c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Albania<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Albania", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Albania", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [1601.056136, 1942.2842440000002, 2312.888958, 2760.196931, 3313.422188, 3533.0039100000004, 3630.880722, 3738.9327350000003, 2497.4379010000002, 3193.054604, 4604.211737, 5937.029525999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Austria<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Austria", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Austria", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [6137.076492, 8842.59803, 10750.721109999999, 12834.6024, 16661.6256, 19749.4223, 21597.083619999998, 23687.82607, 27042.01868, 29095.920660000003, 32417.607689999997, 36126.4927], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Belgium<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Belgium", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=Belgium", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [8343.105126999999, 9714.960623, 10991.20676, 13149.04119, 16672.14356, 19117.97448, 20979.84589, 22525.56308, 25575.57069, 27561.196630000002, 30485.88375, 33692.60508], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Bosnia and Herzegovina<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Bosnia and Herzegovina", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "country=Bosnia and Herzegovina", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [973.5331947999999, 1353.989176, 1709.683679, 2172.3524230000003, 2860.16975, 3528.481305, 4126.613157, 4314.114757, 2546.781445, 4766.355904, 6018.975239, 7446.298803], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Bulgaria<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Bulgaria", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "country=Bulgaria", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [2444.2866480000002, 3008.670727, 4254.337839, 5577.0028, 6597.494398, 7612.240438, 8224.191647, 8239.854824, 6302.6234380000005, 5970.38876, 7696.777725, 10680.79282], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Croatia<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Croatia", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "country=Croatia", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [3119.23652, 4338.231617, 5477.890018, 6960.297861, 9164.090127, 11305.38517, 13221.82184, 13822.58394, 8447.794873, 9875.604515, 11628.38895, 14619.222719999998], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Czech Republic<br>year=%{x}<br>gdpPercap=%{y}", "legendgroup": "country=Czech Republic", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "country=Czech Republic", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [6876.14025, 8256.343918, 10136.86713, 11399.44489, 13108.4536, 14800.160619999999, 15377.22855, 16310.4434, 14297.021219999999, 16048.51424, 17596.210219999997, 22833.30851], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "ho ...

# %%
fig1 = go.Figure()

# %%
# Extract data and plot a trace for each country in the dataframe
df1 = df['country'].unique()
for i in df1:
    a = df[df['country'] == i]
    x = a['year']
    y = a['gdpPercap']
    fig1.add_trace(go.Scatter(x = x, y = y, mode='lines', name = i))

# %%
# Update plot layout attributes
fig1.update_layout(title='GDP per capita of European Countries <br> 1952-2007',
                   xaxis=dict(title='Year'),
                   yaxis=dict(title='GDP per capita in USD'),
                   hovermode='closest' )

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b3126d60-1439-4c87-83bf-fac6b1a2f1dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3126d60-1439-4c87-83bf-fac6b1a2f1dc")) {
#                     Plotly.newPlot(
#                         'b3126d60-1439-4c87-83bf-fac6b1a2f1dc',
#                         [{"mode": "lines", "name": "Albania", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [1601.056136, 1942.2842440000002, 2312.888958, 2760.196931, 3313.422188, 3533.0039100000004, 3630.880722, 3738.9327350000003, 2497.4379010000002, 3193.054604, 4604.211737, 5937.029525999999]}, {"mode": "lines", "name": "Austria", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [6137.076492, 8842.59803, 10750.721109999999, 12834.6024, 16661.6256, 19749.4223, 21597.083619999998, 23687.82607, 27042.01868, 29095.920660000003, 32417.607689999997, 36126.4927]}, {"mode": "lines", "name": "Belgium", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [8343.105126999999, 9714.960623, 10991.20676, 13149.04119, 16672.14356, 19117.97448, 20979.84589, 22525.56308, 25575.57069, 27561.196630000002, 30485.88375, 33692.60508]}, {"mode": "lines", "name": "Bosnia and Herzegovina", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [973.5331947999999, 1353.989176, 1709.683679, 2172.3524230000003, 2860.16975, 3528.481305, 4126.613157, 4314.114757, 2546.781445, 4766.355904, 6018.975239, 7446.298803]}, {"mode": "lines", "name": "Bulgaria", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [2444.2866480000002, 3008.670727, 4254.337839, 5577.0028, 6597.494398, 7612.240438, 8224.191647, 8239.854824, 6302.6234380000005, 5970.38876, 7696.777725, 10680.79282]}, {"mode": "lines", "name": "Croatia", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [3119.23652, 4338.231617, 5477.890018, 6960.297861, 9164.090127, 11305.38517, 13221.82184, 13822.58394, 8447.794873, 9875.604515, 11628.38895, 14619.222719999998]}, {"mode": "lines", "name": "Czech Republic", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [6876.14025, 8256.343918, 10136.86713, 11399.44489, 13108.4536, 14800.160619999999, 15377.22855, 16310.4434, 14297.021219999999, 16048.51424, 17596.210219999997, 22833.30851]}, {"mode": "lines", "name": "Denmark", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [9692.385245, 11099.65935, 13583.31351, 15937.21123, 18866.20721, 20422.9015, 21688.04048, 25116.17581, 26406.73985, 29804.34567, 32166.500060000002, 35278.41874]}, {"mode": "lines", "name": "Finland", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [6424.519071, 7545.415386, 9371.842561, 10921.63626, 14358.8759, 15605.422830000001, 18533.15761, 21141.01223, 20647.16499, 23723.9502, 28204.59057, 33207.0844]}, {"mode": "lines", "name": "France", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [7029.809327, 8662.834898000001, 10560.48553, 12999.91766, 16107.19171, 18292.635140000002, 20293.89746, 22066.44214, 24703.79615, 25889.78487, 28926.032339999998, 30470.0167]}, {"mode": "lines", "name": "Germany", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [7144.114393000001, 10187.82665, 12902.46291, 14745.62561, 18016.180269999997, 20512.92123, 22031.532740000002, 24639.18566, 26505.30317, 27788.88416, 30035.80198, 32170.37442]}, {"mode": "lines", "name": "Greece", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [3530.690067, 4916.299889, 6017.190732999999, 8513.097016, 12724.82957, 14195.524280000001, 15268.420890000001, 16120.528390000001, 17541.49634, 18747.69814, 22514.2548, 27538.41188]}, {"mode": "lines", "name": "Hungary", "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "y": [5263.6738159999995, 6040.180011,  ...

# %%
# Define the a palette of choice
import plotly.express as px
from itertools import cycle
palette = cycle(px.colors.qualitative.Pastel)

# Extract data and plot a trace for each country in the dataframe
fig1 = go.Figure()
for i in df1:
    a = df[df['country'] == i]
    x = a['year']
    y = a['gdpPercap']
    fig1.add_trace(go.Scatter(x = x, y = y, mode='lines', name = i, marker_color=next(palette)))


# x and y axis tick properties 
fig1.update_xaxes(showgrid=False, 
                 ticks="outside",
                 tickson="boundaries",
                 ticklen=10)

fig1.update_yaxes(showgrid=False,
                 ticks="outside",
                 tickson="boundaries",
                 ticklen=10)

# x axis line thickness and color
fig1.update_xaxes(showline=True,  
                 linewidth=2.5, 
                 linecolor='black')

# update plot layout variables
fig1.update_layout(font=dict(family="Courier New, monospace", 
                             size=18,
                             color="black"), 
                   width=1000, 
                   height=500,
                   title='GDP per capita of European Countries <br> 1952-2007',
                   title_x=0.4,
                   xaxis=dict(title='Year'),
                   yaxis=dict(title