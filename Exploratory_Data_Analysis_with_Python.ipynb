# %% [markdown]
# [Reference](https://medium.com/analytics-vidhya/exploratory-data-analysis-with-python-589a002989f8)

# %%
from sklearn.datasets import load_iris
import pandas as pd
data = load_iris() #3
df = pd.DataFrame(data.data, columns=data.feature_names)#4

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(df.shape)
print(df.columns)
# Out:
# (150, 4)
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    sepal length (cm)  ...  petal width (cm)
# sepal length (cm)           1.000000  ...          0.817941
# sepal width (cm)           -0.117570  ...         -0.366126
# petal length (cm)           0.871754  ...          0.962865
# petal width (cm)            0.817941  ...          1.000000
#
# [4 rows x 4 columns]

# %%
df.plot.hist( subplots = True, grid = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e2220320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e217a5c0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e21b05c0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e21665c0>],
#       dtype=object)

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e1fa19e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e1af28d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e1b218d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa5e1ad68d0>],
#       dtype=object)
