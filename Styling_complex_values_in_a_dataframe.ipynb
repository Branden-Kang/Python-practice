# %% [markdown]
# [Reference](https://cees-roele.medium.com/styling-complex-values-in-a-dataframe-7ebc5a17b3e7)

# %%
import pandas as pd
import numpy as np

# %%
# Create a 5x5 matrix of random numbers between [-0.3,0.7)
m = np.random.rand(5,5) - 0.3
df = pd.DataFrame(m)
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_1fb7a_row0_col0 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_1fb7a_row0_col1, #T_1fb7a_row0_col4, #T_1fb7a_row1_col0, #T_1fb7a_row1_col3, #T_1fb7a_row4_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1fb7a_row0_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_1fb7a_row0_col3 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_1fb7a_row1_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_1fb7a_row1_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_1fb7a_row1_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_1fb7a_row2_col0, #T_1fb7a_row2_col2, #T_1fb7a_row2_col3, #T_1fb7a_row3_col4, #T_1fb7a_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1fb7a_row2_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1fb7a_row2_col4 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_1fb7a_row3_col0 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_1fb7a_row3_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_1fb7a_row3_col2 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_1fb7a_row3_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_1fb7a_row4_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_1fb7a_row4_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_1fb7a_row4_col4 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1fb7a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fb7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fb7a_row0_col0" class="data row0 col0" >0.622125</td>
#       <td id="T_1fb7a_row0_col1" class="data row0 col1" >0.257838</td>
#       <td id="T_1fb7a_row0_col2" class="data row0 col2" >0.135233</td>
#       <td id="T_1fb7a_row0_col3" class="data row0 col3" >0.535091</td>
#       <td id="T_1fb7a_row0_col4" class="data row0 col4" >0.227610</td>
#     </tr>
#     <tr>
#       <th id="T_1fb7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1fb7a_row1_col0" class="data row1 col0" >0.628711</td>
#       <td id="T_1fb7a_row1_col1" class="data row1 col1" >-0.111232</td>
#       <td id="T_1fb7a_row1_col2" class="data row1 col2" >0.229143</td>
#       <td id="T_1fb7a_row1_col3" class="data row1 col3" >0.651015</td>
#       <td id="T_1fb7a_row1_col4" class="data row1 col4" >0.016267</td>
#     </tr>
#     <tr>
#       <th id="T_1fb7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1fb7a_row2_col0" class="data row2 col0" >-0.127933</td>
#       <td id="T_1fb7a_row2_col1" class="data row2 col1" >-0.217844</td>
#       <td id="T_1fb7a_row2_col2" class="data row2 col2" >0.080531</td>
#       <td id="T_1fb7a_row2_col3" class="data row2 col3" >0.008445</td>
#       <td id="T_1fb7a_row2_col4" class="data row2 col4" >0.159393</td>
#     </tr>
#     <tr>
#       <th id="T_1fb7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1fb7a_row3_col0" class="data row3 col0" >0.428820</td>
#       <td id="T_1fb7a_row3_col1" class="data row3 col1" >-0.086931</td>
#       <td id="T_1fb7a_row3_col2" class="data row3 col2" >0.339639</td>
#       <td id="T_1fb7a_row3_col3" class="data row3 col3" >0.112919</td>
#       <td id="T_1fb7a_row3_col4" class="data row3 col4" >-0.043466</td>
#     </tr>
#     <tr>
#       <th id="T_1fb7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1fb7a_row4_col0" class="data row4 col0" >0.035853</td>
#       <td id="T_1fb7a_row4_col1" class="data row4 col1" >-0.248090</td>
#       <td id="T_1fb7a_row4_col2" class="data row4 col2" >0.467629</td>
#       <td id="T_1fb7a_row4_col3" class="data row4 col3" >0.200647</td>
#       <td id="T_1fb7a_row4_col4" class="data row4 col4" >0.149727</td>
#     </tr>
#   </tbody>
# </table>

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
df.style.applymap(style_negative, props='color:red;')
# Out:
# <style type="text/css">
# #T_7f734_row1_col1, #T_7f734_row2_col0, #T_7f734_row2_col1, #T_7f734_row3_col1, #T_7f734_row3_col4, #T_7f734_row4_col1 {
#   color: red;
# }
# </style>
# <table id="T_7f734_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f734_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f734_row0_col0" class="data row0 col0" >0.622125</td>
#       <td id="T_7f734_row0_col1" class="data row0 col1" >0.257838</td>
#       <td id="T_7f734_row0_col2" class="data row0 col2" >0.135233</td>
#       <td id="T_7f734_row0_col3" class="data row0 col3" >0.535091</td>
#       <td id="T_7f734_row0_col4" class="data row0 col4" >0.227610</td>
#     </tr>
#     <tr>
#       <th id="T_7f734_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f734_row1_col0" class="data row1 col0" >0.628711</td>
#       <td id="T_7f734_row1_col1" class="data row1 col1" >-0.111232</td>
#       <td id="T_7f734_row1_col2" class="data row1 col2" >0.229143</td>
#       <td id="T_7f734_row1_col3" class="data row1 col3" >0.651015</td>
#       <td id="T_7f734_row1_col4" class="data row1 col4" >0.016267</td>
#     </tr>
#     <tr>
#       <th id="T_7f734_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f734_row2_col0" class="data row2 col0" >-0.127933</td>
#       <td id="T_7f734_row2_col1" class="data row2 col1" >-0.217844</td>
#       <td id="T_7f734_row2_col2" class="data row2 col2" >0.080531</td>
#       <td id="T_7f734_row2_col3" class="data row2 col3" >0.008445</td>
#       <td id="T_7f734_row2_col4" class="data row2 col4" >0.159393</td>
#     </tr>
#     <tr>
#       <th id="T_7f734_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f734_row3_col0" class="data row3 col0" >0.428820</td>
#       <td id="T_7f734_row3_col1" class="data row3 col1" >-0.086931</td>
#       <td id="T_7f734_row3_col2" class="data row3 col2" >0.339639</td>
#       <td id="T_7f734_row3_col3" class="data row3 col3" >0.112919</td>
#       <td id="T_7f734_row3_col4" class="data row3 col4" >-0.043466</td>
#     </tr>
#     <tr>
#       <th id="T_7f734_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f734_row4_col0" class="data row4 col0" >0.035853</td>
#       <td id="T_7f734_row4_col1" class="data row4 col1" >-0.248090</td>
#       <td id="T_7f734_row4_col2" class="data row4 col2" >0.467629</td>
#       <td id="T_7f734_row4_col3" class="data row4 col3" >0.200647</td>
#       <td id="T_7f734_row4_col4" class="data row4 col4" >0.149727</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
# "A Visit from St. Nicholas" by Clement Clarke Moore
# https://www.poetryfoundation.org/poems/43171/a-visit-from-st-nicholas
poem = """
'Twas the night before Christmas, when all through the house
Not a creature was stirring, not even a mouse;
The stockings were hung by the chimney with care,
In hopes that St. Nicholas soon would be there;
"""
words = re.split(r'\W+', poem)
pairs = [(x, len(x)) for x in words]
# Create a 5x5 matrix of tuples: (word, length)
matrix = []
for i in range(0,5):
    matrix.append(pairs[5*i:5*(i+1)])
df2 = pd.DataFrame(matrix)

# %%
df2.style.format(lambda x: x[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_186fb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_186fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_186fb_row0_col0" class="data row0 col0" ></td>
#       <td id="T_186fb_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_186fb_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_186fb_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_186fb_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_186fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_186fb_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_186fb_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_186fb_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_186fb_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_186fb_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_186fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_186fb_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_186fb_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_186fb_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_186fb_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_186fb_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_186fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_186fb_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_186fb_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_186fb_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_186fb_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_186fb_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_186fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_186fb_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_186fb_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_186fb_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_186fb_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_186fb_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %%
def font_short(v, weight, color):
    """
    Mark short words
    
    Parameters
    ----------
    v: tuple of (word, length)
    weight: CSS term accepted as a font-weight value
    color: CSS term accepted as a color
    """
    return f"font-weight: {weight}; color: {color}" if v[1] < 4 else None
# We must apply both `format` and `applymap` to the DataFrame.style
styler = df2.style.format(lambda x: x[0])
styler.applymap(font_short, weight='bold', color='orange')
# Out:
# <style type="text/css">
# #T_ef062_row0_col0, #T_ef062_row0_col2, #T_ef062_row1_col2, #T_ef062_row1_col4, #T_ef062_row2_col1, #T_ef062_row2_col2, #T_ef062_row2_col4, #T_ef062_row3_col1, #T_ef062_row3_col3, #T_ef062_row4_col0, #T_ef062_row4_col4 {
#   font-weight: bold;
#   color: orange;
# }
# </style>
# <table id="T_ef062_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef062_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef062_row0_col0" class="data row0 col0" ></td>
#       <td id="T_ef062_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_ef062_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_ef062_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_ef062_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_ef062_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef062_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_ef062_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_ef062_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_ef062_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_ef062_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_ef062_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef062_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_ef062_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_ef062_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_ef062_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_ef062_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_ef062_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef062_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_ef062_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_ef062_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_ef062_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_ef062_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_ef062_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef062_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_ef062_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_ef062_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_ef062_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_ef062_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib as mpl
def make_gradient(v, min_length, max_length, cmap='YlGn'):
    """
    Parameters
    ----------
    
    v: tuple of (word, length)
    min_length: int 
        minimum length of all words in the matrix
    max_length: int
        maximum length of all words in the matrix
    cmap: matplotlib color map, default value here is 'YlGn'
        
    Returns
    -------
    
    string:
        CSS setting a colour
              
    For Matplotlib colormaps:
    See: https://matplotlib.org/stable/tutorials/colors/colormaps.html
"""
    # normalize the word length as a fraction of the range 
    # between min_length and max_length
    rel_v = (v[1] - min_length) / (max_length - min_length)
    # define the colormap
    cmap = mpl.cm.get_cmap(cmap)
    # Get a colour out of the given colormap based on a value [0,1]
    rgba = cmap(rel_v)  
    # convert the colour to a hexadecimal string representation
    return f'background-color: {mpl.colors.rgb2hex(rgba)};'
# We must apply both `format` and `applymap` to the DataFrame.style
styler = df2.style.format(lambda x: x[0])
min_length = min([x[1] for x in pairs])
max_length = max([x[1] for x in pairs])
styler.applymap(lambda x: make_gradient(x, min_length, max_length))
# Out:
# <style type="text/css">
# #T_606bf_row0_col0 {
#   background-color: #ffffe5;
# }
# #T_606bf_row0_col1, #T_606bf_row1_col1, #T_606bf_row3_col2, #T_606bf_row4_col2, #T_606bf_row4_col3 {
#   background-color: #90d083;
# }
# #T_606bf_row0_col2, #T_606bf_row1_col2, #T_606bf_row1_col4, #T_606bf_row2_col1, #T_606bf_row2_col4, #T_606bf_row3_col1, #T_606bf_row4_col0 {
#   background-color: #bce395;
# }
# #T_606bf_row0_col3, #T_606bf_row2_col0, #T_606bf_row3_col4 {
#   background-color: #5fba6c;
# }
# #T_606bf_row0_col4 {
#   background-color: #379e54;
# }
# #T_606bf_row1_col0, #T_606bf_row4_col1 {
#   background-color: #004529;
# }
# #T_606bf_row1_col3 {
#   background-color: #1a7d40;
# }
# #T_606bf_row2_col2, #T_606bf_row3_col3 {
#   background-color: #f8fcbe;
# }
# #T_606bf_row2_col3, #T_606bf_row3_col0 {
#   background-color: #006435;
# }
# #T_606bf_row4_col4 {
#   background-color: #e0f3a8;
# }
# </style>
# <table id="T_606bf_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_606bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_606bf_row0_col0" class="data row0 col0" ></td>
#       <td id="T_606bf_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_606bf_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_606bf_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_606bf_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_606bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_606bf_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_606bf_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_606bf_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_606bf_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_606bf_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_606bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_606bf_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_606bf_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_606bf_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_606bf_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_606bf_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_606bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_606bf_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_606bf_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_606bf_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_606bf_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_606bf_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_606bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_606bf_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_606bf_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_606bf_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_606bf_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_606bf_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create one dataframe with only words
df_words = df2.applymap(lambda x: x[0])
# .. and a second one with only lengths
df_lengths = df2.applymap(lambda x: x[1])
# Now use the lengths to apply the background gradient to the words
df_words.style.background_gradient(gmap=df_lengths, axis=None)
# Out:
# <style type="text/css">
# #T_22890_row0_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_22890_row0_col1, #T_22890_row1_col1, #T_22890_row3_col2, #T_22890_row4_col2, #T_22890_row4_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_22890_row0_col2, #T_22890_row1_col2, #T_22890_row1_col4, #T_22890_row2_col1, #T_22890_row2_col4, #T_22890_row3_col1, #T_22890_row4_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_22890_row0_col3, #T_22890_row2_col0, #T_22890_row3_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_22890_row0_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_22890_row1_col0, #T_22890_row4_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_22890_row1_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_22890_row2_col2, #T_22890_row3_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_22890_row2_col3, #T_22890_row3_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_22890_row4_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# </style>
# <table id="T_22890_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22890_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22890_row0_col0" class="data row0 col0" ></td>
#       <td id="T_22890_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_22890_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_22890_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_22890_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_22890_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22890_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_22890_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_22890_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_22890_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_22890_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_22890_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22890_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_22890_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_22890_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_22890_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_22890_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_22890_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22890_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_22890_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_22890_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_22890_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_22890_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_22890_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22890_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_22890_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_22890_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_22890_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_22890_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_lengths.applymap(lambda x: f'length: {x}')
# Out:
#            0          1          2          3          4
# 0  length: 0  length: 4  length: 3  length: 5  length: 6
# 1  length: 9  length: 4  length: 3  length: 7  length: 3
# 2  length: 5  length: 3  length: 1  length: 8  length: 3
# 3  length: 8  length: 3  length: 4  length: 1  length: 5
# 4  length: 3  length: 9  length: 4  length: 4  length: 2

# %%
styler = df_words.style.background_gradient(gmap=df_lengths,     axis=None, cmap='YlOrRd')
styler.set_tooltips(
    df_lengths.applymap(lambda x: f'length: {x}'), 
    props=[
        ('visibility', 'hidden'),
        ('position', 'absolute'),
        ('background-color', 'white'),
        ('color', 'black'),
        ('z-index', 1),
        ('padding', '3px 3px'),
        ('margin', '2px')
    ])
# Out:
# <style type="text/css">
# #T_baeb8_ .pd-t {
#   visibility: hidden;
#   position: absolute;
#   background-color: white;
#   color: black;
#   z-index: 1;
#   padding: 3px 3px;
#   margin: 2px;
# }
# #T_baeb8_ #T_baeb8_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row0_col0 .pd-t::after {
#   content: "length: 0";
# }
# #T_baeb8_ #T_baeb8_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row0_col1 .pd-t::after {
#   content: "length: 4";
# }
# #T_baeb8_ #T_baeb8_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row0_col2 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row0_col3 .pd-t::after {
#   content: "length: 5";
# }
# #T_baeb8_ #T_baeb8_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row0_col4 .pd-t::after {
#   content: "length: 6";
# }
# #T_baeb8_ #T_baeb8_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row1_col0 .pd-t::after {
#   content: "length: 9";
# }
# #T_baeb8_ #T_baeb8_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row1_col1 .pd-t::after {
#   content: "length: 4";
# }
# #T_baeb8_ #T_baeb8_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row1_col2 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row1_col3 .pd-t::after {
#   content: "length: 7";
# }
# #T_baeb8_ #T_baeb8_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row1_col4 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row2_col0 .pd-t::after {
#   content: "length: 5";
# }
# #T_baeb8_ #T_baeb8_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row2_col1 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row2_col2 .pd-t::after {
#   content: "length: 1";
# }
# #T_baeb8_ #T_baeb8_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row2_col3 .pd-t::after {
#   content: "length: 8";
# }
# #T_baeb8_ #T_baeb8_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row2_col4 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row3_col0 .pd-t::after {
#   content: "length: 8";
# }
# #T_baeb8_ #T_baeb8_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row3_col1 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row3_col2 .pd-t::after {
#   content: "length: 4";
# }
# #T_baeb8_ #T_baeb8_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row3_col3 .pd-t::after {
#   content: "length: 1";
# }
# #T_baeb8_ #T_baeb8_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row3_col4 .pd-t::after {
#   content: "length: 5";
# }
# #T_baeb8_ #T_baeb8_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row4_col0 .pd-t::after {
#   content: "length: 3";
# }
# #T_baeb8_ #T_baeb8_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row4_col1 .pd-t::after {
#   content: "length: 9";
# }
# #T_baeb8_ #T_baeb8_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row4_col2 .pd-t::after {
#   content: "length: 4";
# }
# #T_baeb8_ #T_baeb8_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row4_col3 .pd-t::after {
#   content: "length: 4";
# }
# #T_baeb8_ #T_baeb8_row4_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_baeb8_ #T_baeb8_row4_col4 .pd-t::after {
#   content: "length: 2";
# }
# #T_baeb8_row0_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_baeb8_row0_col1, #T_baeb8_row1_col1, #T_baeb8_row3_col2, #T_baeb8_row4_col2, #T_baeb8_row4_col3 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_baeb8_row0_col2, #T_baeb8_row1_col2, #T_baeb8_row1_col4, #T_baeb8_row2_col1, #T_baeb8_row2_col4, #T_baeb8_row3_col1, #T_baeb8_row4_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_baeb8_row0_col3, #T_baeb8_row2_col0, #T_baeb8_row3_col4 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_baeb8_row0_col4 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_baeb8_row1_col0, #T_baeb8_row4_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_baeb8_row1_col3 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_baeb8_row2_col2, #T_baeb8_row3_col3 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_baeb8_row2_col3, #T_baeb8_row3_col0 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_baeb8_row4_col4 {
#   background-color: #fede80;
#   color: #000000;
# }
# </style>
# <table id="T_baeb8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baeb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_baeb8_row0_col0" class="data row0 col0" ><span class="pd-t"></span></td>
#       <td id="T_baeb8_row0_col1" class="data row0 col1" >Twas<span class="pd-t"></span></td>
#       <td id="T_baeb8_row0_col2" class="data row0 col2" >the<span class="pd-t"></span></td>
#       <td id="T_baeb8_row0_col3" class="data row0 col3" >night<span class="pd-t"></span></td>
#       <td id="T_baeb8_row0_col4" class="data row0 col4" >before<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_baeb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_baeb8_row1_col0" class="data row1 col0" >Christmas<span class="pd-t"></span></td>
#       <td id="T_baeb8_row1_col1" class="data row1 col1" >when<span class="pd-t"></span></td>
#       <td id="T_baeb8_row1_col2" class="data row1 col2" >all<span class="pd-t"></span></td>
#       <td id="T_baeb8_row1_col3" class="data row1 col3" >through<span class="pd-t"></span></td>
#       <td id="T_baeb8_row1_col4" class="data row1 col4" >the<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_baeb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_baeb8_row2_col0" class="data row2 col0" >house<span class="pd-t"></span></td>
#       <td id="T_baeb8_row2_col1" class="data row2 col1" >Not<span class="pd-t"></span></td>
#       <td id="T_baeb8_row2_col2" class="data row2 col2" >a<span class="pd-t"></span></td>
#       <td id="T_baeb8_row2_col3" class="data row2 col3" >creature<span class="pd-t"></span></td>
#       <td id="T_baeb8_row2_col4" class="data row2 col4" >was<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_baeb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_baeb8_row3_col0" class="data row3 col0" >stirring<span class="pd-t"></span></td>
#       <td id="T_baeb8_row3_col1" class="data row3 col1" >not<span class="pd-t"></span></td>
#       <td id="T_baeb8_row3_col2" class="data row3 col2" >even<span class="pd-t"></span></td>
#       <td id="T_baeb8_row3_col3" class="data row3 col3" >a<span class="pd-t"></span></td>
#       <td id="T_baeb8_row3_col4" class="data row3 col4" >mouse<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_baeb8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_baeb8_row4_col0" class="data row4 col0" >The<span class="pd-t"></span></td>
#       <td id="T_baeb8_row4_col1" class="data row4 col1" >stockings<span class="pd-t"></span></td>
#       <td id="T_baeb8_row4_col2" class="data row4 col2" >were<span class="pd-t"></span></td>
#       <td id="T_baeb8_row4_col3" class="data row4 col3" >hung<span class="pd-t"></span></td>
#       <td id="T_baeb8_row4_col4" class="data row4 col4" >by<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
