# %% [markdown]
# [Reference](https://towardsdatasciece.com/an-ultimate-cheat-sheet-for-data-visualization-in-pandas-4010e1b16b5c)

# %%
import pandas as pd
a = pd.Series([40, 34, 30, 22, 28, 17, 19, 20, 13, 9, 15, 10, 7, 3])
a.plot()

# %%
a.plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)

# %%
a.plot(kind='area')

# %%
a.plot.area()

# %%
b = pd.Series([45, 22, 12, 9, 20, 34, 28, 19, 26, 38, 41, 24, 14, 32])
c = pd.Series([25, 38, 33, 38, 23, 12, 30, 37, 34, 22, 16, 24, 12, 9])
d = pd.DataFrame({'a':a, 'b': b, 'c': c})

# %%
d.plot.area(figsize=(8, 6), title='Area Plot')

# %%
d.plot.area(alpha=0.4, color=['coral', 'purple', 'lightgreen'],figsize=(8, 6), title='Area Plot', fontsize=12)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rashida048/Datasets/master/nhanes_2015_2016.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  ...  BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0  83732     1.0     NaN     1.0  ...     43.6     35.9     101.1     2.0
# 1  83733     1.0     NaN     6.0  ...     40.0     33.2     107.9     NaN
# 2  83734     1.0     NaN     NaN  ...     37.0     31.0     116.5     2.0
# 3  83735     2.0     1.0     1.0  ...     37.7     38.3     110.1     2.0
# 4  83736     2.0     1.0     1.0  ...     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
df['BMXWT'].hist()

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].plot.hist(stacked=True, bins=20, fontsize=12, figsize=(10, 8))

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].hist(bins=20,figsize=(10, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cc925c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cb4afd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cb0c240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cabf4a8>]],
#       dtype=object)

# %%
df["DMDEDUC2x"] = df.DMDEDUC2.replace({1: "less than 9", 2: "9-11", 3: "HS/GED", 4: "Some college/AA", 5: "College", 7: "Refused", 9: "Don't know"})

# %%
df[['DMDEDUC2x', 'BPXSY1']].hist(by='DMDEDUC2x', figsize=(18, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd70c992c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd70d298240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cc7e128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd70cb29668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd70c9b04e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd70c9216a0>]],
#       dtype=object)

# %%
df["DMDMARTLx"] = df.DMDMARTL.replace({1: "Married", 2: "Widowed", 3: "Divorced", 4: "Separated", 5: "Never married", 6: "Living w/partner", 77: "Refused"})

# %%
df.groupby('DMDMARTLx')['BPXSY1'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(8, 6))

# %%
df.groupby('DMDEDUC2x')['BPXSY1'].mean().plot(kind='barh', rot=45, fontsize=10, figsize=(8, 6))

# %%
df_bmx = df.groupby('RIDRETH1')['BMXWT', 'BMXHT', 'BMXBMI'].mean().reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_bmx.plot(x = 'RIDRETH1', 
            y=['BMXWT', 'BMXHT', 'BMXBMI'], 
            kind = 'bar', 
            color = ['lightblue', 'red', 'yellow'], 
            fontsize=10)

# %%
df_bmx.plot(x = 'RIDRETH1', 
            y=['BMXWT', 'BMXHT', 'BMXBMI'], 
            kind = 'bar', stacked=True,
            color = ['lightblue', 'red', 'yellow'], 
            fontsize=10)

# %%
df_edu_marit = df.groupby('DMDEDUC2x')['DMDMARTL'].count()
pd.Series(df_edu_marit)
# Out:
# DMDEDUC2x
# 9-11                643
# College            1366
# Don't know            3
# HS/GED             1186
# Some college/AA    1621
# less than 9         655
# Name: DMDMARTL, dtype: int64

# %%
ax = pd.Series(df_edu_marit).plot.pie(subplots=True, label='',
     labels = ['College Education', 'high school', 
     'less than high school', 'Some college',
     'HS/GED', 'Unknown'],
     figsize = (8, 6),
     colors = ['lightgreen', 'violet', 'coral', 'skyblue', 'yellow', 'purple'], autopct = '%.2f')

# %%
color = {'boxes': 'DarkBlue', 'whiskers': 'coral', 
         'medians': 'Black', 'caps': 'Green'}
df[['BMXBMI', 'BMXLEG', 'BMXARML']].plot.box(figsize=(8, 6),color=color)

# %%
df.head(300).plot(x='BMXBMI', y= 'BPXSY1', kind = 'scatter')

# %%
df.head(500).plot.scatter(x= 'BMXWT', y = 'BMXHT', c ='BMXLEG', s=50, figsize=(8, 6))

# %%
df.head(200).plot.scatter(x= 'BMXHT', y = 'BMXWT', 
                          s =df['BMXBMI'][:200] * 7, 
                          alpha=0.5, color='purple',
                         figsize=(8, 6))

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', gridsize= 20)

# %%
import numpy as np

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', C = 'BMXHT',
                         reduce_C_function=np.max,
                         gridsize=15,
                        figsize=(8,6))

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', C = 'BMXHT',
                         reduce_C_function=np.max,
                         gridsize=15,
                        figsize=(8,6),
                        cmap = 'viridis')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML']], alpha = 0.2, figsize=(10, 8), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd700f5b828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700f12898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700f46ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700ef8d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700eb0f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd700e70240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700f12438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700e477b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700e47828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700dafcc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd700d64f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700d231d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700cd8438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700c8d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700cbf908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd700c74b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700c28dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700bea080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700b9d2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700b50550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd700b847b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700b36a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700aebc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700aa2ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd700a60198>]],
#       dtype=object)

# %%
df['BMXWT'].plot.kde()

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].plot.kde(figsize = (8, 6))

# %%
from pandas.plotting import parallel_coordinates

parallel_coordinates(df[['BMXWT', 'BMXHT', 'BMXBMI', 'RIAGENDR']].dropna().head(200), 'RIAGENDR', color=['blue', 'violet'])

# %%
from pandas.plotting import bootstrap_plot

bootstrap_plot(df['BMXBMI'], size=100, samples=1000, color='skyblue')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
