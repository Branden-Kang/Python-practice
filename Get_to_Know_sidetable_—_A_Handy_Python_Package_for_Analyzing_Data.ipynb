# %% [markdown]
# [Reference](https://medium.com/@anala007/get-to-know-sidetable-a-handy-python-package-for-analyzing-data-5ff027dbddc0)

# %%
# !python -m pip install sidetable
import pandas as pd 
import sidetable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.DataFrame({'A': ['a', 'b', 'a', 'b'],
'B': [1, 2, 3, 4],
'C': ['x', 'y', 'z', 'w']})
df.stb.freq(['A'])
# Out:
#    A  count  percent  cumulative_count  cumulative_percent
# 0  b      2     50.0                 2                50.0
# 1  a      2     50.0                 4               100.0

# %%
df.stb.freq(['B'])
# Out:
#    B  count  percent  cumulative_count  cumulative_percent
# 0  4      1     25.0                 1                25.0
# 1  3      1     25.0                 2                50.0
# 2  2      1     25.0                 3                75.0
# 3  1      1     25.0                 4               100.0

# %%
df.stb.freq(['A','B'])
# Out:
#    A  B  count  percent  cumulative_count  cumulative_percent
# 0  b  4      1     25.0                 1                25.0
# 1  b  2      1     25.0                 2                50.0
# 2  a  3      1     25.0                 3                75.0
# 3  a  1      1     25.0                 4               100.0
