# %% [markdown]
# [Reference](https://levelup.gitconnected.com/working-with-groupby-in-pandas-7e7823414537)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(
    {"key1":list("aabbab"),
     "key2":["one","two","three"]*2,
     "data1":np.random.randn(6),
     "data2":np.random.randn(6)})
df
# Out:
#   key1   key2     data1     data2
# 0    a    one -0.733562  0.160089
# 1    a    two -0.530035 -0.523706
# 2    b  three -1.122770  1.281235
# 3    b    one  0.620954 -1.906671
# 4    a    two  0.829370  0.365393
# 5    b  three -0.243797  0.055353

# %%
group=df["data1"].groupby(df["key1"])

# %%
group

# %%
group.mean()
# Out:
# key1
# a   -0.144742
# b   -0.248538
# Name: data1, dtype: float64

# %%
ave=df["data1"].groupby([df["key1"],
                         df["key2"]]).mean()
ave
# Out:
# key1  key2
# a     one     -0.733562
#       two      0.149668
# b     one      0.620954
#       three   -0.683283
# Name: data1, dtype: float64

# %%
ave.unstack()
# Out:
# key2       one     three       two
# key1
# a    -0.733562       NaN  0.149668
# b     0.620954 -0.683283       NaN

# %%
df.groupby("key1").mean()
# Out:
#          data1     data2
# key1
# a    -0.144742  0.000592
# b    -0.248538 -0.190028

# %%
df.groupby(["key1","key2"]).mean()
# Out:
#                data1     data2
# key1 key2
# a    one   -0.733562  0.160089
#      two    0.149668 -0.079157
# b    one    0.620954 -1.906671
#      three -0.683283  0.668294

# %% [markdown]
# # Iterating over Groups

# %%
for name, group in df.groupby("key1"):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one -0.733562  0.160089
# 1    a  two -0.530035 -0.523706
# 4    a  two  0.829370  0.365393
# b
#   key1   key2     data1     data2
# 2    b  three -1.122770  1.281235
# 3    b    one  0.620954 -1.906671
# 5    b  three -0.243797  0.055353

# %%
for (x1,x2),group in df.groupby(["key1",
                                 "key2"]):
    print(x1,x2)
    print(group)
# Out:
# a one
#   key1 key2     data1     data2
# 0    a  one -0.733562  0.160089
# a two
#   key1 key2     data1     data2
# 1    a  two -0.530035 -0.523706
# 4    a  two  0.829370  0.365393
# b one
#   key1 key2     data1     data2
# 3    b  one  0.620954 -1.906671
# b three
#   key1   key2     data1     data2
# 2    b  three -1.122770  1.281235
# 5    b  three -0.243797  0.055353

# %%
piece=dict(list(df.groupby("key1")))
piece["a"]
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.733562  0.160089
# 1    a  two -0.530035 -0.523706
# 4    a  two  0.829370  0.365393

# %% [markdown]
# # Selecting a Column or Subset of Columns

# %%
df.groupby(['key1', 
            'key2'])[['data1']].mean()
# Out:
#                data1
# key1 key2
# a    one   -0.733562
#      two    0.149668
# b    one    0.620954
#      three -0.683283

# %% [markdown]
# # Grouping with Dicts and Series

# %%
fruit=pd.DataFrame(np.random.randn(4,4),
                   columns=list("abcd"),
                   index=["apple","cherry",
                          "banana","kiwi"])
fruit
# Out:
#                a         b         c         d
# apple   0.289173 -1.981669  1.176892 -0.421748
# cherry -0.419894 -1.060042 -0.404343 -1.433458
# banana -0.257480  0.260566  0.631103  1.198952
# kiwi   -1.269702  0.131651  0.619057 -0.367785

# %%
label={"a": "green","b":"yellow",
       "c":"green","d":"yellow",
       "e":"purple"}

# %%
group=fruit.groupby(label,axis=1)

# %%
group.sum()
# Out:
#            green    yellow
# apple   1.466065 -2.403417
# cherry -0.824237 -2.493500
# banana  0.373624  1.459519
# kiwi   -0.650645 -0.236134

# %%
s=pd.Series(label)
s
# Out:
# a     green
# b    yellow
# c     green
# d    yellow
# e    purple
# dtype: object

# %%
fruit.groupby(s,axis=1).count()
# Out:
#         green  yellow
# apple       2       2
# cherry      2       2
# banana      2       2
# kiwi        2       2

# %% [markdown]
# # Grouping with Functions

# %%
fruit.groupby(len).sum()
# Out:
#           a         b         c         d
# 4 -1.269702  0.131651  0.619057 -0.367785
# 5  0.289173 -1.981669  1.176892 -0.421748
# 6 -0.677374 -0.799476  0.226761 -0.234506

# %% [markdown]
# # Grouping by Index Levels

# %%
data=pd.DataFrame(np.random.randn(4,5),
                  columns=[list("AAABB"),
                           [1,2,3,1,2]])

# %%
data.columns.names=["letter","number"]
data
# Out:
# letter         A                             B
# number         1         2         3         1         2
# 0       1.579174 -2.026467  0.250509 -0.155879 -0.457966
# 1       0.694029  0.091966 -0.184268  0.154181 -2.062210
# 2       0.744386  1.705838 -0.489713 -0.008884  1.349077
# 3       0.249495  0.272742  0.703468 -0.216501 -0.548471

# %%
data.groupby(level="letter",axis=1).sum()
# Out:
# letter         A         B
# 0      -0.196784 -0.613844
# 1       0.601727 -1.908029
# 2       1.960511  1.340192
# 3       1.225705 -0.764972
