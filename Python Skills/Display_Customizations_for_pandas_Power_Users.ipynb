# %% [markdown]
# [Reference1](https://towardsdatascience.com/become-a-pandas-power-user-with-these-display-customizations-6d3a5a5885c1)
# [Reference2](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html)

# %%
import os
import platform
from platform import python_version
# !pip install jupyterlab
import jupyterlab
import pandas as pd
import random
# Out:
# ...
#      |████████████████████████████████| 7.8MB 2.7MB/s
# ...
#      |████████████████████████████████| 61kB 7.7MB/s
# ...
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# ...

# %%
print("System")
print("os name: %s" % os.name)
print("system: %s" % platform.system())
print("release: %s" % platform.release())
print()
print("Python")
print("version: %s" % python_version())
print()
print("Python Packages")
print("jupterlab==%s" % jupyterlab.__version__)
print("pandas==%s" % pd.__version__)
# Out:
# System
# os name: posix
# system: Linux
# release: 4.19.112+
#
# Python
# version: 3.6.9
#
# Python Packages
# jupterlab==2.2.6
# pandas==1.0.5

# %%
seed = 42
random.seed(seed)
pd.np.random.seed(seed)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def generate_sentence(n_chars=200):
    return ''.join(random.choice('abcdefg ') for _ in range(n_chars))

n = 100
df = pd.DataFrame(
    {
        "col1": pd.np.random.random_sample(n),
        "text": [generate_sentence() for _ in range(n)]
    }
)
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   import sys
# (100, 2)

# %%
df.head()
# Out:
#        col1                                               text
# 0  0.374540  baeddcbbgaabddadgd eacgfecdfbbgbffea bgbefdbad...
# 1  0.950714  aabdcg  dgacgage eg cdedaafaa cabcbbdgbdabgfed...
# 2  0.731994  befbdeddcaad b gdg gdcabgdc adb c f g c  ede d...
# 3  0.598658  bedgdef fgff eeedbdfbcdd eebdedfceaceaaec bae ...
# 4  0.156019  eaee c  ffg fddgdgaf ggc acfb b acgcb efgbfgf ...

# %%
df.iloc[0, 0] = 1e-10
df.head()
# Out:
#            col1                                               text
# 0  1.000000e-10  baeddcbbgaabddadgd eacgfecdfbbgbffea bgbefdbad...
# 1  9.507143e-01  aabdcg  dgacgage eg cdedaafaa cabcbbdgbdabgfed...
# 2  7.319939e-01  befbdeddcaad b gdg gdcabgdc adb c f g c  ede d...
# 3  5.986585e-01  bedgdef fgff eeedbdfbcdd eebdedfceaceaaec bae ...
# 4  1.560186e-01  eaee c  ffg fddgdgaf ggc acfb b acgcb efgbfgf ...

# %%
pd.options.display.float_format = '{:,.10f}'.format
df.head()
# Out:
#           col1                                               text
# 0 0.0000000001  baeddcbbgaabddadgd eacgfecdfbbgbffea bgbefdbad...
# 1 0.9507143064  aabdcg  dgacgage eg cdedaafaa cabcbbdgbdabgfed...
# 2 0.7319939418  befbdeddcaad b gdg gdcabgdc adb c f g c  ede d...
# 3 0.5986584842  bedgdef fgff eeedbdfbcdd eebdedfceaceaaec bae ...
# 4 0.1560186404  eaee c  ffg fddgdgaf ggc acfb b acgcb efgbfgf ...

# %%
pd.reset_option('display.float_format')

# %%
df.T
# Out:
#                                                       0  ...                                                 99
# col1                                              1e-10  ...                                           0.107891
# text  baeddcbbgaabddadgd eacgfecdfbbgbffea bgbefdbad...  ...  fabgecgba addfaecedbdceebdaaebgbafdacbfbg fgeg...
#
# [2 rows x 100 columns]

# %%
pd.set_option("display.max_columns", 100)
df.T
# Out:
#                                                       0  \
# col1                                              1e-10
# text  baeddcbbgaabddadgd eacgfecdfbbgbffea bgbefdbad...
#
#                                                       1  \
# col1                                           0.950714
# text  aabdcg  dgacgage eg cdedaafaa cabcbbdgbdabgfed...
#
#                                                       2  \
# col1                                           0.731994
# text  befbdeddcaad b gdg gdcabgdc adb c f g c  ede d...
#
#                                                       3  \
# col1                                           0.598658
# text  bedgdef fgff eeedbdfbcdd eebdedfceaceaaec bae ...
#
#                                                       4  \
# col1                                           0.156019
# text  eaee c  ffg fddgdgaf ggc acfb b acgcb efgbfgf ...
#
#                                                       5  \
# ...

# %%
pd.set_option("display.max_columns", 20)

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.set_option('max_colwidth', 500)

# %%
pd.set_option('large_repr', 'info')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    100 non-null    float64
#  1   text    100 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %%
pd.reset_option('large_repr') # reset it
