# %% [markdown]
# [Reference](https://medium.com/@tricky16122000/7-python-libraries-for-data-science-880ac741c86f)

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# Load and clean
sales = pd.read_csv("sales.csv")
sales['date'] = pd.to_datetime(sales['date'], errors='coerce')
sales.dropna(subset=['amount'], inplace=True)

# GroupBy magic
monthly_sales = sales.groupby(pd.Grouper(key='date', freq='M'))['amount'].sum()
print(monthly_sales)

# %% [markdown]
# # NumPy

# %%
import numpy as np

arr = np.random.rand(1000000)
mean_value = arr.mean()
print(mean_value)
# Out:
# 0.4999649807114343

# %% [markdown]
# # Matplotlib & Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
sns.scatterplot(data=sales, x="date", y="amount")
plt.title("Sales Over Time")
plt.show()

# %% [markdown]
# # SciPy
# SciPy is the toolbox for scientific computing.

# %% [markdown]
# # scikit-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = sales[['amount']]
y = sales['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = RandomForestClassifier().fit(X_train, y_train)
print(model.score(X_test, y_test))

# %% [markdown]
# # TensorFlow & PyTorch
# - TensorFlow is like a big corporate handbook — structured, powerful, but occasionally frustrating.
# - PyTorch feels like the cool open‑source kid who explains things in plain English.

# %% [markdown]
# # Jupyter
# It’s the perfect mix of code, notes, visuals, and experimentation.
