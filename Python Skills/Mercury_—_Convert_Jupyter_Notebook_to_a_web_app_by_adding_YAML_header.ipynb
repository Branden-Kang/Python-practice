# %% [markdown]
# [Reference](https://medium.com/@MLJARofficial/mercury-convert-jupyter-notebook-to-a-web-app-by-adding-yaml-header-872ce4e53676)

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
_ = sns.pairplot(tips, hue='smoker')

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
_ = sns.pairplot(tips, hue='sex')

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
_ = sns.pairplot(tips, hue='time')

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
_ = sns.pairplot(tips, hue='day')

# %% [markdown]
# # Install Mercury

# %%
pip install mljar-mercury
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 11.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 596 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 126 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 296 kB 59.7 MB/s
# ...
#      |████████████████████████████████| 556 kB 55.9 MB/s
# ...
#      |████████████████████████████████| 791 kB 64.3 MB/s
# ...
#      |████████████████████████████████| 81 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 47.9 MB/s
# ...
#      |████████████████████████████████| 7.9 MB 66.1 MB/s
# ...
#      |████████████████████████████████| 957 kB 66.2 MB/s
# ...
#      |████████████████████████████████| 401 kB 64.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 58.4 MB/s
# ...
#      |████████████████████████████████| 89 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 189 kB 80.9 MB/s
# ...

# %%
# mercury watch tips_dashboard.ipynb

# %% [markdown]
# ```python
# # Procfile
# web: mercury runserver --runworker 0.0.0.0:$PORT
# ```

# %% [markdown]
# ```
# git add tips_dashboard.ipynb
# git add requirements.txt
# git add Procfile
# git commit -am "add tips dashboard"
# git push
# ```

# %%
heroku create mercury-demo-1

# %%
# heroku config:set SERVE_STATIC=True
# heroku config:set ALLOWED_HOSTS=mercury-simple-demo.herokuapp.com
# heroku config:set NOTEBOOKS=/app/*.ipynb

# %%
# git push heroku main
