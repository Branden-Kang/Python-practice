# %% [markdown]
# [Reference](https://medium.com/@lmpo/getting-started-with-gemini-cli-a94f37428424)

# %% [markdown]
# # 1. Installation and Setup
# ```
# node -v
# ```

# %% [markdown]
# ```
# npm install -g @google/gemini-cli
# ```

# %% [markdown]
# ```
# gemini
# ```

# %% [markdown]
# ```
# export GOOGLE_CLOUD_PROJECT="your-project-id"
# export GEMINI_API_KEY="YOUR_API_KEY"
# ```

# %% [markdown]
# ```
# # ~/.bashrc or ~/.zshrc
# export GOOGLE_CLOUD_PROJECT="your-project-id"
#
# export GEMINI_API_KEY="YOUR_API_KEY"
#
# source ~/.zshrc  # or source ~/.bashrc

# %% [markdown]
# # 2. Basic Commands and Configuration
# ```
# !ls
# ```
#
# ```
# Describe the content of the image file @image.png
# ```
#
# ```
# List all *.png files, analyze each image, and rename them with descriptive, meaningful names.
# ```
#
# ```
# Summarize the article @https://example.com/mcp-article
# ```

# %% [markdown]
# # 3. Chat Functionality (/chat)
# ```
# /chat save article
# /chat list
# /chat resojme article
# ```

# %% [markdown]
# # 4. Model Context Protocol (MCP) Integration
# ```
# # ~/.gemini/settings.json
# {
#   "mcpServers": {
#     "playwright": {
#       "command": "npx",
#       "args": ["-y", "@modelcontextprotocol/server-playwright"],
#       "env": {}
#     }
#   }
# }
# ```

# %% [markdown]
# # 5. AI Programming Capabilities
# ```
# # Coding Standards
# - **Python Environment**: Use Python 3.9+.
# - **Code Style**: Follow PEP 8.
# - **Frontend**: Use React with Tailwind CSS.
# - **Theme Colors**: Primary: #007bff, Secondary: #6c757d.
# ```

# %% [markdown]
# # 6. Additional Commands
# - /about: Displays version information.
# - /bug: Submits bug reports.
# /clear: Clears the terminal screen.
# - /docs: Opens the documentation.
# - /editor: Configures external editors.
# - /help: Provides usage help.
# - /privacy: Manages privacy settings.
# - /quit: Exits Gemini CLI (or use Ctrl+C twice).
# - /stats: Shows token usage statistics.
