# %% [markdown]
# [Reference](https://medium.com/@tricky16122000/top-6-python-debugging-tools-for-software-developers-2431625fb777)

# %% [markdown]
# # 1. pdb — The OG That Refuses to Die

# %%
import pdb
pdb.set_trace()
# Out:
# --Call--
# > /usr/local/lib/python3.12/dist-packages/IPython/core/displayhook.py(252)__call__()
#     250         sys.stdout.flush()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#     254
#
# ipdb>
# ipdb> exit

# %% [markdown]
# #

# %% [markdown]
# # 2. ipdb — Like pdb, But on Steroids

# %%
pip install ipdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.3 MB/s eta 0:00:00
# ...

# %%
import ipdb; ipdb.set_trace()
# Out:
# --Call--
# > /usr/local/lib/python3.12/dist-packages/IPython/core/displayhook.py(252)__call__()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#
# ipdb> exit

# %% [markdown]
# # 3. PuDB — Debugging, But Make It Visual

# %% [markdown]
# ```
# pip install pudb
# python -m pudb.run your_script.py
# ```

# %% [markdown]
# # 4. PyCharm Debugger — The Cadillac of Debuggers
# PyCharm’s debugger is buttery smooth, with breakpoints you can click (yes, click), step-through execution, and variable watches.

# %% [markdown]
# # 5. Visual Studio Code Debugger — Free, Fast, and Surprisingly Good
#
# Breakpoints, watch variables, conditional execution — it’s got it all.

# %% [markdown]
# # 6. pdb++ — pdb, But Actually Fun

# %%
pip install pdbpp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 1.4 MB/s eta 0:00:00
# ...
