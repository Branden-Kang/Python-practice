# %% [markdown]
# [Reference](https://ai.plainenglish.io/important-methods-in-pandas-2d4c774fcac9)

# %%
import pandas as pd
import numpy as np

s = pd.Series([1,2,3,4],
              index=["a","b","c","d"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s["a"]
# Out:
# 1

# %%
s2=s.reindex(["b","d","a","c","e"])
s2
# Out:
# b    2.0
# d    4.0
# a    1.0
# c    3.0
# e    NaN
# dtype: float64

# %%
s3 = pd.Series(["blue","yellow","purple"],
              index=[0,2,4])
s3
# Out:
# 0      blue
# 2    yellow
# 4    purple
# dtype: object

# %%
s3.reindex(range(6),method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    yellow
# 3    yellow
# 4    purple
# 5    purple
# dtype: object

# %%
df=pd.DataFrame(np.arange(9).reshape(3,3),
                index=["a","c","d"],
                columns=["Tim","Tom","Kate"])
df
# Out:
#    Tim  Tom  Kate
# a    0    1     2
# c    3    4     5
# d    6    7     8

# %%
df2=df.reindex(["d","c","b","a"])
df2
# Out:
#    Tim  Tom  Kate
# d  6.0  7.0   8.0
# c  3.0  4.0   5.0
# b  NaN  NaN   NaN
# a  0.0  1.0   2.0

# %%
names=["Kate","Tim","Tom"]
df.reindex(columns=names)
# Out:
#    Kate  Tim  Tom
# a     2    0    1
# c     5    3    4
# d     8    6    7

# %%
df.loc[["c","d","a"]]
# Out:
#    Tim  Tom  Kate
# c    3    4     5
# d    6    7     8
# a    0    1     2

# %%
s=pd.Series(np.arange(5.),
            index=["a","b","c","d","e"])

# %%
s
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_s=s.drop("b")
new_s
# Out:
# a    0.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
s.drop(["c","d"])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data=pd.DataFrame(np.arange(16).reshape(4,4),
                  index=["Kate","Tim",
                         "Tom","Alex"],
                  columns=list("ABCD"))
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.drop(["Kate","Tim"])
# Out:
#        A   B   C   D
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.drop("A",axis=1)
# Out:
#        B   C   D
# Kate   1   2   3
# Tim    5   6   7
# Tom    9  10  11
# Alex  13  14  15

# %%
data.drop("Kate",axis=0)
# Out:
#        A   B   C   D
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.mean(axis="index")
# Out:
# A    6.0
# B    7.0
# C    8.0
# D    9.0
# dtype: float64

# %%
data.mean(axis="columns")
# Out:
# Kate     1.5
# Tim      5.5
# Tom      9.5
# Alex    13.5
# dtype: float64
