# %% [markdown]
# [Reference](https://levelup.gitconnected.com/practical-guide-into-data-analysis-and-machine-learning-using-python-7e8ce4081dfc)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
iris_data = datasets.load_iris()
iris_data.keys()
iris_data['target_names']

df_data = pd.DataFrame(iris_data['data'], columns=iris_data['feature_names'])
df_target = pd.DataFrame(iris_data['target'], columns=['species'])
df = pd.concat([df_data, df_target], axis=1)

df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                  5.1               3.5  ...               0.2        0
# 1                  4.9               3.0  ...               0.2        0
# 2                  4.7               3.2  ...               0.2        0
# 3                  4.6               3.1  ...               0.2        0
# 4                  5.0               3.6  ...               0.2        0
# ..                 ...               ...  ...               ...      ...
# 145                6.7               3.0  ...               2.3        2
# 146                6.3               2.5  ...               1.9        2
# 147                6.5               3.0  ...               2.0        2
# 148                6.2               3.4  ...               2.3        2
# 149                5.9               3.0  ...               1.8        2
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2        0
# 1                4.9               3.0  ...               0.2        0
# 2                4.7               3.2  ...               0.2        0
# 3                4.6               3.1  ...               0.2        0
# 4                5.0               3.6  ...               0.2        0
#
# [5 rows x 5 columns]

# %%
df['sepal length (cm)']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
df.iloc[:3, :2]
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2

# %%
df.loc[:3, [x for x in df.columns if 'width' in x]]
# Out:
#    sepal width (cm)  petal width (cm)
# 0               3.5               0.2
# 1               3.0               0.2
# 2               3.2               0.2
# 3               3.1               0.2

# %%
# Listing all the available unique classes

df['species'].unique()
df[df['species'] == 2]
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 100                6.3               3.3  ...               2.5        2
# 101                5.8               2.7  ...               1.9        2
# 102                7.1               3.0  ...               2.1        2
# 103                6.3               2.9  ...               1.8        2
# 104                6.5               3.0  ...               2.2        2
# 105                7.6               3.0  ...               2.1        2
# 106                4.9               2.5  ...               1.7        2
# 107                7.3               2.9  ...               1.8        2
# 108                6.7               2.5  ...               1.8        2
# 109                7.2               3.6  ...               2.5        2
# 110                6.5               3.2  ...               2.0        2
# 111                6.4               2.7  ...               1.9        2
# 112                6.8               3.0  ...               2.1        2
# 113                5.7               2.5  ...               2.0        2
# 114                5.8               2.8  ...               2.4        2
# 115                6.4               3.2  ...               2.3        2
# 116                6.5               3.0  ...               1.8        2
# 117                7.7               3.8  ...               2.2        2
# 118                7.7               2.6  ...               2.3        2
# 119                6.0               2.2  ...               1.5        2
# 120                6.9               3.2  ...               2.3        2
# 121                5.6               2.8  ...               2.0        2
# 122                7.7               2.8  ...               2.0        2
# 123                6.3               2.7  ...               1.8        2
# 124                6.7               3.3  ...               2.1        2
# 125                7.2               3.2  ...               1.8        2
# 126                6.2               2.8  ...               1.8        2
# 127                6.1               3.0  ...               1.8        2
# 128                6.4               2.8  ...               2.1        2
# 129                7.2               3.0  ...               1.6        2
# 130                7.4               2.8  ...               1.9        2
# 131                7.9               3.8  ...               2.0        2
# 132                6.4               2.8  ...               2.2        2
# 133                6.3               2.8  ...               1.5        2
# 134                6.1               2.6  ...               1.4        2
# 135                7.7               3.0  ...               2.3        2
# 136                6.3               3.4  ...               2.4        2
# 137                6.4               3.1  ...               1.8        2
# 138                6.0               3.0  ...               1.8        2
# 139                6.9               3.1  ...               2.1        2
# 140                6.7               3.1  ...               2.4        2
# 141                6.9               3.1  ...               2.3        2
# 142                5.8               2.7  ...               1.9        2
# 143                6.8               3.2  ...               2.3        2
# 144                6.7               3.3  ...               2.5        2
# 145                6.7               3.0  ...               2.3        2
# 146                6.3               2.5  ...               1.9        2
# 147                6.5               3.0  ...               2.0        2
# 148                6.2               3.4  ...               2.3        2
# 149                5.9               3.0  ...               1.8        2
#
# [50 rows x 5 columns]

# %%
df.count()
# Out:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# species              150
# dtype: int64

# %%
df[df['species'] == 2].count()
# Out:
# sepal length (cm)    50
# sepal width (cm)     50
# petal length (cm)    50
# petal width (cm)     50
# species              50
# dtype: int64

# %%
virginica = df[df['species'] == 2].reset_index(drop=True)
virginica
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                 6.3               3.3  ...               2.5        2
# 1                 5.8               2.7  ...               1.9        2
# 2                 7.1               3.0  ...               2.1        2
# 3                 6.3               2.9  ...               1.8        2
# 4                 6.5               3.0  ...               2.2        2
# 5                 7.6               3.0  ...               2.1        2
# 6                 4.9               2.5  ...               1.7        2
# 7                 7.3               2.9  ...               1.8        2
# 8                 6.7               2.5  ...               1.8        2
# 9                 7.2               3.6  ...               2.5        2
# 10                6.5               3.2  ...               2.0        2
# 11                6.4               2.7  ...               1.9        2
# 12                6.8               3.0  ...               2.1        2
# 13                5.7               2.5  ...               2.0        2
# 14                5.8               2.8  ...               2.4        2
# 15                6.4               3.2  ...               2.3        2
# 16                6.5               3.0  ...               1.8        2
# 17                7.7               3.8  ...               2.2        2
# 18                7.7               2.6  ...               2.3        2
# 19                6.0               2.2  ...               1.5        2
# 20                6.9               3.2  ...               2.3        2
# 21                5.6               2.8  ...               2.0        2
# 22                7.7               2.8  ...               2.0        2
# 23                6.3               2.7  ...               1.8        2
# 24                6.7               3.3  ...               2.1        2
# 25                7.2               3.2  ...               1.8        2
# 26                6.2               2.8  ...               1.8        2
# 27                6.1               3.0  ...               1.8        2
# 28                6.4               2.8  ...               2.1        2
# 29                7.2               3.0  ...               1.6        2
# 30                7.4               2.8  ...               1.9        2
# 31                7.9               3.8  ...               2.0        2
# 32                6.4               2.8  ...               2.2        2
# 33                6.3               2.8  ...               1.5        2
# 34                6.1               2.6  ...               1.4        2
# 35                7.7               3.0  ...               2.3        2
# 36                6.3               3.4  ...               2.4        2
# 37                6.4               3.1  ...               1.8        2
# 38                6.0               3.0  ...               1.8        2
# 39                6.9               3.1  ...               2.1        2
# 40                6.7               3.1  ...               2.4        2
# 41                6.9               3.1  ...               2.3        2
# 42                5.8               2.7  ...               1.9        2
# 43                6.8               3.2  ...               2.3        2
# 44                6.7               3.3  ...               2.5        2
# 45                6.7               3.0  ...               2.3        2
# 46                6.3               2.5  ...               1.9        2
# 47                6.5               3.0  ...               2.0        2
# 48                6.2               3.4  ...               2.3        2
# 49                5.9               3.0  ...               1.8        2
#
# [50 rows x 5 columns]

# %%
df[(df['species'] == 2) & (df['petal width (cm)'] > 2.2)]
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 100                6.3               3.3  ...               2.5        2
# 109                7.2               3.6  ...               2.5        2
# 114                5.8               2.8  ...               2.4        2
# 115                6.4               3.2  ...               2.3        2
# 118                7.7               2.6  ...               2.3        2
# 120                6.9               3.2  ...               2.3        2
# 135                7.7               3.0  ...               2.3        2
# 136                6.3               3.4  ...               2.4        2
# 140                6.7               3.1  ...               2.4        2
# 141                6.9               3.1  ...               2.3        2
# 143                6.8               3.2  ...               2.3        2
# 144                6.7               3.3  ...               2.5        2
# 145                6.7               3.0  ...               2.3        2
# 148                6.2               3.4  ...               2.3        2
#
# [14 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)     species
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 25%             5.100000          2.800000  ...          0.300000    0.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# 75%             6.400000          3.300000  ...          1.800000    2.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [8 rows x 5 columns]

# %%
# Passing in custom percentiles
df.describe(percentiles=[.2, .4, .8, .9, .95])
# Out:
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)     species
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 20%             5.000000          2.700000  ...          0.200000    0.000000
# 40%             5.600000          3.000000  ...          1.160000    1.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# 80%             6.520000          3.400000  ...          1.900000    2.000000
# 90%             6.900000          3.610000  ...          2.200000    2.000000
# 95%             7.255000          3.800000  ...          2.300000    2.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [11 rows x 5 columns]

# %%
# Checking for correlations between the features
df.corr()
# Out:
#                    sepal length (cm)  ...   species
# sepal length (cm)           1.000000  ...  0.782561
# sepal width (cm)           -0.117570  ... -0.426658
# petal length (cm)           0.871754  ...  0.949035
# petal width (cm)            0.817941  ...  0.956547
# species                     0.782561  ...  1.000000
#
# [5 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Plotting an histogram of the petal width feature
plt.figure(figsize=(6,4))
plt.hist(df['petal width (cm)'], color='black')
plt.xlabel('Width', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Iris Petal Width', fontsize=14,)
# Out:
# Text(0.5, 1.0, 'Iris Petal Width')

# %%
# Plotting subplots of the 4 features (NOTE: THIS IS NOT IDEAL!)
fig, ax = plt.subplots(2, 2, figsize=(6,4))
ax[0][0].hist(df['petal width (cm)'], color='black')
ax[0][0].set_xlabel('Width', fontsize=12)
ax[0][0].set_ylabel('Count', fontsize=12)
ax[0][0].set_title("Iris Petal Width", fontsize=14)

ax[0][1].hist(df['petal length (cm)'], color='black')
ax[0][1].set_xlabel('Length', fontsize=12)
ax[0][1].set_ylabel('Count', fontsize=12)
ax[0][1].set_title("Iris Petal Length", fontsize=14)
ax[1][0].hist(df['sepal width (cm)'], color='black')

ax[1][0].set_xlabel('Width', fontsize=12)
ax[1][0].set_ylabel('Count', fontsize=12)
ax[1][0].set_title("Iris Sepal Width", fontsize=14)

ax[1][1].hist(df['sepal length (cm)'], color='black')
ax[1][1].set_xlabel('Length', fontsize=12)
ax[1][1].set_ylabel('Count', fontsize=12)
ax[1][1].set_title("Iris Sepal Length", fontsize=14)

plt.tight_layout()

# %%
# A scatterplot of the Petal Width against the Petal Length
plt.scatter(df['petal width (cm)'], df['petal length (cm)'], color='green')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.title('Petal Scatterplot')
# Out:
# Text(0.5, 1.0, 'Petal Scatterplot')

# %%
# A simple line plot of the Petal Length
plt.figure(figsize=(6,6))
plt.plot(df['petal length (cm)'], color='blue')
plt.xlabel('Specimen Number')
plt.ylabel('Petal Length')
plt.title('Petal Length Plot')
# Out:
# Text(0.5, 1.0, 'Petal Length Plot')

# %%
# A Bar-chart of the mean of each feature for the 3 classes of irises

fig, ax = plt.subplots(figsize=(6,6))
labels = [x for x in df.columns if 'length' in x or 'width' in x]

ver_y = [df[df['species'] == 0][x].mean() for x in labels]
vir_y = [df[df['species'] == 1][x].mean() for x in labels]
set_y = [df[df['species'] == 2][x].mean() for x in labels]
x = np.arange(len(labels))

plt.bar(x, vir_y, bottom=set_y, color='darkgrey')
plt.bar(x, set_y, bottom=ver_y, color='white')
plt.bar(x, ver_y, color='black')

plt.xticks(x)
ax.set_xticklabels(labels, rotation=-70, fontsize=12);
plt.title('Mean Measurement by Class')
plt.legend(['Setosa', 'Versicolor', 'Virginica'])

# %%
import seaborn as sns
sns.pairplot(df, hue='species')

# %%
sns.set(style='white', palette='muted')
features = [col for col in df.columns if '(cm)' in col]

plt.figure(figsize=(7, 7))
for n in range(len(features)):
    plt.subplot(2, 2, n+1)
    sns.violinplot(x='species', y=features[n], data=df)
    
plt.suptitle('Violin Plots', fontsize=16)
plt.tight_layout()

# %%
# Replacing each of the unique Iris types

dict_map = {0: 'SET', 
            1: 'VIR', 
            2: 'VER'}
df['species'] = df['species'].map(dict_map)
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                  5.1               3.5  ...               0.2      SET
# 1                  4.9               3.0  ...               0.2      SET
# 2                  4.7               3.2  ...               0.2      SET
# 3                  4.6               3.1  ...               0.2      SET
# 4                  5.0               3.6  ...               0.2      SET
# ..                 ...               ...  ...               ...      ...
# 145                6.7               3.0  ...               2.3      VER
# 146                6.3               2.5  ...               1.9      VER
# 147                6.5               3.0  ...               2.0      VER
# 148                6.2               3.4  ...               2.3      VER
# 149                5.9               3.0  ...               1.8      VER
#
# [150 rows x 5 columns]

# %%
# Creating a new feature via petal width
df['wide petal'] = df['petal width (cm)'].apply(lambda x: 1 if x>=1.3 else 0)
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  species  wide petal
# 0                  5.1               3.5  ...      SET           0
# 1                  4.9               3.0  ...      SET           0
# 2                  4.7               3.2  ...      SET           0
# 3                  4.6               3.1  ...      SET           0
# 4                  5.0               3.6  ...      SET           0
# ..                 ...               ...  ...      ...         ...
# 145                6.7               3.0  ...      VER           1
# 146                6.3               2.5  ...      VER           1
# 147                6.5               3.0  ...      VER           1
# 148                6.2               3.4  ...      VER           1
# 149                5.9               3.0  ...      VER           1
#
# [150 rows x 6 columns]

# %%
# creating a new column via petal length & petal width
df['petal area'] = df.apply(lambda row: row['petal width (cm)'] * row['petal length (cm)'], axis=1)
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  wide petal  petal area
# 0                  5.1               3.5  ...           0        0.28
# 1                  4.9               3.0  ...           0        0.28
# 2                  4.7               3.2  ...           0        0.26
# 3                  4.6               3.1  ...           0        0.30
# 4                  5.0               3.6  ...           0        0.28
# ..                 ...               ...  ...         ...         ...
# 145                6.7               3.0  ...           1       11.96
# 146                6.3               2.5  ...           1        9.50
# 147                6.5               3.0  ...           1       10.40
# 148                6.2               3.4  ...           1       12.42
# 149                5.9               3.0  ...           1        9.18
#
# [150 rows x 7 columns]

# %%
# Getting the log values of all the data cells
df.applymap(lambda x: np.log(x) if isinstance(x, float) else x)
# Out:
#      sepal length (cm)  sepal width (cm)  ...  wide petal  petal area
# 0             1.629241          1.252763  ...           0   -1.272966
# 1             1.589235          1.098612  ...           0   -1.272966
# 2             1.547563          1.163151  ...           0   -1.347074
# 3             1.526056          1.131402  ...           0   -1.203973
# 4             1.609438          1.280934  ...           0   -1.272966
# ..                 ...               ...  ...         ...         ...
# 145           1.902108          1.098612  ...           1    2.481568
# 146           1.840550          0.916291  ...           1    2.251292
# 147           1.871802          1.098612  ...           1    2.341806
# 148           1.824549          1.223775  ...           1    2.519308
# 149           1.774952          1.098612  ...           1    2.217027
#
# [150 rows x 7 columns]

# %%
df.groupby('species').mean()
# Out:
#          sepal length (cm)  sepal width (cm)  ...  wide petal  petal area
# species                                       ...
# SET                  5.006             3.428  ...         0.0      0.3656
# VER                  6.588             2.974  ...         1.0     11.2962
# VIR                  5.936             2.770  ...         0.7      5.7204
#
# [3 rows x 6 columns]

# %%
# T for transpose
df.groupby('species').describe().T
# Out:
# species                        SET        VER        VIR
# sepal length (cm) count  50.000000  50.000000  50.000000
#                   mean    5.006000   6.588000   5.936000
#                   std     0.352490   0.635880   0.516171
#                   min     4.300000   4.900000   4.900000
#                   25%     4.800000   6.225000   5.600000
#                   50%     5.000000   6.500000   5.900000
#                   75%     5.200000   6.900000   6.300000
#                   max     5.800000   7.900000   7.000000
# sepal width (cm)  count  50.000000  50.000000  50.000000
#                   mean    3.428000   2.974000   2.770000
#                   std     0.379064   0.322497   0.313798
#                   min     2.300000   2.200000   2.000000
#                   25%     3.200000   2.800000   2.525000
#                   50%     3.400000   3.000000   2.800000
#                   75%     3.675000   3.175000   3.000000
#                   max     4.400000   3.800000   3.400000
# petal length (cm) count  50.000000  50.000000  50.000000
#                   mean    1.462000   5.552000   4.260000
#                   std     0.173664   0.551895   0.469911
#                   min     1.000000   4.500000   3.000000
#                   25%     1.400000   5.100000   4.000000
#                   50%     1.500000   5.550000   4.350000
#                   75%     1.575000   5.875000   4.600000
#                   max     1.900000   6.900000   5.100000
# petal width (cm)  count  50.000000  50.000000  50.000000
#                   mean    0.246000   2.026000   1.326000
#                   std     0.105386   0.274650   0.197753
#                   min     0.100000   1.400000   1.000000
#                   25%     0.200000   1.800000   1.200000
#                   50%     0.200000   2.000000   1.300000
#                   75%     0.300000   2.300000   1.500000
#                   max     0.600000   2.500000   1.800000
# wide petal        count  50.000000  50.000000  50.000000
#                   mean    0.000000   1.000000   0.700000
#                   std     0.000000   0.000000   0.462910
#                   min     0.000000   1.000000   0.000000
#                   25%     0.000000   1.000000   0.000000
#                   50%     0.000000   1.000000   1.000000
#                   75%     0.000000   1.000000   1.000000
#                   max     0.000000   1.000000   1.000000
# petal area        count  50.000000  50.000000  50.000000
#                   mean    0.365600  11.296200   5.720400
#                   std     0.181155   2.157412   1.368403
#                   min     0.110000   7.500000   3.300000
#                   25%     0.280000   9.717500   4.860000
#                   50%     0.300000  11.445000   5.615000
#                   75%     0.420000  12.790000   6.750000
#                   max     0.960000  15.870000   8.640000

# %%
# Group the classes by the petal width they are associated with
df.groupby('petal width (cm)')['species'].unique().to_frame()
# Out:
#                      species
# petal width (cm)
# 0.1                    [SET]
# 0.2                    [SET]
# 0.3                    [SET]
# 0.4                    [SET]
# 0.5                    [SET]
# 0.6                    [SET]
# 1.0                    [VIR]
# 1.1                    [VIR]
# 1.2                    [VIR]
# 1.3                    [VIR]
# 1.4               [VIR, VER]
# 1.5               [VIR, VER]
# 1.6               [VIR, VER]
# 1.7               [VIR, VER]
# 1.8               [VIR, VER]
# 1.9                    [VER]
# 2.0                    [VER]
# 2.1                    [VER]
# 2.2                    [VER]
# 2.3                    [VER]
# 2.4                    [VER]
# 2.5                    [VER]

# %%
df.groupby('species')['petal width (cm)'].agg(lambda x: x.max() - x.min())
# Out:
# species
# SET    0.5
# VER    1.1
# VIR    0.8
# Name: petal width (cm), dtype: float64

# %%
plt.figure(figsize=(7,7))
plt.scatter(df['sepal width (cm)'][:50], df['sepal length (cm)'][:50])
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.title('Setosa Sepal Width vs. Length', fontsize=14, y=1.02)
# Out:
# Text(0.5, 1.02, 'Setosa Sepal Width vs. Length')

# %%
import statsmodels.api as sm
y = df['sepal length (cm)'][:50]
x = df['sepal width (cm)'][:50]
X = sm.add_constant(x)
results = sm.OLS(y, X).fit()
results.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sepal length (cm)   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     58.99
# Date:                Sat, 13 Mar 2021   Prob (F-statistic):           6.71e-10
# Time:                        05:46:32   Log-Likelihood:                 1.7341
# No. Observations:                  50   AIC:                            0.5319
# Df Residuals:                      48   BIC:                             4.356
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.6390      0.310      8.513      0.000       2.016       3.262
# sepal width (cm)     0.6905      0.090      7.681      0.000       0.510       0.871
# ==============================================================================
# Omnibus:                        0.274   Durbin-Watson:                   2.542
# Prob(Omnibus):                  0.872   Jarque-Bera (JB):                0.464
# Skew:                          -0.041   Prob(JB):                        0.793
# Kurtosis:                       2.535   Cond. No.                         34.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(7,7))
plt.plot(x, results.fittedvalues, label='regression line', color='r')
plt.scatter(x, y, label='data point')
plt.ylabel('Sepal Length (cm)')
plt.xlabel('Sepal Width (cm)')
plt.title('Setosa Sepal Width vs. Sepal Length', fontsize=14,)
plt.legend(loc=0)

# %%
from sklearn.model_selection import train_test_split as tts
y = df.pop('species')
X_train, X_test, y_train, y_test = tts(df, y, test_size=.3)

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=5, n_estimators=10)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

rf = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
rf['correct'] = rf.apply(lambda x: 1 if x.predicted == x.actual else 0, axis=1)
rf
# Out:
#    predicted actual  correct
# 0        SET    SET        1
# 1        VER    VER        1
# 2        SET    SET        1
# 3        SET    SET        1
# 4        SET    SET        1
# 5        VIR    VIR        1
# 6        SET    SET        1
# 7        SET    SET        1
# 8        VER    VER        1
# 9        VIR    VIR        1
# 10       VER    VER        1
# 11       VIR    VIR        1
# 12       VIR    VER        0
# 13       VER    VER        1
# 14       VER    VER        1
# 15       VIR    VIR        1
# 16       VER    VER        1
# 17       SET    SET        1
# 18       SET    SET        1
# 19       SET    SET        1
# 20       VIR    VIR        1
# 21       VER    VER        1
# 22       VIR    VIR        1
# 23       VER    VER        1
# 24       VIR    VIR        1
# 25       VIR    VIR        1
# 26       VIR    VIR        1
# 27       SET    SET        1
# 28       VIR    VIR        1
# 29       VIR    VIR        1
# 30       VER    VER        1
# 31       VIR    VIR        1
# 32       SET    SET        1
# 33       VIR    VIR        1
# 34       VIR    VIR        1
# 35       VER    VER        1
# 36       VER    VER        1
# 37       SET    SET        1
# 38       VER    VER        1
# 39       SET    SET        1
# 40       SET    SET        1
# 41       VIR    VER        0
# 42       VER    VER        1
# 43       SET    SET        1
# 44       VER    VIR        0

# %%
# accuracy percentage
rf['correct'].sum() / rf['correct'].count()
# Out:
# 0.9333333333333333

# %%
# Feature Selection
f_names = df.columns
f_importances = clf.feature_importances_
f_std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)

zz = zip(f_names, f_importances, f_std)
zzs = sorted(zz, key=lambda x: x[1], reverse=True)

labels = [x[0] for x in zzs]
imps = [x[1] for x in zzs]
errs = [x[2] for x in zzs]

plt.figure(figsize=(10,4))
plt.bar(range(df.shape[1]), imps, color='r', yerr=errs, align='center')
plt.xticks(range(len(f_importances)), labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7ff354926c90>,
#   <matplotlib.axis.XTick at 0x7ff354926c50>,
#   <matplotlib.axis.XTick at 0x7ff354926810>,
#   <matplotlib.axis.XTick at 0x7ff3548dc710>,
#   <matplotlib.axis.XTick at 0x7ff3548e6450>,
#   <matplotlib.axis.XTick at 0x7ff3548e6990>],
#  [Text(0, 0, 'petal area'),
#   Text(0, 0, 'petal length (cm)'),
#   Text(0, 0, 'petal width (cm)'),
#   Text(0, 0, 'wide petal'),
#   Text(0, 0, 'sepal width (cm)'),
#   Text(0, 0, 'sepal length (cm)')])

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
clf = OneVsRestClassifier(SVC(kernel='linear'))

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

svc = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
svc['correct'] = svc.apply(lambda x: 1 if x.predicted == x.actual else 0, axis=1)
svc
# Out:
#    predicted actual  correct
# 0        SET    SET        1
# 1        VER    VER        1
# 2        SET    SET        1
# 3        SET    SET        1
# 4        SET    SET        1
# 5        VIR    VIR        1
# 6        SET    SET        1
# 7        SET    SET        1
# 8        VER    VER        1
# 9        VIR    VIR        1
# 10       VER    VER        1
# 11       VIR    VIR        1
# 12       VIR    VER        0
# 13       VER    VER        1
# 14       VER    VER        1
# 15       VIR    VIR        1
# 16       VER    VER        1
# 17       SET    SET        1
# 18       SET    SET        1
# 19       SET    SET        1
# 20       VIR    VIR        1
# 21       VER    VER        1
# 22       VIR    VIR        1
# 23       VER    VER        1
# 24       VIR    VIR        1
# 25       VIR    VIR        1
# 26       VIR    VIR        1
# 27       SET    SET        1
# 28       VIR    VIR        1
# 29       VIR    VIR        1
# 30       VER    VER        1
# 31       VIR    VIR        1
# 32       SET    SET        1
# 33       VIR    VIR        1
# 34       VIR    VIR        1
# 35       VER    VER        1
# 36       VER    VER        1
# 37       SET    SET        1
# 38       VER    VER        1
# 39       SET    SET        1
# 40       SET    SET        1
# 41       VER    VER        1
# 42       VER    VER        1
# 43       SET    SET        1
# 44       VER    VIR        0

# %%
svc['correct'].sum() / svc['correct'].count()
# Out:
# 0.9555555555555556
