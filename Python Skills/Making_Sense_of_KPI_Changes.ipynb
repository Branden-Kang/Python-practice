# %% [markdown]
# [Reference](https://miptgirl.medium.com/making-sense-of-kpi-changes-627e1f416803)

# %%
import pandas as pd
import numpy as np
import random
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

pio.templates.default = "simple_white"

# visualisations

def create_share_vs_impact_chart(df, dimension, share_field, impact_field):
    """
    Creates an interactive scatter plot chart using Plotly to compare the size of the segments vs its impact on the metric change

    Parameters:
    -----------
    df : pandas DataFrame
        Data containing share
    dimension : str
        Column name of the parameter/segment variable
    share_field : str
        Column name for the share of segment values
    impact_field : str
        Column name for the impact on the metric change values
    """
    plot_df = df.copy() # cloning df for manipulations
    plot_df['impact_norm'] = plot_df[impact_field]/plot_df[share_field]

    colorscale = px.colors.qualitative.D3
    fig = go.Figure()

    # Add scatter plot with conditional colors
    for i, row in plot_df.iterrows():
        marker_color = colorscale[2] if row['impact_norm'] > 1.5 else (colorscale[3] if row['impact_norm'] < -0.5 else colorscale[0])

        fig.add_trace(go.Scatter(
            x=[row[share_field]],
            y=[row[impact_field]],
            mode='markers',
            marker=dict(
                size=10,  # Larger marker size
                color=marker_color,
                opacity=0.75
            ),
            showlegend=False
        ))


    # Add the x=y reference line
    max_val = max(max(plot_df[share_field].values), max(plot_df[impact_field].values))
    min_val = min(min(plot_df[share_field].values), min(plot_df[impact_field].values))
    line_range = [min_val, max_val]

    fig.add_trace(
        go.Scatter(
            x=line_range,
            y=line_range,
            mode="lines",
            line=dict(dash="dash", color="gray", width=1.5),
        )
    )

    # Add annotations to the chart
    for i, row in plot_df.iterrows():
        fig.add_annotation(
            x=row[share_field],
            y=row[impact_field],
            text=f"{row[dimension]}",
            showarrow=False,
            xanchor='center',
            yanchor='bottom',
            font=dict(size=10),
            yshift=5,
        )

    # Show the plot
    fig.update_layout(
        title="<b>Metric change explained:</b> correlation between segment size and impact on the change",
        xaxis_title="Share of segment before, %",
        yaxis_title="Share in difference, %",
        template="simple_white",
        height=600,
        width=800,
        showlegend = False)
    fig.show()

def create_parallel_coordinates_chart(df, dimension, before_field='before',
                                      after_field='after', impact_norm_field = 'impact_norm', metric_name = '', show_mean = False):
    """
    Creates an interactive parallel coordinates chart using Plotly

    Parameters:
    -----------
    df : pandas DataFrame
        Data containing before/after values per segment
    dimension : str
        Column name of the parameter/segment variable
    before_field : str
        Column name for the 'before' values
    after_field : str
        Column name for the 'after' values
    impact_norm_field : str
        Column name for the normalised impact coefficient values (the ratio of impact to the segment size)
    """
    # Create a copy of the dataframe for manipulation
    plot_df = df.copy()
    plot_df = plot_df.sort_values(impact_norm_field, ascending = False)

    # Define color mapping for params
    dimensions = plot_df[dimension].unique()
    if df.shape[0] <= 10:
        colorscale = px.colors.qualitative.D3
    else:
        colorscale = px.colors.qualitative.Dark24
    colors = [colorscale[i % len(colorscale)] for i in range(len(dimensions))]
    color_map = dict(zip(dimensions, colors))
    plot_df['color'] = plot_df[dimension].map(color_map)

    # Create accents on meaningful changes using line width and opacity
    plot_df['line_width'] = plot_df[impact_norm_field].map(
        lambda x: 4 if (x > 1.5) or (x < -0.5) else 2
    )
    plot_df['opacity'] = plot_df[impact_norm_field].map(
        lambda x: 1 if (x > 1.5) or (x < -0.5) else 0.6
    )

    # Create the figure
    fig = go.Figure()

    if show_mean:
        # Calculate mean values for reference line
        mean_before = plot_df[before_field].mean()
        mean_after = plot_df[after_field].mean()

        # Add mean reference line
        fig.add_trace(
            go.Scatter(
                x=['BEFORE', 'AFTER'],
                y=[mean_before, mean_after],
                mode='lines',
                line=dict(color='gray', width=1.5, dash='dash'),
                opacity=0.7,
                name='Average',
                showlegend=False # remove from legend
            )
        )

    # Add lines for each parameter value
    for idx, row in plot_df.iterrows():
        fig.add_trace(
            go.Scatter(
                x=['BEFORE', 'AFTER'],
                y=[row[before_field], row[after_field]],
                mode='lines+markers',
                line=dict(
                    color=row['color'],
                    width=row['line_width']
                ),
                opacity=row['opacity'],
                name=f"{row[dimension]}",
                marker=dict(size=8),
            )
        )

    # Update layout
    if metric_name != '':
        metric_title = ', ' + metric_name
    else:
        metric_title = ''
    fig.update_layout(
        title= '<b>Metric change explained:</b> before vs after' + metric_title,
        xaxis=dict(
            showgrid=False,
            tickfont=dict(size=12, weight='bold')
        ),
        yaxis=dict(
            title='Value',
            showgrid=True,
            gridcolor='rgba(211, 211, 211, 0.7)',
            gridwidth=1,
            tickformat='.0s'  # Automatically format large numbers (K, M)
        ),
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=-0.25,
            xanchor='center',
            x=0.5,
            font=dict(size=10)
        ),
        plot_bgcolor='white',
        width=800,
        height=600,
        margin=dict(l=60, r=30, t=80, b=120)
    )

    fig.show()

def hex_to_rgba(hex_color, alpha=None):
    hex_color = hex_color.lstrip('#')
    rgb = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
    if alpha is not None:
        return f"rgba({rgb[0]}, {rgb[1]}, {rgb[2]}, {alpha})"
    else:
        return f"rgb({rgb[0]}, {rgb[1]}, {rgb[2]})"

def plot_conversion_waterfall(rate_before, rate_after, df, add_other = True):
    """
    Creates a waterfall chart showing contribution of dimension effects to conversion change.

    Parameters:
    -----------
    rate_before : float
        Initial conversion rate
    rate_after : float
        Final conversion rate
    df : pandas DataFrame
        DataFrame indexed by dimensions, with a column "effect" showing contribution
    """

    plot_df = df.copy()
    plot_df = plot_df[plot_df.effect != 0] # filtering out segments without effect
    plot_df = plot_df.sort_values('effect', ascending = False)
    colorscale = px.colors.qualitative.D3

    # Build the waterfall steps
    dimensions = plot_df.index.tolist()
    effects = plot_df["effect"].tolist()


    base = rate_before
    total_effect = sum(effects)
    remaining_effect = (rate_after - rate_before) - total_effect

    if add_other:
        if abs(remaining_effect) >= 0.1:
            dimensions.append('remaining effects')
            effects.append(remaining_effect)
        total_effect = sum(effects)

    # Add starting point
    x = ["Before"] + dimensions + ["After"]
    y = [rate_before] + effects + [rate_after - (rate_before + total_effect)]

    measures = ["absolute"] + ["relative"] * len(dimensions) + ["total"]

    fig = go.Figure(go.Waterfall(
        name="Conversion",
        orientation="v",
        measure=measures,
        textposition="outside",
        x=x,
        y=y,
        text= ['%.1f%%' % rate_before] + list(map(lambda x: '+%.1f%%' % x if x > 0 else '%.1f%%' % x, effects)) + ['%.1f%%' % rate_after],
        connector={"line": {"color": "gray"}},
        increasing={"marker": {"color": hex_to_rgba(colorscale[2], 0.7)}},
        decreasing={"marker": {"color": hex_to_rgba(colorscale[3], 0.7)}},
        totals={"marker": {"color": hex_to_rgba(colorscale[0], 0.7)}}
    ))

    fig.update_layout(
        title="<b>Conversion rate change explained</b>",
        yaxis_title="conversion, %",
        waterfallgap=0.4,
        margin=dict(t=100)
    )

    plot_df = plot_df.sort_values('effect', ascending = False)
    plot_df['cum_effect'] = plot_df.effect.cumsum()
    max_val = max([rate_before, rate_after, rate_before + plot_df['cum_effect'].max()]) + 10

    # max_val = rate_before + plot_df['cum_effect'].max() + 10  # adjust buffer
    fig.update_yaxes(range=[0, max_val])

    fig.show()

# analysis

def calculate_simple_growth_metrics(stats_df):
    """
    Analyses the change of simple metrics before and after

    Parameters:
    -----------
    df : pandas DataFrame
        Data containing before/after values per segment:
            - dimension is in index;
            - data frame has columns "before" and "after"
    """

    # Calculating overall stats
    before = stats_df.before.sum()
    after = stats_df.after.sum()
    print('Metric change: %.2f -> %.2f (%.2f%%)' % (before, after, 100*(after - before)/before))

    # Estimating impact of each segment
    stats_df['difference'] = stats_df.after - stats_df.before
    stats_df['difference_rate'] = (100*stats_df.difference/stats_df.before).map(lambda x: round(x, 2))
    stats_df['impact'] = (100*stats_df.difference / stats_df.difference.sum()).map(lambda x: round(x, 2))
    stats_df['segment_share_before'] = (100* stats_df.before / stats_df.before.sum()).map(lambda x: round(x, 2))
    stats_df['impact_norm'] = (stats_df.impact/stats_df.segment_share_before).map(lambda x: round(x, 2))
    # stats_df['abs_impact_norm'] = stats_df.impact_norm.map(abs)

    # Sorting based on the impact normed on the size
    # stats_df = stats_df.sort_values('abs_impact_norm', ascending = False)
    # stats_df = stats_df.drop('abs_impact_norm', axis = 1)

    # Creating visualisations
    create_parallel_coordinates_chart(stats_df.reset_index(), stats_df.index.name)
    create_share_vs_impact_chart(stats_df.reset_index(), stats_df.index.name, 'segment_share_before', 'impact')

    return stats_df.sort_values('impact_norm', ascending = False)

def calculate_conversion_effects(df, dimension, numerator_field1, denominator_field1,
                       numerator_field2, denominator_field2):
    """
    Analyses the change of conversion metrics before and after

    Parameters:
    -----------
    df : pandas DataFrame
        Data containing before/after values per segment
    dimension : str
        Column name of the parameter/segment variable
    numerator_field1: str
        Column name of the numerator field before
    denominator_field1: str
        Column name of the denominator field before
    numerator_field2: str
        Column name of the numerator field after
    denominator_field2: str
        Column name of the denominator field after
    """

    cmp_df = df.groupby(dimension)[[numerator_field1, denominator_field1, numerator_field2, denominator_field2]].sum()
    cmp_df = cmp_df.rename(columns = {
        numerator_field1: 'c1',
        numerator_field2: 'c2',
        denominator_field1: 't1',
        denominator_field2: 't2'
    })

    cmp_df['conversion_before'] = cmp_df['c1']/cmp_df['t1']
    cmp_df['conversion_after'] = cmp_df['c2']/cmp_df['t2']

    C1 = cmp_df['c1'].sum()
    T1 = cmp_df['t1'].sum()
    C2 = cmp_df['c2'].sum()
    T2 = cmp_df['t2'].sum()

    print('conversion before = %.2f' % (100*C1/T1))
    print('conversion after = %.2f' % (100*C2/T2))
    print('total conversion change = %.2f' % (100*(C2/T2 - C1/T1)))

    cmp_df['dt'] = (T1*cmp_df.t2 - T2*cmp_df.t1)/(T2 - cmp_df.t2)
    cmp_df['total_effect'] = (C1 - cmp_df.c1 + (cmp_df.t1 + cmp_df.dt)*cmp_df.conversion_after)/(T1 + cmp_df.dt) - C1/T1
    cmp_df['mix_change_effect'] = (C1 + cmp_df.dt*cmp_df.conversion_before)/(T1 + cmp_df.dt) - C1/T1
    cmp_df['conversion_change_effect'] = (cmp_df.t1*cmp_df.c2 - cmp_df.t2*cmp_df.c1)/(T1 * cmp_df.t2)

    for col in ['total_effect', 'mix_change_effect', 'conversion_change_effect', 'conversion_before', 'conversion_after']:
        cmp_df[col] = 100*cmp_df[col]

    cmp_df['conversion_diff'] = cmp_df.conversion_after - cmp_df.conversion_before
    cmp_df['before_segment_share'] = 100*cmp_df.t1/T1
    cmp_df['after_segment_share'] = 100*cmp_df.t2/T2
    for p in ['before_segment_share', 'after_segment_share', 'conversion_before', 'conversion_after', 'conversion_diff',
                     'total_effect', 'mix_change_effect', 'conversion_change_effect']:
        cmp_df[p] = cmp_df[p].map(lambda x: round(x, 2))
    cmp_df['total_effect_share'] = (100*cmp_df.total_effect/(100*(C2/T2 - C1/T1))).map(lambda x: round(x, 2))
    cmp_df['impact_norm'] = cmp_df.total_effect_share/cmp_df.before_segment_share

    # creating visualisations
    create_share_vs_impact_chart(cmp_df.reset_index(), dimension, 'before_segment_share', 'total_effect_share')
    cmp_df = cmp_df[['before_segment_share', 'after_segment_share', 'conversion_before', 'conversion_after', 'conversion_diff',
                     'total_effect', 'mix_change_effect', 'conversion_change_effect', 'total_effect_share', 'impact_norm']]
    cmp_df = cmp_df.sort_values('total_effect', ascending = False)

    # return cmp_df[['total_effect']].rename(columns = {'total_effect': 'effect'})
    plot_conversion_waterfall(
        100*C1/T1, 100*C2/T2, cmp_df[['total_effect']].rename(columns = {'total_effect': 'effect'})
    )

    # putting together effects split by change of mix and conversion change
    tmp = []
    for rec in cmp_df.reset_index().to_dict('records'):
        tmp.append(
            {
                'segment': rec[dimension] + ' - change of mix',
                'effect': rec['mix_change_effect']
            }
        )
        tmp.append(
            {
                'segment': rec[dimension] + ' - conversion change',
                'effect': rec['conversion_change_effect']
            }
        )
    effects_det_df = pd.DataFrame(tmp)
    effects_det_df['effect_abs'] = effects_det_df.effect.map(lambda x: abs(x))
    effects_det_df = effects_det_df.sort_values('effect_abs', ascending = False)
    top_effects_det_df = effects_det_df.head(5).drop('effect_abs', axis = 1)
    plot_conversion_waterfall(
        100*C1/T1, 100*C2/T2, top_effects_det_df.set_index('segment'),
        add_other = True
    )

    create_parallel_coordinates_chart(cmp_df.reset_index(), dimension, before_field='before_segment_share',
                                      after_field='after_segment_share', impact_norm_field = 'impact_norm', metric_name = 'share of segment',
                                     show_mean = False)
    create_parallel_coordinates_chart(cmp_df.reset_index(), dimension, before_field='conversion_before',
                                      after_field='conversion_after', impact_norm_field = 'impact_norm', metric_name = 'conversion',
                                      show_mean = False)
    return cmp_df.rename(columns = {'before_segment_share': 'before_seg_share', 'after_segment_share': 'after_seg_share',
                                   'conversion_before': 'conv_before', 'conversion_after': 'conv_after',
                                   'conversion_diff': 'conv_diff', 'conversion_change_effect': 'conv_change_effect'}).drop('impact_norm', axis = 1)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/miptgirl/miptgirl_medium/refs/heads/main/growth_narrative_llm_agent/absolute_metrics_example.csv', sep = '\t')
df.head()
# Out:
#    country  maturity  revenue_before  revenue_after_scenario_1  \
# 0       UK       new       128324.22                  34838.87
# 1       UK  existing       353085.05                 298405.57
# 2   France       new        57901.91                  17443.06
# 3   France  existing       182802.72                 143202.12
# 4  Germany       new        48105.83                  13678.94
#
#    revenue_after_scenario_2  revenue_after_scenario_3
# 0                 127304.87                 127304.87
# 1                 349728.15                 349728.15
# 2                  57673.79                  57673.79
# 3                  50183.27                  50183.27
# 4                  47795.22                  47795.22

# %% [markdown]
# # Revenue

# %%
calculate_simple_growth_metrics(
  df.groupby('country')[['revenue_before', 'revenue_after_scenario_1']].sum()\
    .sort_values('revenue_before', ascending = False).rename(
        columns = {'revenue_after_scenario_1': 'after',
          'revenue_before': 'before'}
    )
)
# Out:
# Metric change: 1731985.21 -> 1107924.43 (-36.03%)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="af9c0b02-0c1d-4104-922f-a3a27a4f3f8b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af9c0b02-0c1d-4104-922f-a3a27a4f3f8b")) {                    Plotly.newPlot(                        "af9c0b02-0c1d-4104-922f-a3a27a4f3f8b",                        [{"line":{"color":"#1F77B4","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":0.6,"x":["BEFORE","AFTER"],"y":[96281.86,55061.020000000004],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":0.6,"x":["BEFORE","AFTER"],"y":[120352.31,71306.70999999999],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[632767.39,381711.22000000003],"type":"scatter"},{"line":{"color":"#D62728","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":0.6,"x":["BEFORE","AFTER"],"y":[160469.75,105955.86],"type":"scatter"},{"line":{"color":"#9467BD","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":0.6,"x":["BEFORE","AFTER"],"y":[240704.63,160645.18],"type":"scatter"},{"line":{"color":"#8C564B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":0.6,"x":["BEFORE","AFTER"],"y":[481409.27,333244.44],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surfac ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fcdcb448-b1a0-42eb-a6eb-a3f797a2fdf2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcdcb448-b1a0-42eb-a6eb-a3f797a2fdf2")) {                    Plotly.newPlot(                        "fcdcb448-b1a0-42eb-a6eb-a3f797a2fdf2",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[36.53],"y":[40.23],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[27.8],"y":[23.74],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.9],"y":[12.83],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[9.27],"y":[8.74],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.95],"y":[7.86],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[5.56],"y":[6.61],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[5.56,40.23],"y":[5.56,40.23],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.33333 ...
#             before      after  difference  difference_rate  impact  \
# country
# Spain     96281.86   55061.02   -41220.84           -42.81    6.61
# Italy    120352.31   71306.71   -49045.60           -40.75    7.86
# other    632767.39  381711.22  -251056.17           -39.68   40.23
# Germany  160469.75  105955.86   -54513.89           -33.97    8.74
# France   240704.63  160645.18   -80059.45           -33.26   12.83
# UK       481409.27  333244.44  -148164.83           -30.78   23.74
#
#          segment_share_before  impact_norm
# country
# Spain                    5.56         1.19
# Italy                    6.95         1.13
# other                   36.53         1.10
# Germany                  9.27         0.94
# France                  13.90         0.92
# UK                      27.80         0.85

# %%
calculate_simple_growth_metrics(
    df.groupby('country')[['revenue_before', 'revenue_after_scenario_2']].sum()\
        .sort_values('revenue_before', ascending = False).rename(
            columns = {'revenue_after_scenario_2': 'after', 'revenue_before': 'before'}
        )
)
# Out:
# Metric change: 1731985.21 -> 1599065.55 (-7.67%)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="65e6adda-186e-4ef8-92a3-0ca1fe4b8705" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65e6adda-186e-4ef8-92a3-0ca1fe4b8705")) {                    Plotly.newPlot(                        "65e6adda-186e-4ef8-92a3-0ca1fe4b8705",                        [{"line":{"color":"#1F77B4","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":1.0,"x":["BEFORE","AFTER"],"y":[240704.63,107857.06],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":0.6,"x":["BEFORE","AFTER"],"y":[481409.27,477033.02],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":0.6,"x":["BEFORE","AFTER"],"y":[160469.75,159778.76],"type":"scatter"},{"line":{"color":"#D62728","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":0.6,"x":["BEFORE","AFTER"],"y":[96281.86,96064.76999999999],"type":"scatter"},{"line":{"color":"#9467BD","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[632767.39,637000.48],"type":"scatter"},{"line":{"color":"#8C564B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":0.6,"x":["BEFORE","AFTER"],"y":[120352.31,121331.46],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"ou ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="367e3d89-62d9-4433-8ebd-b5ff5c09054e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("367e3d89-62d9-4433-8ebd-b5ff5c09054e")) {                    Plotly.newPlot(                        "367e3d89-62d9-4433-8ebd-b5ff5c09054e",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[36.53],"y":[-3.18],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[27.8],"y":[3.29],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.9],"y":[99.95],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[9.27],"y":[0.52],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.95],"y":[-0.74],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[5.56],"y":[0.16],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[-3.18,99.95],"y":[-3.18,99.95],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.333 ...
#             before      after  difference  difference_rate  impact  \
# country
# France   240704.63  107857.06  -132847.57           -55.19   99.95
# UK       481409.27  477033.02    -4376.25            -0.91    3.29
# Germany  160469.75  159778.76     -690.99            -0.43    0.52
# Spain     96281.86   96064.77     -217.09            -0.23    0.16
# other    632767.39  637000.48     4233.09             0.67   -3.18
# Italy    120352.31  121331.46      979.15             0.81   -0.74
#
#          segment_share_before  impact_norm
# country
# France                  13.90         7.19
# UK                      27.80         0.12
# Germany                  9.27         0.06
# Spain                    5.56         0.03
# other                   36.53        -0.09
# Italy                    6.95        -0.11

# %%
calculate_simple_growth_metrics(
    df.groupby('country')[['revenue_before', 'revenue_after_scenario_3']].sum()\
        .sort_values('revenue_before', ascending = False).rename(
            columns = {'revenue_after_scenario_3': 'after', 'revenue_before': 'before'}
        )
)
# Out:
# Metric change: 1731985.21 -> 1665375.27 (-3.85%)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cde8cf58-05da-4c25-9f1a-ce4ae0530335" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cde8cf58-05da-4c25-9f1a-ce4ae0530335")) {                    Plotly.newPlot(                        "cde8cf58-05da-4c25-9f1a-ce4ae0530335",                        [{"line":{"color":"#1F77B4","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":1.0,"x":["BEFORE","AFTER"],"y":[240704.63,107857.06],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":0.6,"x":["BEFORE","AFTER"],"y":[481409.27,477033.02],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":0.6,"x":["BEFORE","AFTER"],"y":[160469.75,159778.76],"type":"scatter"},{"line":{"color":"#D62728","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[632767.39,637000.48],"type":"scatter"},{"line":{"color":"#9467BD","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":0.6,"x":["BEFORE","AFTER"],"y":[120352.31,121331.46],"type":"scatter"},{"line":{"color":"#8C564B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":1.0,"x":["BEFORE","AFTER"],"y":[96281.86,162374.495],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="29992463-6624-4ea4-8858-26d04d2f73a5" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29992463-6624-4ea4-8858-26d04d2f73a5")) {                    Plotly.newPlot(                        "29992463-6624-4ea4-8858-26d04d2f73a5",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[36.53],"y":[-6.36],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[27.8],"y":[6.57],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.9],"y":[199.44],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[9.27],"y":[1.04],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.95],"y":[-1.47],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[5.56],"y":[-99.22],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[-99.22,199.44],"y":[-99.22,199.44],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"] ...
#             before       after  difference  difference_rate  impact  \
# country
# France   240704.63  107857.060 -132847.570           -55.19  199.44
# UK       481409.27  477033.020   -4376.250            -0.91    6.57
# Germany  160469.75  159778.760    -690.990            -0.43    1.04
# other    632767.39  637000.480    4233.090             0.67   -6.36
# Italy    120352.31  121331.460     979.150             0.81   -1.47
# Spain     96281.86  162374.495   66092.635            68.64  -99.22
#
#          segment_share_before  impact_norm
# country
# France                  13.90        14.35
# UK                      27.80         0.24
# Germany                  9.27         0.11
# other                   36.53        -0.17
# Italy                    6.95        -0.21
# Spain                    5.56       -17.85

# %%
df['segment'] = df.country + ' - ' + df.maturity

# %%
calculate_simple_growth_metrics(
    df.groupby(['segment'])[['revenue_before', 'revenue_after_scenario_1']].sum()\
        .sort_values('revenue_before', ascending = False).rename(
            columns = {'revenue_after_scenario_1': 'after', 'revenue_before': 'before'}
        )
)
# Out:
# Metric change: 1731985.21 -> 1107924.43 (-36.03%)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="884f1719-f459-4c5a-ae1b-770bf3d77bde" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("884f1719-f459-4c5a-ae1b-770bf3d77bde")) {                    Plotly.newPlot(                        "884f1719-f459-4c5a-ae1b-770bf3d77bde",                        [{"line":{"color":"#2E91E5","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[32394.1,7758.9],"type":"scatter"},{"line":{"color":"#E15F99","width":4},"marker":{"size":8},"mode":"lines+markers","name":"UK - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[128324.22,34838.87],"type":"scatter"},{"line":{"color":"#1CA71C","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Germany - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[48105.83,13678.94],"type":"scatter"},{"line":{"color":"#FB0D0D","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[57901.91,17443.06],"type":"scatter"},{"line":{"color":"#DA16FF","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Italy - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[36941.57,11615.29],"type":"scatter"},{"line":{"color":"#222A2A","width":4},"marker":{"size":8},"mode":"lines+markers","name":"other - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[233958.42,72666.89],"type":"scatter"},{"line":{"color":"#B68100","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[83410.74,59691.42],"type":"scatter"},{"line":{"color":"#750D86","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[63887.76,47302.12],"type":"scatter"},{"line":{"color":"#EB663B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[398808.97,309044.33],"type":"scatter"},{"line":{"color":"#511CFB","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[182802.72,143202.12],"type":"scatter"},{"line":{"color":"#00A08B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[112363.92,92276.92],"type":"scatter"},{"line":{"color":"#FB00D1","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[353085.05,298405.57],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2433c78a-9fea-4dbf-b68c-d7d4f1c85964" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2433c78a-9fea-4dbf-b68c-d7d4f1c85964")) {                    Plotly.newPlot(                        "2433c78a-9fea-4dbf-b68c-d7d4f1c85964",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[23.03],"y":[14.38],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[20.39],"y":[8.76],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.51],"y":[25.85],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[10.55],"y":[6.35],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[7.41],"y":[14.98],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.49],"y":[3.22],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[4.82],"y":[3.8],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.69],"y":[2.66],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.34],"y":[6.48],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[2.78],"y":[5.52],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[2.13],"y":[4.06],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[1.87],"y":[3.95],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[1.87,25.85],"y":[1.87,25.85],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778 ...
#                        before      after  difference  difference_rate  impact  \
# segment
# Spain - new          32394.10    7758.90   -24635.20           -76.05    3.95
# UK - new            128324.22   34838.87   -93485.35           -72.85   14.98
# Germany - new        48105.83   13678.94   -34426.89           -71.56    5.52
# France - new         57901.91   17443.06   -40458.85           -69.87    6.48
# Italy - new          36941.57   11615.29   -25326.28           -68.56    4.06
# other - new         233958.42   72666.89  -161291.53           -68.94   25.85
# Italy - existing     83410.74   59691.42   -23719.32           -28.44    3.80
# Spain - existing     63887.76   47302.12   -16585.64           -25.96    2.66
# other - existing    398808.97  309044.33   -89764.64           -22.51   14.38
# France - existing   182802.72  143202.12   -39600.60           -21.66    6.35
# Germany - existing  112363.92   92276.92   -20087.00           -17.88    3.22
# UK - existing       353085.05  298405.57   -54679.48           -15.49    8.76
#
#                     segment_share_before  impact_norm
# segment
# Spain - new                         1.87         2.11
# UK - new                            7.41         2.02
# Germany - new                       2.78         1.99
# France - new                        3.34         1.94
# Italy - new                         2.13         1.91
# other - new                        13.51         1.91
# Italy - existing                    4.82         0.79
# Spain - existing                    3.69         0.72
# other - existing                   23.03         0.62
# France - existing                  10.55         0.60
# Germany - existing                  6.49         0.50
# UK - existing                      20.39         0.43

# %%
calculate_simple_growth_metrics(
    df.groupby(['segment'])[['revenue_before', 'revenue_after_scenario_3']].sum()\
        .sort_values('revenue_before', ascending = False).rename(
            columns = {'revenue_after_scenario_3': 'after', 'revenue_before': 'before'}
        )
)
# Out:
# Metric change: 1731985.21 -> 1665375.27 (-3.85%)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="882afb70-5d02-4097-9e5f-b4255e4f80c1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("882afb70-5d02-4097-9e5f-b4255e4f80c1")) {                    Plotly.newPlot(                        "882afb70-5d02-4097-9e5f-b4255e4f80c1",                        [{"line":{"color":"#2E91E5","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France - existing","opacity":1.0,"x":["BEFORE","AFTER"],"y":[182802.72,50183.27],"type":"scatter"},{"line":{"color":"#E15F99","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[353085.05,349728.15],"type":"scatter"},{"line":{"color":"#1CA71C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[128324.22,127304.87],"type":"scatter"},{"line":{"color":"#FB0D0D","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[48105.83,47795.22],"type":"scatter"},{"line":{"color":"#DA16FF","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[57901.91,57673.79],"type":"scatter"},{"line":{"color":"#222A2A","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[112363.92,111983.54],"type":"scatter"},{"line":{"color":"#B68100","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[36941.57,36893.3],"type":"scatter"},{"line":{"color":"#750D86","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[233958.42,235306.99],"type":"scatter"},{"line":{"color":"#EB663B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[398808.97,401693.49],"type":"scatter"},{"line":{"color":"#511CFB","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain - new","opacity":0.6,"x":["BEFORE","AFTER"],"y":[32394.1,32674.67],"type":"scatter"},{"line":{"color":"#00A08B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[83410.74,84438.16],"type":"scatter"},{"line":{"color":"#FB00D1","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain - existing","opacity":1.0,"x":["BEFORE","AFTER"],"y":[63887.76,129699.825],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5071e95d-2f95-413e-8d74-6955b2eca35e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5071e95d-2f95-413e-8d74-6955b2eca35e")) {                    Plotly.newPlot(                        "5071e95d-2f95-413e-8d74-6955b2eca35e",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[23.03],"y":[-4.33],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[20.39],"y":[5.04],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.51],"y":[-2.02],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[10.55],"y":[199.1],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[7.41],"y":[1.53],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.49],"y":[0.57],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[4.82],"y":[-1.54],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.69],"y":[-98.8],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.34],"y":[0.34],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[2.78],"y":[0.47],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[2.13],"y":[0.07],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[1.87],"y":[-0.42],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[-98.8,199.1],"y":[-98.8,199.1],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777 ...
#                        before       after  difference  difference_rate  \
# segment
# France - existing   182802.72   50183.270 -132619.450           -72.55
# UK - existing       353085.05  349728.150   -3356.900            -0.95
# UK - new            128324.22  127304.870   -1019.350            -0.79
# Germany - new        48105.83   47795.220    -310.610            -0.65
# France - new         57901.91   57673.790    -228.120            -0.39
# Germany - existing  112363.92  111983.540    -380.380            -0.34
# Italy - new          36941.57   36893.300     -48.270            -0.13
# other - new         233958.42  235306.990    1348.570             0.58
# other - existing    398808.97  401693.490    2884.520             0.72
# Spain - new          32394.10   32674.670     280.570             0.87
# Italy - existing     83410.74   84438.160    1027.420             1.23
# Spain - existing     63887.76  129699.825   65812.065           103.01
#
#                     impact  segment_share_before  impact_norm
# segment
# France - existing   199.10                 10.55        18.87
# UK - existing         5.04                 20.39         0.25
# UK - new              1.53                  7.41         0.21
# Germany - new         0.47                  2.78         0.17
# France - new          0.34                  3.34         0.10
# Germany - existing    0.57                  6.49         0.09
# Italy - new           0.07                  2.13         0.03
# other - new          -2.02                 13.51        -0.15
# other - existing     -4.33                 23.03        -0.19
# Spain - new          -0.42                  1.87        -0.22
# Italy - existing     -1.54                  4.82        -0.32
# Spain - existing    -98.80                  3.69       -26.78

# %% [markdown]
# # Conversion

# %%
conv_df = pd.read_csv('https://raw.githubusercontent.com/miptgirl/miptgirl_medium/refs/heads/main/growth_narrative_llm_agent/conversion_metrics_example.csv', sep = '\t')
conv_df.head()
# Out:
#    country  maturity  users_before  converted_users_before  \
# 0       UK       new          8327                     863
# 1       UK  existing         18417                   14154
# 2   France       new          3621                     177
# 3   France  existing          9750                    7693
# 4  Germany       new          2452                     162
#
#    users_after_scenario_1  converted_users_after_scenario_1  \
# 0                    8733                              2592
# 1                   18636                             14246
# 2                    3675                               943
# 3                    9633                              7652
# 4                    2507                               640
#
#    users_after_scenario_2  converted_users_after_scenario_2
# 0                   87318                             16756
# 1                   18636                             16125
# 2                    3675                               477
# 3                    9633                              8675
# 4                    2507                               409

# %%
calculate_conversion_effects(
    conv_df, 'country', 'converted_users_before', 'users_before',
    'converted_users_after_scenario_1', 'users_after_scenario_1',
)
# Out:
# conversion before = 55.62
# conversion after = 61.41
# total conversion change = 5.80
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="59c5d3d0-c177-452f-99f7-7b45b9f601df" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59c5d3d0-c177-452f-99f7-7b45b9f601df")) {                    Plotly.newPlot(                        "59c5d3d0-c177-452f-99f7-7b45b9f601df",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.9],"y":[13.46],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[9.26],"y":[8.63],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.95],"y":[9.83],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[5.56],"y":[5.0],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[27.8],"y":[26.4],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[36.54],"y":[36.58],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[5.0,36.58],"y":[5.0,36.58],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.333333333 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a3a2d10f-c705-41af-9b5f-4dbe0c804d14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a2d10f-c705-41af-9b5f-4dbe0c804d14")) {                    Plotly.newPlot(                        "a3a2d10f-c705-41af-9b5f-4dbe0c804d14",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+2.1%","+1.5%","+0.8%","+0.6%","+0.5%","+0.3%","61.4%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other","UK","France","Italy","Germany","Spain","After"],"y":[55.61502884165671,2.12,1.53,0.78,0.57,0.5,0.29,0.0062021793263653535],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="75a12682-39ff-4678-a935-aef6e093ec9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75a12682-39ff-4678-a935-aef6e093ec9e")) {                    Plotly.newPlot(                        "75a12682-39ff-4678-a935-aef6e093ec9e",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+2.1%","+1.5%","+0.8%","+0.6%","+0.5%","+0.3%","61.4%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other - conversion change","UK - conversion change","France - conversion change","Italy - conversion change","Germany - conversion change","remaining effects","After"],"y":[55.61502884165671,2.14,1.49,0.8,0.55,0.5,0.31620217932636496,0.0],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde7 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="846b0096-8cb4-4d28-bc1e-c568db4420d3" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("846b0096-8cb4-4d28-bc1e-c568db4420d3")) {                    Plotly.newPlot(                        "846b0096-8cb4-4d28-bc1e-c568db4420d3",                        [{"line":{"color":"#1F77B4","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":0.6,"x":["BEFORE","AFTER"],"y":[6.95,6.64],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[36.54,36.33],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":0.6,"x":["BEFORE","AFTER"],"y":[13.9,13.78],"type":"scatter"},{"line":{"color":"#D62728","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":0.6,"x":["BEFORE","AFTER"],"y":[27.8,28.35],"type":"scatter"},{"line":{"color":"#9467BD","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":0.6,"x":["BEFORE","AFTER"],"y":[9.26,9.25],"type":"scatter"},{"line":{"color":"#8C564B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":0.6,"x":["BEFORE","AFTER"],"y":[5.56,5.65],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="af026394-22cb-496e-82bd-463d36693c93" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af026394-22cb-496e-82bd-463d36693c93")) {                    Plotly.newPlot(                        "af026394-22cb-496e-82bd-463d36693c93",                        [{"line":{"color":"#1F77B4","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":0.6,"x":["BEFORE","AFTER"],"y":[42.24,50.16],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[59.31,65.18],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":0.6,"x":["BEFORE","AFTER"],"y":[58.86,64.59],"type":"scatter"},{"line":{"color":"#D62728","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":0.6,"x":["BEFORE","AFTER"],"y":[56.15,61.52],"type":"scatter"},{"line":{"color":"#9467BD","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":0.6,"x":["BEFORE","AFTER"],"y":[46.22,51.6],"type":"scatter"},{"line":{"color":"#8C564B","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":0.6,"x":["BEFORE","AFTER"],"y":[52.92,58.18],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outsi ...
#          before_seg_share  after_seg_share  conv_before  conv_after  \
# country
# other               36.54            36.33        59.31       65.18
# UK                  27.80            28.35        56.15       61.52
# France              13.90            13.78        58.86       64.59
# Italy                6.95             6.64        42.24       50.16
# Germany              9.26             9.25        46.22       51.60
# Spain                5.56             5.65        52.92       58.18
#
#          conv_diff  total_effect  mix_change_effect  conv_change_effect  \
# country
# other         5.87          2.12              -0.01                2.14
# UK            5.37          1.53               0.00                1.49
# France        5.73          0.78              -0.00                0.80
# Italy         7.92          0.57               0.04                0.55
# Germany       5.38          0.50               0.00                0.50
# Spain         5.26          0.29              -0.00                0.29
#
#          total_effect_share
# country
# other                 36.58
# UK                    26.40
# France                13.46
# Italy                  9.83
# Germany                8.63
# Spain                  5.00

# %%
conv_df.groupby('country').sum().sum()
# Out:
# maturity                            newexistingnewexistingnewexistingnewexistingne...
# users_before                                                                    96215
# converted_users_before                                                          53510
# users_after_scenario_1                                                          96554
# converted_users_after_scenario_1                                                59295
# users_after_scenario_2                                                         175139
# converted_users_after_scenario_2                                                78319
# dtype: object

# %%
calculate_conversion_effects(
    conv_df, 'country', 'converted_users_before', 'users_before',
    'converted_users_after_scenario_2', 'users_after_scenario_2'
)
# Out:
# conversion before = 55.62
# conversion after = 44.72
# total conversion change = -10.90
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ab7992b2-649a-4ee5-8af0-e293bb1f9190" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab7992b2-649a-4ee5-8af0-e293bb1f9190")) {                    Plotly.newPlot(                        "ab7992b2-649a-4ee5-8af0-e293bb1f9190",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[13.9],"y":[-4.77],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[9.26],"y":[-8.9],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.95],"y":[-7.16],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[5.56],"y":[-3.3],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[27.8],"y":[137.2],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[36.54],"y":[-10.92],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[-10.92,137.2],"y":[-10.92,137.2],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0f289d2b-07f8-45b7-a54a-aa080f1d4246" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f289d2b-07f8-45b7-a54a-aa080f1d4246")) {                    Plotly.newPlot(                        "0f289d2b-07f8-45b7-a54a-aa080f1d4246",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+1.2%","+1.0%","+0.8%","+0.5%","+0.4%","-14.9%","+0.2%","44.7%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other","Germany","Italy","France","Spain","UK","remaining effects","After"],"y":[55.61502884165671,1.19,0.97,0.78,0.52,0.36,-14.95,0.23316642039229052,0.0],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":1 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a475952b-24a3-4308-9280-0395d55b0b24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a475952b-24a3-4308-9280-0395d55b0b24")) {                    Plotly.newPlot(                        "a475952b-24a3-4308-9280-0395d55b0b24",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+3.9%","+1.4%","+1.0%","-1.0%","-7.0%","-9.2%","44.7%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other - conversion change","France - conversion change","Germany - conversion change","other - change of mix","UK - conversion change","remaining effects","After"],"y":[55.61502884165671,3.92,1.38,0.98,-0.96,-6.98,-9.236833579607708,0.0],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde72 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97992326-bfa0-4c9c-824a-9707f4d8f6c0" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97992326-bfa0-4c9c-824a-9707f4d8f6c0")) {                    Plotly.newPlot(                        "97992326-bfa0-4c9c-824a-9707f4d8f6c0",                        [{"line":{"color":"#1F77B4","width":4},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":1.0,"x":["BEFORE","AFTER"],"y":[27.8,60.5],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[36.54,20.03],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":0.6,"x":["BEFORE","AFTER"],"y":[13.9,7.6],"type":"scatter"},{"line":{"color":"#D62728","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":1.0,"x":["BEFORE","AFTER"],"y":[5.56,3.11],"type":"scatter"},{"line":{"color":"#9467BD","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":1.0,"x":["BEFORE","AFTER"],"y":[9.26,5.1],"type":"scatter"},{"line":{"color":"#8C564B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":1.0,"x":["BEFORE","AFTER"],"y":[6.95,3.66],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"color ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e4ccb356-deb0-4b99-bf5f-712353323cda" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4ccb356-deb0-4b99-bf5f-712353323cda")) {                    Plotly.newPlot(                        "e4ccb356-deb0-4b99-bf5f-712353323cda",                        [{"line":{"color":"#1F77B4","width":4},"marker":{"size":8},"mode":"lines+markers","name":"UK","opacity":1.0,"x":["BEFORE","AFTER"],"y":[56.15,31.03],"type":"scatter"},{"line":{"color":"#FF7F0E","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other","opacity":0.6,"x":["BEFORE","AFTER"],"y":[59.31,70.03],"type":"scatter"},{"line":{"color":"#2CA02C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France","opacity":0.6,"x":["BEFORE","AFTER"],"y":[58.86,68.77],"type":"scatter"},{"line":{"color":"#D62728","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain","opacity":1.0,"x":["BEFORE","AFTER"],"y":[52.92,62.36],"type":"scatter"},{"line":{"color":"#9467BD","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Germany","opacity":1.0,"x":["BEFORE","AFTER"],"y":[46.22,56.81],"type":"scatter"},{"line":{"color":"#8C564B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Italy","opacity":1.0,"x":["BEFORE","AFTER"],"y":[42.24,50.63],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outs ...
#          before_seg_share  after_seg_share  conv_before  conv_after  \
# country
# other               36.54            20.03        59.31       70.03
# Germany              9.26             5.10        46.22       56.81
# Italy                6.95             3.66        42.24       50.63
# France              13.90             7.60        58.86       68.77
# Spain                5.56             3.11        52.92       62.36
# UK                  27.80            60.50        56.15       31.03
#
#          conv_diff  total_effect  mix_change_effect  conv_change_effect  \
# country
# other        10.72          1.19              -0.96                3.92
# Germany      10.59          0.97               0.43                0.98
# Italy         8.39          0.78               0.47                0.58
# France        9.91          0.52              -0.24                1.38
# Spain         9.45          0.36               0.07                0.53
# UK          -25.12        -14.95               0.24               -6.98
#
#          total_effect_share
# country
# other                -10.92
# Germany               -8.90
# Italy                 -7.16
# France                -4.77
# Spain                 -3.30
# UK                   137.20

# %%
conv_df['segment'] = conv_df.country + ' - ' + conv_df.maturity

# %%
calculate_conversion_effects(
    conv_df, 'segment', 'converted_users_before', 'users_before',
    'converted_users_after_scenario_2', 'users_after_scenario_2',

).reset_index()
# Out:
# conversion before = 55.62
# conversion after = 44.72
# total conversion change = -10.90
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="92003623-74d0-4512-9fa2-bf2c396662a2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92003623-74d0-4512-9fa2-bf2c396662a2")) {                    Plotly.newPlot(                        "92003623-74d0-4512-9fa2-bf2c396662a2",                        [{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[10.13],"y":[5.41],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.76],"y":[-9.64],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[6.72],"y":[-2.11],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[2.55],"y":[-6.42],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.88],"y":[0.55],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[3.07],"y":[-7.53],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[4.18],"y":[-0.0],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[1.37],"y":[-3.3],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[19.14],"y":[11.01],"type":"scatter"},{"marker":{"color":"#2CA02C","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[8.65],"y":[146.92],"type":"scatter"},{"marker":{"color":"#1F77B4","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[25.01],"y":[25.6],"type":"scatter"},{"marker":{"color":"#D62728","opacity":0.75,"size":10},"mode":"markers","showlegend":false,"x":[11.52],"y":[-33.13],"type":"scatter"},{"line":{"color":"gray","dash":"dash","width":1.5},"mode":"lines","x":[-33.13,146.92],"y":[-33.13,146.92],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c97fbde2-a64d-4d41-a19e-8afea75797c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c97fbde2-a64d-4d41-a19e-8afea75797c7")) {                    Plotly.newPlot(                        "c97fbde2-a64d-4d41-a19e-8afea75797c7",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+3.6%","+1.1%","+0.8%","+0.7%","+0.4%","+0.2%","-0.1%","-0.6%","-1.2%","-2.8%","-16.0%","+3.0%","44.7%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other - new","France - new","Italy - new","Germany - new","Spain - new","Germany - existing","Italy - existing","France - existing","UK - existing","other - existing","UK - new","remaining effects","After"],"y":[55.61502884165671,3.61,1.05,0.82,0.7,0.36,0.23,-0.06,-0.59,-1.2,-2.79,-16.01,2.9831664203922905,0.0],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.33333 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="41986391-1015-4381-b30b-47d3730233a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41986391-1015-4381-b30b-47d3730233a4")) {                    Plotly.newPlot(                        "41986391-1015-4381-b30b-47d3730233a4",                        [{"connector":{"line":{"color":"gray"}},"decreasing":{"marker":{"color":"rgba(214, 39, 40, 0.7)"}},"increasing":{"marker":{"color":"rgba(44, 160, 44, 0.7)"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","total"],"name":"Conversion","orientation":"v","text":["55.6%","+3.0%","+2.6%","-2.2%","-4.2%","-20.4%","+10.4%","44.7%"],"textposition":"outside","totals":{"marker":{"color":"rgba(31, 119, 180, 0.7)"}},"x":["Before","other - new - change of mix","other - existing - conversion change","UK - existing - change of mix","other - existing - change of mix","UK - new - change of mix","remaining effects","After"],"y":[55.61502884165671,2.99,2.6,-2.23,-4.23,-20.41,10.383166420392293,0.0],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8dc3e40-f6cb-41b9-ace3-695e6bcb26ba" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8dc3e40-f6cb-41b9-ace3-695e6bcb26ba")) {                    Plotly.newPlot(                        "b8dc3e40-f6cb-41b9-ace3-695e6bcb26ba",                        [{"line":{"color":"#2E91E5","width":4},"marker":{"size":8},"mode":"lines+markers","name":"UK - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[8.65,49.86],"type":"scatter"},{"line":{"color":"#E15F99","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[25.01,13.82],"type":"scatter"},{"line":{"color":"#1CA71C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[19.14,10.64],"type":"scatter"},{"line":{"color":"#FB0D0D","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[10.13,5.5],"type":"scatter"},{"line":{"color":"#DA16FF","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[3.88,1.99],"type":"scatter"},{"line":{"color":"#222A2A","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[4.18,2.36],"type":"scatter"},{"line":{"color":"#B68100","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[6.72,3.67],"type":"scatter"},{"line":{"color":"#750D86","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[1.37,0.75],"type":"scatter"},{"line":{"color":"#EB663B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Italy - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[3.07,1.67],"type":"scatter"},{"line":{"color":"#511CFB","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Germany - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[2.55,1.43],"type":"scatter"},{"line":{"color":"#00A08B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[3.76,2.1],"type":"scatter"},{"line":{"color":"#FB00D1","width":4},"marker":{"size":8},"mode":"lines+markers","name":"other - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[11.52,6.2],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.77777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24fa6ec8-7f7d-46fe-9992-792c1b3998ef" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24fa6ec8-7f7d-46fe-9992-792c1b3998ef")) {                    Plotly.newPlot(                        "24fa6ec8-7f7d-46fe-9992-792c1b3998ef",                        [{"line":{"color":"#2E91E5","width":4},"marker":{"size":8},"mode":"lines+markers","name":"UK - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[10.36,19.19],"type":"scatter"},{"line":{"color":"#E15F99","width":2},"marker":{"size":8},"mode":"lines+markers","name":"other - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[83.95,94.35],"type":"scatter"},{"line":{"color":"#1CA71C","width":2},"marker":{"size":8},"mode":"lines+markers","name":"UK - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[76.85,86.53],"type":"scatter"},{"line":{"color":"#FB0D0D","width":2},"marker":{"size":8},"mode":"lines+markers","name":"France - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[78.9,90.06],"type":"scatter"},{"line":{"color":"#DA16FF","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Italy - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[67.53,76.06],"type":"scatter"},{"line":{"color":"#222A2A","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Spain - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[66.02,74.4],"type":"scatter"},{"line":{"color":"#B68100","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Germany - existing","opacity":0.6,"x":["BEFORE","AFTER"],"y":[61.25,72.6],"type":"scatter"},{"line":{"color":"#750D86","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Spain - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[13.01,24.49],"type":"scatter"},{"line":{"color":"#EB663B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Italy - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[10.21,20.25],"type":"scatter"},{"line":{"color":"#511CFB","width":4},"marker":{"size":8},"mode":"lines+markers","name":"Germany - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[6.61,16.31],"type":"scatter"},{"line":{"color":"#00A08B","width":4},"marker":{"size":8},"mode":"lines+markers","name":"France - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[4.89,12.98],"type":"scatter"},{"line":{"color":"#FB00D1","width":4},"marker":{"size":8},"mode":"lines+markers","name":"other - new","opacity":1.0,"x":["BEFORE","AFTER"],"y":[5.82,15.86],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779 ...
#                segment  before_seg_share  after_seg_share  conv_before  \
# 0          other - new             11.52             6.20         5.82
# 1         France - new              3.76             2.10         4.89
# 2          Italy - new              3.07             1.67        10.21
# 3        Germany - new              2.55             1.43         6.61
# 4          Spain - new              1.37             0.75        13.01
# 5   Germany - existing              6.72             3.67        61.25
# 6     Spain - existing              4.18             2.36        66.02
# 7     Italy - existing              3.88             1.99        67.53
# 8    France - existing             10.13             5.50        78.90
# 9        UK - existing             19.14            10.64        76.85
# 10    other - existing             25.01            13.82        83.95
# 11            UK - new              8.65            49.86        10.36
#
#     conv_after  conv_diff  total_effect  mix_change_effect  \
# 0        15.86      10.04          3.61               2.99
# 1        12.98       8.09          1.05               0.88
# 2        20.25      10.05          0.82               0.65
# 3        16.31       9.71          0.70               0.56
# 4        24.49      11.48          0.36               0.27
# 5        72.60      11.35          0.23              -0.18
# 6        74.40       8.38          0.00              -0.20
# 7        76.06       8.53         -0.06              -0.23
# 8        90.06      11.15         -0.59              -1.20
# 9        86.53       9.67         -1.20              -2.23
# 10       94.35      10.40         -2.79              -4.23
# 11       19.19       8.83        -16.01             -20.41
#
#     conv_change_effect  total_effect_share
# 0                 1.16              -33.13
# 1                 0.30               -9.64
# 2                 0.31               -7.53
# 3                 0.25               -6.42
# 4                 0.16               -3.30
# 5                 0.76               -2.11
# 6                 0.35               -0.00
# 7                 0.33                0.55
# 8                 1.13                5.41
# 9                 1.85               11.01
# 10                2.60               25.60
# 11                0.76              146.92
