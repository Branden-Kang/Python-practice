# %% [markdown]
# [Reference](https://medium.com/@HeCanThink/dendrograms-the-hierarchical-portrait-of-data-%EF%B8%8F-bc97c7820599)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Example dataset
data = np.array([[2, 3],
                 [5, 8],
                 [1, 6],
                 [8, 2],
                 [7, 4]])

# %%
# Perform hierarchical clustering
linked = linkage(data, method='single')  # 'single' for single linkage, you can choose other linkage methods as well

# %%
# Create the dendrogram
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.title("Dendrogram")
plt.show()
