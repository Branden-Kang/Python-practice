# %% [markdown]
# [Reference](https://medium.com/the-click-reader/apache-airflow-in-python-getting-started-as-a-data-engineer-584e13a91320)

# %%
pip install apache-airflow
# Out:
# ...
#      |████████████████████████████████| 5.3 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 49 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 111 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 209 kB 43.9 MB/s
# ...
#      |████████████████████████████████| 155 kB 50.1 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 32.7 MB/s
# ...
#      |████████████████████████████████| 6.2 MB 32.3 MB/s
# ...
#      |████████████████████████████████| 548 kB 55.2 MB/s
# ...
#      |████████████████████████████████| 212 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 25.6 MB/s
# ...
#      |████████████████████████████████| 133 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 82 kB 567 kB/s
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 75 kB 3.9 MB/s
# ...

# %% [markdown]
# # Create your first Airflow pipeline

# %%
# !airflow initdb
# Out:
# usage: airflow [-h] GROUP_OR_COMMAND ...
#
# positional arguments:
#   GROUP_OR_COMMAND
#
#     Groups:
#       celery         Celery components
#       config         View configuration
#       connections    Manage connections
#       dags           Manage DAGs
#       db             Database operations
#       jobs           Manage jobs
#       kubernetes     Tools to help run the KubernetesExecutor
#       pools          Manage pools
#       providers      Display providers
#       roles          Manage roles
#       tasks          Manage tasks
#       users          Manage users
#       variables      Manage variables
#
#     Commands:
#       cheat-sheet    Display cheat sheet
#       info           Show information about current Airflow and environment
#       kerberos       Start a kerberos ticket renewer
#       plugins        Dump information about loaded plugins
#       rotate-fernet-key
#                      Rotate encrypted connection credentials and variables
# ...

# %%
# !airflow webserver -p 8080
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144 UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
# [2021-10-21 12:51:31,322] {cli_action_loggers.py:105} WARNING - Failed to log action with (sqlite3.OperationalError) no such table: log
# [SQL: INSERT INTO log (dttm, dag_id, task_id, event, execution_date, owner, extra) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('2021-10-21 12:51:31.318504', None, None, 'cli_webserver', None, 'root', '{"host_name": "c3a40ea85af0", "full_command": "[\'/usr/local/bin/airflow\', \'webserver\', \'-p\', \'8080\']"}')]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ...

# %%
# !airflow scheduler
# Out:
# [2021-10-21 12:53:40,843] {cli_action_loggers.py:105} WARNING - Failed to log action with (sqlite3.OperationalError) no such table: log
# [SQL: INSERT INTO log (dttm, dag_id, task_id, event, execution_date, owner, extra) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('2021-10-21 12:53:40.839426', None, None, 'cli_scheduler', None, 'root', '{"host_name": "c3a40ea85af0", "full_command": "[\'/usr/local/bin/airflow\', \'scheduler\']"}')]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py", line 1277, in _execute_context
#     cursor, statement, parameters, context
# ...
