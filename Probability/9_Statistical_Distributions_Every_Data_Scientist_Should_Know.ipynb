# %% [markdown]
# [Reference](https://ai.plainenglish.io/9-statistical-distributions-every-data-scientist-should-know-cbe15b49c020)

# %% [markdown]
# # 1. 𝐔𝐧𝐢𝐟𝐨𝐫𝐦 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.uniform(0, 1, 1000)
plt.hist(data, bins=10, density=True)
plt.title("Uniform Distribution")
plt.show()

# %% [markdown]
# # 2. 𝐍𝐨𝐫𝐦𝐚𝐥 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %%
data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=30, density=True)
plt.title("Normal Distribution")
plt.show()

# %% [markdown]
# # 3. 𝐁𝐢𝐧𝐨𝐦𝐢𝐚𝐥 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %%
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

plt.bar(x, pmf)
plt.title("Binomial Distribution")
plt.show()

# %% [markdown]
# # 4. 𝐏𝐨𝐢𝐬𝐬𝐨𝐧 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %%
from scipy.stats import poisson

lam = 3
x = np.arange(0, 10)
pmf = poisson.pmf(x, lam)

plt.bar(x, pmf)
plt.title("Poisson Distribution")
plt.show()

# %% [markdown]
# # 5. 𝐁𝐞𝐫𝐧𝐨𝐮𝐥𝐥𝐢 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %% [markdown]
# Modeling whether a light bulb is functional (success) or defective (failure).

# %% [markdown]
# # 6. 𝐋𝐨𝐠-𝐍𝐨𝐫𝐦𝐚𝐥 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %% [markdown]
# Modeling stock prices, where prices cannot be negative.

# %% [markdown]
# # 7. 𝐆𝐚𝐦𝐦𝐚 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %% [markdown]
# Survival analysis or modeling customer waiting times in a call center.

# %% [markdown]
# # 8. 𝐆𝐞𝐨𝐦𝐞𝐭𝐫𝐢𝐜 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %% [markdown]
# Predicting the number of attempts needed to fix a bug in software.

# %% [markdown]
# # 9. 𝐁𝐞𝐭𝐚 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %% [markdown]
# Estimating the probability of success in an A/B test or election polling.
