# %% [markdown]
# [Reference](https://medium.com/@jkishan421/builder-pattern-in-python-clean-code-for-complex-object-creation-bb33afff18ff)

# %% [markdown]
# # Using Constructor with Many Arguments

# %%
class Computer:
    def __init__(self, cpu, gpu=None, ram=None, storage=None, keyboard=None, monitor=None):
        self.cpu = cpu
        self.gpu = gpu
        self.ram = ram
        self.storage = storage
        self.keyboard = keyboard
        self.monitor = monitor

    def __str__(self):
        return f"CPU: {self.cpu}, GPU: {self.gpu}, RAM: {self.ram}, Storage: {self.storage}, Keyboard: {self.keyboard}, Monitor: {self.monitor}"

# Create a computer
pc = Computer("Intel i9", "RTX 4090", "32GB", "2TB", "Mechanical", "4K")
print(pc)
# Out:
# CPU: Intel i9, GPU: RTX 4090, RAM: 32GB, Storage: 2TB, Keyboard: Mechanical, Monitor: 4K

# %%
class Computer:
    def __init__(self):
        self.cpu = None
        self.gpu = None
        self.ram = None
        self.storage = None
        self.keyboard = None
        self.monitor = None

    def __str__(self):
        return f"CPU: {self.cpu}, GPU: {self.gpu}, RAM: {self.ram}, Storage: {self.storage}, Keyboard: {self.keyboard}, Monitor: {self.monitor}"


class ComputerBuilder:
    def __init__(self):
        self.computer = Computer()

    def set_cpu(self, cpu):
        self.computer.cpu = cpu
        return self

    def set_gpu(self, gpu):
        self.computer.gpu = gpu
        return self

    def set_ram(self, ram):
        self.computer.ram = ram
        return self

    def set_storage(self, storage):
        self.computer.storage = storage
        return self

    def set_keyboard(self, keyboard):
        self.computer.keyboard = keyboard
        return self

    def set_monitor(self, monitor):
        self.computer.monitor = monitor
        return self

    def build(self):
        return self.computer

if __name__ == "__main__":
  builder = ComputerBuilder()
  pc = (
      builder.set_cpu("Intel i9")
             .set_gpu("RTX 4090")
             .set_ram("32GB")
             .set_storage("2TB SSD")
             .set_keyboard("Mechanical")
             .set_monitor("4K")
             .build()
  )

  print(pc)
class Computer:
    def __init__(self):
        self.cpu = None
        self.gpu = None
        self.ram = None
        self.storage = None
        self.keyboard = None
        self.monitor = None

    def __str__(self):
        return f"CPU: {self.cpu}, GPU: {self.gpu}, RAM: {self.ram}, Storage: {self.storage}, Keyboard: {self.keyboard}, Monitor: {self.monitor}"


class ComputerBuilder:
    def __init__(self):
        self.computer = Computer()

    def set_cpu(self, cpu):
        self.computer.cpu = cpu
        return self

    def set_gpu(self, gpu):
        self.computer.gpu = gpu
        return self

    def set_ram(self, ram):
        self.computer.ram = ram
        return self

    def set_storage(self, storage):
        self.computer.storage = storage
        return self

    def set_keyboard(self, keyboard):
        self.computer.keyboard = keyboard
        return self

    def set_monitor(self, monitor):
        self.computer.monitor = monitor
        return self

    def build(self):
        return self.computer

if __name__ == "__main__":
  builder = ComputerBuilder()
  pc = (
      builder.set_cpu("Intel i9")
             .set_gpu("RTX 4090")
             .set_ram("32GB")
             .set_storage("2TB SSD")
             .set_keyboard("Mechanical")
             .set_monitor("4K")
             .build()
  )

  print(pc)
# Out:
# CPU: Intel i9, GPU: RTX 4090, RAM: 32GB, Storage: 2TB SSD, Keyboard: Mechanical, Monitor: 4K
# CPU: Intel i9, GPU: RTX 4090, RAM: 32GB, Storage: 2TB SSD, Keyboard: Mechanical, Monitor: 4K
