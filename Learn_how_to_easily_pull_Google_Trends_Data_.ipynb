# %% [markdown]
# [Reference](https://blog.devgenius.io/learn-how-to-easily-pull-google-trends-data-with-python-code-e52523c6ac1d)

# %%
pip install pytrends
# Out:
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=3dff79ea16a19a57df11337994105a353d9abbccf09a14c60dcbdea240c56427
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...

# %%
import pandas as pd
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
pytrends.build_payload(kw_list=['machine learning'])

df = pytrends.interest_by_region() # Interest by Region
df.sort_values(by=['machine learning'], ascending=False)
# Out:
#                           machine learning
# geoName
# China                                  100
# Singapore                               43
# St. Helena                              30
# India                                   30
# Hong Kong                               23
# ...                                    ...
# Guyana                                   0
# Haiti                                    0
# Heard & McDonald Islands                 0
# Honduras                                 0
# Åland Islands                            0
#
# [250 rows x 1 columns]

# %%
df.reset_index().plot(x='geoName', y='machine learning', figsize=(120, 10), kind='bar')

# %% [markdown]
# # Daily Search Trends

# %%
df = pytrends.trending_searches(pn='india')
df.head()
# Out:
#                    0
# 0   Champions League
# 1         Campus IPO
# 2      Chhavi Mittal
# 3  Bhool Bhulaiyaa 2
# 4       Dwayne Bravo

# %%
df = pytrends.today_searches(pn='IN') #IN (india)
df
# Out:
# 0     /trends/explore?q=Champions+League&date=now+7-...
# 1     /trends/explore?q=Gangubai+Kathiawadi&date=now...
# 2      /trends/explore?q=Campus+IPO&date=now+7-d&geo=IN
# 3     /trends/explore?q=Chhavi+Mittal&date=now+7-d&g...
# 4     /trends/explore?q=Bhool+Bhulaiyaa+2&date=now+7...
# 5     /trends/explore?q=Liam+Livingstone&date=now+7-...
# 6     /trends/explore?q=Dwayne+Bravo&date=now+7-d&ge...
# 7     /trends/explore?q=Abhishek+Bachchan&date=now+7...
# 8     /trends/explore?q=Tejasswi+Prakash&date=now+7-...
# 9     /trends/explore?q=LIC+IPO+Date&date=now+7-d&ge...
# 10    /trends/explore?q=TSLPRB+Notification+2022&dat...
# 11      /trends/explore?q=RR+vs+RCB&date=now+7-d&geo=IN
# Name: exploreLink, dtype: object

# %% [markdown]
# # Top Charts

# %%
df = pytrends.top_charts(2021, hl='en-US', tz=300, geo='GLOBAL')
df.head()
# Out:
#                 title exploreQuery
# 0  Australia vs India
# 1    India vs England
# 2                 IPL
# 3                 NBA
# 4           Euro 2021

# %%
keywords = pytrends.suggestions(keyword='spacex')
df = pd.DataFrame(keywords)
df.drop(columns='mid')
# Out:
#                  title               type
# 0               SpaceX  Aerospace company
# 1             Starlink              Topic
# 2             Starship               Plan
# 3               Spacex              Topic
# 4  SpaceX Inspiration4              Topic

# %%
pytrends.build_payload(kw_list=['jobs'])
related_queries = pytrends.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                   query  value
# 0          jobs near me    100
# 1                   job     84
# 2           indeed jobs     75
# 3                indeed     75
# 4        part time jobs     45
# 5             city jobs     38
# 6           jobs hiring     35
# 7           jobs online     34
# 8       government jobs     27
# 9           amazon jobs     26
# 10            best jobs     23
# 11       jobs from home     23
# 12           steve jobs     21
# 13      craigslist jobs     20
# 14             nhs jobs     19
# 15          google jobs     19
# 16            govt jobs     17
# 17  work from home jobs     17
# 18              it jobs     17
# 19       work from home     17
# 20  jobs near me hiring     15
# 21       hiring near me     15
# 22        facebook jobs     13
# 23        security jobs     13
# 24             usa jobs     13, 'rising':                           query  value
# 0           amazon jobs near me   3300
# ...
