# %% [markdown]
# [Reference](https://towardsdatascience.com/10-things-you-didnt-know-about-pandas-d20f06d1bf6b)

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

X,y = fetch_openml("autos", version=1, as_frame=True, return_X_y=True)
data = X
data['target'] = y
data.head()
# Out:
#    normalized-losses         make fuel-type  ... highway-mpg    price target
# 0                NaN  alfa-romero       gas  ...        27.0  13495.0      3
# 1                NaN  alfa-romero       gas  ...        27.0  16500.0      3
# 2                NaN  alfa-romero       gas  ...        26.0  16500.0      1
# 3              164.0         audi       gas  ...        30.0  13950.0      2
# 4              164.0         audi       gas  ...        22.0  17450.0      2
#
# [5 rows x 26 columns]

# %%
import numpy as np

pivot_table = pd.pivot_table(data, values='horsepower', index=['num-of-cylinders'],
                    columns=['target'], aggfunc=np.sum, fill_value=0)

print(pivot_table)
# Out:
# target             -2    -1     0     1     2     3
# num-of-cylinders
# eight               0   155   184   472     0   155
# five                0   369   393   360   225     0
# four              390  1511  4340  3604  2518  1854
# six                 0   552  1596   435     0  1303
# three               0     0     0     0    48     0
# twelve              0     0   262     0     0     0
# two                 0     0     0     0     0   438

# %%
data.describe(include='all')
# Out:
#         normalized-losses    make fuel-type  ... highway-mpg         price target
# count          164.000000     205       205  ...  205.000000    201.000000    205
# unique                NaN      22         2  ...         NaN           NaN      6
# top                   NaN  toyota       gas  ...         NaN           NaN      0
# freq                  NaN      32       185  ...         NaN           NaN     67
# mean           122.000000     NaN       NaN  ...   30.751220  13207.129353    NaN
# std             35.442168     NaN       NaN  ...    6.886443   7947.066342    NaN
# min             65.000000     NaN       NaN  ...   16.000000   5118.000000    NaN
# 25%             94.000000     NaN       NaN  ...   25.000000   7775.000000    NaN
# 50%            115.000000     NaN       NaN  ...   30.000000  10295.000000    NaN
# 75%            150.000000     NaN       NaN  ...   34.000000  16500.000000    NaN
# ...

# %%
round(data.corr(),2)
# Out:
#                    normalized-losses  wheel-base  ...  highway-mpg  price
# normalized-losses               1.00       -0.07  ...        -0.21   0.20
# wheel-base                     -0.07        1.00  ...        -0.54   0.58
# length                          0.02        0.87  ...        -0.70   0.69
# width                           0.11        0.80  ...        -0.68   0.75
# height                         -0.43        0.59  ...        -0.11   0.14
# curb-weight                     0.12        0.78  ...        -0.80   0.83
# engine-size                     0.17        0.57  ...        -0.68   0.87
# bore                           -0.04        0.49  ...        -0.59   0.54
# stroke                          0.07        0.16  ...        -0.04   0.08
# compression-ratio              -0.13        0.25  ...         0.27   0.07
# horsepower                      0.30        0.35  ...        -0.77   0.81
# peak-rpm                        0.26       -0.36  ...        -0.05  -0.10
# ...

# %%
data.plot.scatter(x='engine-size', y='horsepower')

# %%
pivot_table.plot()

# %%
pip install pandas_bokeh

# %%
pd.options.plotting.backend = 'pandas_bokeh'

import pandas_bokeh
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()
p1 = data.plot_bokeh.scatter(x='engine-size', 
                              y='horsepower', 
                              category='target', 
                              title='Risk Rating by Engine Size Horsepower',
                              show_figure=False)
show(p1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas_bokeh/plot.py:1331: UserWarning: There are more than 5 categories in the scatterplot. The legend might be crowded, to hide the axis you can pass 'legend=False' as an optional argument.
#   "There are more than 5 categories in the scatterplot. The legend might be crowded, to hide the axis you can pass 'legend=False' as an optional argument."
#   <div class="bk-root" id="a1f55679-7275-42eb-aacf-5fa682affa8b" data-root-id="1001"></div>

# %%
target_groups = data.groupby('target').mean()
target_groups
# Out:
#         normalized-losses  wheel-base  ...  highway-mpg         price
# target                                 ...
# -3                    NaN         NaN  ...          NaN           NaN
# -2             103.000000  104.300000  ...    26.000000  15781.666667
# -1              85.600000  106.068182  ...    27.272727  17330.681818
# 0              113.166667  101.119403  ...    30.029851  14397.092308
# 1              128.574468   95.912963  ...    34.018519   9648.653846
# 2              125.689655   96.237500  ...    34.156250  10109.281250
# 3              168.647059   94.992593  ...    25.333333  17221.296296
#
# [7 rows x 15 columns]

# %%
data_summary = data[['target', 'engine-size', 'horsepower', 'price']]
data_summary.head(10).style.format({ 
                          "engine-size": "{:20,.0f} cc", 
                          "horsepower": "{:20,.0f} hp",
                          "price":"${:20,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_d054ec84_7c14_11eb_9c65_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >target</th>        <th class="col_heading level0 col1" >engine-size</th>        <th class="col_heading level0 col2" >horsepower</th>        <th class="col_heading level0 col3" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d054ec84_7c14_11eb_9c65_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d054ec84_7c14_11eb_9c65_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_d054ec84_7c14_11eb_9c65_0242ac1c0002row0_col1" class="data row0 col1" >                 130 cc</td>
#                         <td id="T_d054ec84_7c14_11eb_9c65_0242ac1c0002row0_col2" class="data row0 col2" >                 111 hp</td>
# ...

# %%
data_summary.head(10).style.format({ 
                          "engine-size": "{:20,.0f} cc", 
                          "horsepower": "{:20,.0f} hp",
                          "price":"${:20,.0f}"})\
                    .background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row0_col1,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row1_col1{
#             background-color:  #218e8d;
#             color:  #000000;
#         }#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row0_col2,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row1_col2{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row0_col3,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row3_col1,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row3_col2{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row1_col3,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row2_col3{
#             background-color:  #365d8d;
#             color:  #f1f1f1;
#         }#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row2_col1,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row8_col3,#T_d8578e0a_7c14_11eb_9c65_0242ac1c0002row9_col2{
# ...

# %%
pd.set_option("display.max_columns",100)
pd.set_option("display.precision",2)

# %%
data_summary.head(10).style.format({ 
                          "engine-size": "{:20,.0f} cc", 
                          "horsepower": "{:20,.0f} hp",
                          "price":"${:20,.0f}"})\
                    .background_gradient(cmap='viridis')\
                    .set_caption('First 10 Rows')
# Out:
# <style  type="text/css" >
# #T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row0_col1,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row1_col1{
#             background-color:  #218e8d;
#             color:  #000000;
#         }#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row0_col2,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row1_col2{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row0_col3,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row3_col1,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row3_col2{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row1_col3,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row2_col3{
#             background-color:  #365d8d;
#             color:  #f1f1f1;
#         }#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row2_col1,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row8_col3,#T_dfbfa678_7c14_11eb_9c65_0242ac1c0002row9_col2{
# ...
