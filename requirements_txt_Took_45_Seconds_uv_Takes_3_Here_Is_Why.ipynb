# %% [markdown]
# [Reference](https://blog.stackademic.com/requirements-txt-took-45-seconds-uv-takes-3-here-is-why-ab76c0a48b61)

# %% [markdown]
# ```
# # requirements.txt
# fastapi==0.110.0
# sqlalchemy==2.0.28
# pydantic==2.6.3
# httpx==0.27.0
# ```

# %%
# Install uv
pip install uv

# %%
# Initialize a project
uv init myproject
cd myproject
# Add dependencies
uv add fastapi sqlalchemy pydantic httpx
# Add development only dependencies
uv add --dev pytest ruff mypy
# Sync to exact lockfile state
uv sync

# %% [markdown]
# ```
# [project]
# name = "myproject"
# version = "0.1.0"
# requires-python = ">=3.11"
# dependencies = [
#     "fastapi>=0.110.0",
#     "sqlalchemy>=2.0.28",
#     "pydantic>=2.6.3",
#     "httpx>=0.27.0",
# ]
# ```
