# %% [markdown]
# [Reference](https://moez-62905.medium.com/take-your-data-analysis-to-the-next-level-with-these-5-advanced-pandas-functions-98cef90512ce)

# %% [markdown]
# # 1. pd.merge_ordered

# %%
import pandas as pd

# create df1 and df2
df1 = pd.DataFrame({'Date': ['2021-01-01', '2021-02-01', '2021-03-01'],
                    'Revenue': [100, 200, 300]})

df2 = pd.DataFrame({'Date': ['2021-01-01', '2021-02-01', '2021-04-01'],
                    'Cost': [50, 100, 150]})

# merge df1 and df2
merged_df = pd.merge_ordered(df1, df2, on='Date', fill_method='ffill')
print(merged_df)
# Out:
#          Date  Revenue  Cost
# 0  2021-01-01      100    50
# 1  2021-02-01      200   100
# 2  2021-03-01      300   100
# 3  2021-04-01      300   150

# %% [markdown]
# # 2. MultiIndexing in Pandas

# %%
import pandas as pd

data = {'year': [2010, 2010, 2011, 2011],
        'month': [1, 2, 1, 2],
        'sales': [100, 150, 200, 250]}

df = pd.DataFrame(data)
df = df.set_index(['year', 'month'])

# %% [markdown]
# # 3. pd.grouper

# %%
import pandas as pd
import numpy as np

date_rng = pd.date_range(start='1/1/2020', end='1/01/2022', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0,100,size=(len(date_rng)))
df = df.set_index('date')
grouped_year = df.groupby(pd.Grouper(freq='Y')).sum()
grouped_year
# Out:
#              data
# date
# 2020-12-31  18622
# 2021-12-31  17872
# 2022-12-31     42

# %%
import pandas as pd
import numpy as np

date_rng = pd.date_range(start='1/1/2020', end='1/01/2022', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0,100,size=(len(date_rng)))
df = df.set_index('date')
grouped_month = df.groupby(pd.Grouper(freq='M')).sum()
grouped_month
# Out:
#             data
# date
# 2020-01-31  1369
# 2020-02-29  1589
# 2020-03-31  1409
# 2020-04-30  1639
# 2020-05-31  1550
# 2020-06-30  1542
# 2020-07-31  1629
# 2020-08-31  1472
# 2020-09-30  1751
# 2020-10-31  1487
# 2020-11-30  1461
# 2020-12-31  1489
# 2021-01-31  1717
# 2021-02-28  1612
# 2021-03-31  1462
# 2021-04-30  1589
# 2021-05-31  1475
# 2021-06-30  1348
# 2021-07-31  1595
# 2021-08-31  1665
# 2021-09-30  1474
# 2021-10-31  1446
# 2021-11-30  1309
# 2021-12-31  1332
# 2022-01-31    73

# %% [markdown]
# # 4. pd.eval

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0, 100, size=(1000000, 4)), columns=list('ABCD'))
df['E'] = pd.eval('df.A + df.B')
df['F'] = pd.eval('df.C - df.D')
df.head()
# Out:
#     A   B   C   D    E   F
# 0  64  69   3  35  133 -32
# 1  76  10  71  49   86  22
# 2  77  87  10  82  164 -72
# 3  65  18  81  32   83  49
# 4  30  33  42  54   63 -12

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0, 100, size=(1000000, 4)), columns=list('ABCD'))
df['E'] = pd.eval('df.A > 50 and df.B < 30')
df.head()
# Out:
#     A   B   C   D      E
# 0  58  66  65  47  False
# 1  75  43  13  83  False
# 2  17  77  93  52  False
# 3  83  85  44  39  False
# 4  86  34  57   2  False

# %% [markdown]
# # 5. pd.DataFrame.style

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5, 5), columns=list('ABCDE'))
styled_df = df.style.background_gradient(cmap='coolwarm', axis=0)
styled_df
# Out:
# <style type="text/css">
# #T_11b19_row0_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_11b19_row0_col1, #T_11b19_row1_col0, #T_11b19_row2_col4, #T_11b19_row3_col2, #T_11b19_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_11b19_row0_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_11b19_row0_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_11b19_row0_col4, #T_11b19_row1_col1, #T_11b19_row3_col3, #T_11b19_row4_col0, #T_11b19_row4_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_11b19_row1_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_11b19_row1_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_11b19_row1_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_11b19_row2_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_11b19_row2_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_11b19_row2_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_11b19_row2_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_11b19_row3_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_11b19_row3_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_11b19_row3_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_11b19_row4_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_11b19_row4_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_11b19_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11b19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11b19_row0_col0" class="data row0 col0" >-0.355131</td>
#       <td id="T_11b19_row0_col1" class="data row0 col1" >-0.347968</td>
#       <td id="T_11b19_row0_col2" class="data row0 col2" >0.865194</td>
#       <td id="T_11b19_row0_col3" class="data row0 col3" >0.472778</td>
#       <td id="T_11b19_row0_col4" class="data row0 col4" >0.925201</td>
#     </tr>
#     <tr>
#       <th id="T_11b19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11b19_row1_col0" class="data row1 col0" >-1.669599</td>
#       <td id="T_11b19_row1_col1" class="data row1 col1" >1.194680</td>
#       <td id="T_11b19_row1_col2" class="data row1 col2" >-0.223249</td>
#       <td id="T_11b19_row1_col3" class="data row1 col3" >1.502650</td>
#       <td id="T_11b19_row1_col4" class="data row1 col4" >-0.110354</td>
#     </tr>
#     <tr>
#       <th id="T_11b19_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11b19_row2_col0" class="data row2 col0" >-1.156169</td>
#       <td id="T_11b19_row2_col1" class="data row2 col1" >0.772100</td>
#       <td id="T_11b19_row2_col2" class="data row2 col2" >-0.894298</td>
#       <td id="T_11b19_row2_col3" class="data row2 col3" >0.497568</td>
#       <td id="T_11b19_row2_col4" class="data row2 col4" >-0.260167</td>
#     </tr>
#     <tr>
#       <th id="T_11b19_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11b19_row3_col0" class="data row3 col0" >1.617421</td>
#       <td id="T_11b19_row3_col1" class="data row3 col1" >0.270704</td>
#       <td id="T_11b19_row3_col2" class="data row3 col2" >-1.602151</td>
#       <td id="T_11b19_row3_col3" class="data row3 col3" >1.797463</td>
#       <td id="T_11b19_row3_col4" class="data row3 col4" >-0.078411</td>
#     </tr>
#     <tr>
#       <th id="T_11b19_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11b19_row4_col0" class="data row4 col0" >1.853081</td>
#       <td id="T_11b19_row4_col1" class="data row4 col1" >0.797295</td>
#       <td id="T_11b19_row4_col2" class="data row4 col2" >1.682386</td>
#       <td id="T_11b19_row4_col3" class="data row4 col3" >0.360912</td>
#       <td id="T_11b19_row4_col4" class="data row4 col4" >0.736553</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': ['a', 'b', 'c', 'd']})
styled_df = df.style.set_properties(**{'background-color': 'pink', 'color': 'white'}, subset=pd.IndexSlice[1:3, 'B'])
styled_df
# Out:
# <style type="text/css">
# #T_ae257_row1_col1, #T_ae257_row2_col1, #T_ae257_row3_col1 {
#   background-color: pink;
#   color: white;
# }
# </style>
# <table id="T_ae257_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae257_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae257_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ae257_row0_col1" class="data row0 col1" >a</td>
#     </tr>
#     <tr>
#       <th id="T_ae257_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae257_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ae257_row1_col1" class="data row1 col1" >b</td>
#     </tr>
#     <tr>
#       <th id="T_ae257_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae257_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ae257_row2_col1" class="data row2 col1" >c</td>
#     </tr>
#     <tr>
#       <th id="T_ae257_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae257_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ae257_row3_col1" class="data row3 col1" >d</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5, 5), columns=list('ABCDE'))
styled_df = df.style.set_caption('My Custom Caption').set_table_styles([{'selector': 'caption', 'props': [('color', 'red'), ('font-size', '20px')]}])
styled_df
# Out:
# <style type="text/css">
# #T_11152_ caption {
#   color: red;
#   font-size: 20px;
# }
# </style>
# <table id="T_11152_" class="dataframe">
#   <caption>My Custom Caption</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11152_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11152_row0_col0" class="data row0 col0" >-1.499051</td>
#       <td id="T_11152_row0_col1" class="data row0 col1" >-0.694480</td>
#       <td id="T_11152_row0_col2" class="data row0 col2" >-0.173657</td>
#       <td id="T_11152_row0_col3" class="data row0 col3" >-0.335961</td>
#       <td id="T_11152_row0_col4" class="data row0 col4" >0.528174</td>
#     </tr>
#     <tr>
#       <th id="T_11152_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11152_row1_col0" class="data row1 col0" >0.122313</td>
#       <td id="T_11152_row1_col1" class="data row1 col1" >1.789473</td>
#       <td id="T_11152_row1_col2" class="data row1 col2" >1.404269</td>
#       <td id="T_11152_row1_col3" class="data row1 col3" >-3.099198</td>
#       <td id="T_11152_row1_col4" class="data row1 col4" >1.273354</td>
#     </tr>
#     <tr>
#       <th id="T_11152_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11152_row2_col0" class="data row2 col0" >0.473963</td>
#       <td id="T_11152_row2_col1" class="data row2 col1" >0.373504</td>
#       <td id="T_11152_row2_col2" class="data row2 col2" >-1.004536</td>
#       <td id="T_11152_row2_col3" class="data row2 col3" >0.864541</td>
#       <td id="T_11152_row2_col4" class="data row2 col4" >-1.766586</td>
#     </tr>
#     <tr>
#       <th id="T_11152_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11152_row3_col0" class="data row3 col0" >-0.829341</td>
#       <td id="T_11152_row3_col1" class="data row3 col1" >-0.914608</td>
#       <td id="T_11152_row3_col2" class="data row3 col2" >0.436055</td>
#       <td id="T_11152_row3_col3" class="data row3 col3" >0.380552</td>
#       <td id="T_11152_row3_col4" class="data row3 col4" >0.684919</td>
#     </tr>
#     <tr>
#       <th id="T_11152_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11152_row4_col0" class="data row4 col0" >0.741998</td>
#       <td id="T_11152_row4_col1" class="data row4 col1" >-2.000769</td>
#       <td id="T_11152_row4_col2" class="data row4 col2" >0.450342</td>
#       <td id="T_11152_row4_col3" class="data row4 col3" >1.397902</td>
#       <td id="T_11152_row4_col4" class="data row4 col4" >-0.463563</td>
#     </tr>
#   </tbody>
# </table>
