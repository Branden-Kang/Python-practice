# %% [markdown]
# [Reference](https://ai.plainenglish.io/pca-explained-how-machine-learning-reduces-complexity-without-throwing-away-the-whole-story-2246ef435234$0)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
# Example data: [math, physics, chemistry, biology]
X = np.array([
    [85, 88, 90, 84],
    [78, 75, 80, 79],
    [92, 95, 94, 91],
    [60, 65, 63, 62],
    [70, 72, 68, 71]
])
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Reduce to 2 principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
print("Transformed data:")
print(X_pca)
print("Explained variance ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Transformed data:
# [[ 1.55189292  0.10229748]
#  [-0.01551496 -0.41349683]
#  [ 2.69732379  0.12462237]
#  [-2.82731499  0.16814193]
#  [-1.40638677  0.01843505]]
# Explained variance ratio:
# [0.98279009 0.01127933]
