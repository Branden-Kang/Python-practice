# %% [markdown]
# [Reference](https://levelup.gitconnected.com/genetic-algorithm-complete-guide-with-python-implementation-747d62dbe9bd)

# %%
import numpy as np

# Define the fitness function
def fitness(x):
  # Maximize the function f(x) = x^2
  return x**2

# %%
# Define the GA parameters
POP_SIZE = 100
GENS = 100
CROSSOVER_PROB = 0.8
MUTATION_PROB = 0.2

# %%
# Initialize the population
pop = np.random.rand(POP_SIZE)

# Evaluate the fitness of the initial population
fitness_values = np.array([fitness(x) for x in pop])

# %%
parents = np.array([pop[np.argmax(fitness_values)] for _ in range(POP_SIZE//2)])

# %%
offspring = []
for _ in range(POP_SIZE//2):
    parent1, parent2 = parents[np.random.randint(0, len(parents), 2)]
    child = (parent1 + parent2) / 2
    offspring.append(child)

# %%
for i in range(len(offspring)):  # Iterate over the correct range of offspring
    if np.random.rand() < MUTATION_PROB:
      offspring[i] += np.random.normal(0, 0.1)

# %%
import numpy as np

# Define the fitness function
def fitness(x):
  # Maximize the function f(x) = x^2
  return x**2

# Define the GA parameters
POP_SIZE = 100
GENS = 100
CROSSOVER_PROB = 0.8
MUTATION_PROB = 0.2

# Initialize the population
pop = np.random.rand(POP_SIZE)

# Evaluate the fitness of the initial population
fitness_values = np.array([fitness(x) for x in pop])

# Main GA loop
for gen in range(GENS):

  # Selection
  parents = np.array([pop[np.argmax(fitness_values)] for _ in range(POP_SIZE//2)])

  # Crossover
  offspring = []
  for _ in range(POP_SIZE//2):
    parent1, parent2 = parents[np.random.randint(0, len(parents), 2)]
    child = (parent1 + parent2) / 2
    offspring.append(child)

  # Mutation
  for i in range(len(offspring)):  # Iterate over the correct range of offspring
    if np.random.rand() < MUTATION_PROB:
      offspring[i] += np.random.normal(0, 0.1)

  # Replace the population with the new offspring
  pop = offspring

  # Evaluate the fitness of the new population
  fitness_values = np.array([fitness(x) for x in pop])

  # Print the best fitness value
  print(f"Generation {gen+1}, Best Fitness: {np.max(fitness_values)}")
# Print the final best solution
print(f"Final Best Solution: {pop[np.argmax(fitness_values)]}")
# Out:
# Generation 1, Best Fitness: 1.5853338446292844
# Generation 2, Best Fitness: 1.9957179447339513
# Generation 3, Best Fitness: 2.424794105579173
# Generation 4, Best Fitness: 2.5788775487777316
# Generation 5, Best Fitness: 3.4097158360636177
# Generation 6, Best Fitness: 4.138594523517558
# Generation 7, Best Fitness: 4.578815855743189
# Generation 8, Best Fitness: 4.872972184520545
# Generation 9, Best Fitness: 5.721709350128561
# Generation 10, Best Fitness: 6.709457755358586
# Generation 11, Best Fitness: 7.486480985149882
# Generation 12, Best Fitness: 8.855632162775244
# Generation 13, Best Fitness: 9.412631066223629
# Generation 14, Best Fitness: 9.949422058832711
# Generation 15, Best Fitness: 11.06144431780027
# Generation 16, Best Fitness: 12.33798606375533
# Generation 17, Best Fitness: 12.784650622833421
# Generation 18, Best Fitness: 14.336347509075098
# Generation 19, Best Fitness: 15.093293488779047
# Generation 20, Best Fitness: 15.728124394564038
# Generation 21, Best Fitness: 16.763137489571875
# Generation 22, Best Fitness: 17.775779428461696
# Generation 23, Best Fitness: 19.308887906409005
# Generation 24, Best Fitness: 20.328083286347713
# Generation 25, Best Fitness: 21.284287620102603
# Generation 26, Best Fitness: 22.36113432765221
# Generation 27, Best Fitness: 23.73492467383736
# Generation 28, Best Fitness: 24.340805305696673
# Generation 29, Best Fitness: 26.085029755386383
# Generation 30, Best Fitness: 28.326582305469653
# Generation 31, Best Fitness: 30.121579628889744
# Generation 32, Best Fitness: 31.661824879529295
# Generation 33, Best Fitness: 33.308369742077865
# Generation 34, Best Fitness: 33.93212159842274
# Generation 35, Best Fitness: 35.97271409482544
# Generation 36, Best Fitness: 37.352899511739764
# Generation 37, Best Fitness: 41.86353954369389
# Generation 38, Best Fitness: 44.08407204866858
# Generation 39, Best Fitness: 44.59194034544236
# Generation 40, Best Fitness: 45.428874078295244
# Generation 41, Best Fitness: 47.956553552877644
# Generation 42, Best Fitness: 52.30673523175359
# Generation 43, Best Fitness: 54.984127508101956
# Generation 44, Best Fitness: 57.42777480708633
# Generation 45, Best Fitness: 59.93395183398199
# Generation 46, Best Fitness: 60.568055097231806
# Generation 47, Best Fitness: 63.14007663969082
# Generation 48, Best Fitness: 64.99596048092819
# Generation 49, Best Fitness: 69.08874336439678
# Generation 50, Best Fitness: 72.30829361251718
# Generation 51, Best Fitness: 74.74527327226379
# Generation 52, Best Fitness: 77.07119097426333
# Generation 53, Best Fitness: 80.00135358984224
# Generation 54, Best Fitness: 83.14477932400196
# Generation 55, Best Fitness: 85.50024579772925
# Generation 56, Best Fitness: 89.2870710753247
# Generation 57, Best Fitness: 92.87100759074006
# Generation 58, Best Fitness: 99.09485649754644
# Generation 59, Best Fitness: 101.09709241810376
# Generation 60, Best Fitness: 102.90218444664012
# Generation 61, Best Fitness: 106.932042978712
# Generation 62, Best Fitness: 109.16622492709315
# Generation 63, Best Fitness: 110.78098347914776
# Generation 64, Best Fitness: 113.68833366169706
# Generation 65, Best Fitness: 115.15714357196622
# Generation 66, Best Fitness: 119.0368201873899
# Generation 67, Best Fitness: 122.57608582543314
# Generation 68, Best Fitness: 124.29377417722421
# Generation 69, Best Fitness: 128.21848469475594
# Generation 70, Best Fitness: 131.29696986322688
# Generation 71, Best Fitness: 134.63541580843295
# Generation 72, Best Fitness: 136.481655715384
# Generation 73, Best Fitness: 141.6035446690602
# Generation 74, Best Fitness: 145.17981979525024
# Generation 75, Best Fitness: 148.71973555385347
# Generation 76, Best Fitness: 150.30983201179527
# Generation 77, Best Fitness: 156.7742831395394
# Generation 78, Best Fitness: 161.85405845826205
# Generation 79, Best Fitness: 165.03734900209955
# Generation 80, Best Fitness: 168.47642061851946
# Generation 81, Best Fitness: 171.4646243129618
# Generation 82, Best Fitness: 174.46357659400462
# Generation 83, Best Fitness: 179.86629754644113
# Generation 84, Best Fitness: 183.74643832758096
# Generation 85, Best Fitness: 187.4167448717076
# Generation 86, Best Fitness: 194.5884369673689
# Generation 87, Best Fitness: 197.4428809029276
# Generation 88, Best Fitness: 201.62500351437603
# Generation 89, Best Fitness: 207.58030347118682
# Generation 90, Best Fitness: 211.9909178895749
# Generation 91, Best Fitness: 213.93977892543876
# Generation 92, Best Fitness: 219.5271029647569
# Generation 93, Best Fitness: 224.99632254186025
# Generation 94, Best Fitness: 229.12903895490595
# Generation 95, Best Fitness: 230.77692997928216
# Generation 96, Best Fitness: 236.2199678369138
# Generation 97, Best Fitness: 241.81314057585737
# Generation 98, Best Fitness: 246.49483582965232
# Generation 99, Best Fitness: 248.99040266629137
# Generation 100, Best Fitness: 252.5817899597457
# Final Best Solution: 15.892821963381635

# %%
# !pip install deap
# Out:
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.26.4)
# Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: deap
# Successfully installed deap-1.4.1

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from deap import base, creator, tools, algorithms

# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Define the number of features to select
num_features = 3

# Define the fitness function
def fitness(individual):

    # Select the features based on the individual
    selected_indices = [i for i, x in enumerate(individual) if x == 1]

    # Handle the case where no features are selected
    if not selected_indices:
        return 0,  # Return a low fitness value if no features are selected
    selected_features = np.array([X[:, i] for i in selected_indices]).T

    # Create a random forest classifier with the selected features
    clf = RandomForestClassifier(n_estimators=100)

    # Evaluate the model using cross-validation
    scores = cross_val_score(clf, selected_features, y, cv=5)

    # Return the mean score as the fitness value
    return np.mean(scores),

# Create a DEAP creator for the fitness function
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

# Create a DEAP toolbox for the GA
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.choice, [0, 1])
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, n=len(X[0]))
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", fitness)

# Create a population of 50 individuals
pop = toolbox.population(n=50)

# Evaluate the initial population
fitnesses = toolbox.map(toolbox.evaluate, pop)
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

# Run the GA for 20 generations
for g in range(20):
    offspring = algorithms.varAnd(pop, toolbox, cxpb=0.5, mutpb=0.1)
    fits = toolbox.map(toolbox.evaluate, offspring)
    for fit, ind in zip(fits, offspring):
        ind.fitness.values = fit
    pop = toolbox.select(offspring, k=len(pop))

# Print the best individual and the corresponding fitness value
best_individual = tools.selBest(pop, k=1)[0]
print("Best Individual:", best_individual)
print("Best Fitness:", best_individual.fitness.values[0])

# Select the features based on the best individual
selected_features = np.array([X[:, i] for i, x in enumerate(best_individual) if x == 1]).T

# Print the selected features
print("Selected Features:", selected_features)
# Out:
# Best Individual: [0, 0, 1, 1]
# Best Fitness: 0.9666666666666668
# Selected Features: [[1.4 0.2]
#  [1.4 0.2]
#  [1.3 0.2]
#  [1.5 0.2]
#  [1.4 0.2]
#  [1.7 0.4]
#  [1.4 0.3]
#  [1.5 0.2]
#  [1.4 0.2]
#  [1.5 0.1]
#  [1.5 0.2]
#  [1.6 0.2]
#  [1.4 0.1]
#  [1.1 0.1]
#  [1.2 0.2]
#  [1.5 0.4]
#  [1.3 0.4]
#  [1.4 0.3]
#  [1.7 0.3]
#  [1.5 0.3]
#  [1.7 0.2]
#  [1.5 0.4]
#  [1.  0.2]
#  [1.7 0.5]
#  [1.9 0.2]
#  [1.6 0.2]
#  [1.6 0.4]
#  [1.5 0.2]
#  [1.4 0.2]
#  [1.6 0.2]
#  [1.6 0.2]
#  [1.5 0.4]
#  [1.5 0.1]
#  [1.4 0.2]
#  [1.5 0.2]
#  [1.2 0.2]
#  [1.3 0.2]
#  [1.4 0.1]
#  [1.3 0.2]
#  [1.5 0.2]
#  [1.3 0.3]
#  [1.3 0.3]
#  [1.3 0.2]
#  [1.6 0.6]
#  [1.9 0.4]
#  [1.4 0.3]
#  [1.6 0.2]
#  [1.4 0.2]
#  [1.5 0.2]
#  [1.4 0.2]
#  [4.7 1.4]
#  [4.5 1.5]
#  [4.9 1.5]
#  [4.  1.3]
#  [4.6 1.5]
#  [4.5 1.3]
#  [4.7 1.6]
#  [3.3 1. ]
#  [4.6 1.3]
#  [3.9 1.4]
#  [3.5 1. ]
#  [4.2 1.5]
#  [4.  1. ]
#  [4.7 1.4]
#  [3.6 1.3]
#  [4.4 1.4]
#  [4.5 1.5]
#  [4.1 1. ]
#  [4.5 1.5]
#  [3.9 1.1]
#  [4.8 1.8]
#  [4.  1.3]
#  [4.9 1.5]
#  [4.7 1.2]
#  [4.3 1.3]
#  [4.4 1.4]
#  [4.8 1.4]
#  [5.  1.7]
#  [4.5 1.5]
#  [3.5 1. ]
#  [3.8 1.1]
#  [3.7 1. ]
#  [3.9 1.2]
#  [5.1 1.6]
#  [4.5 1.5]
#  [4.5 1.6]
#  [4.7 1.5]
#  [4.4 1.3]
#  [4.1 1.3]
#  [4.  1.3]
#  [4.4 1.2]
#  [4.6 1.4]
#  [4.  1.2]
#  [3.3 1. ]
#  [4.2 1.3]
#  [4.2 1.2]
#  [4.2 1.3]
#  [4.3 1.3]
#  [3.  1.1]
#  [4.1 1.3]
#  [6.  2.5]
#  [5.1 1.9]
#  [5.9 2.1]
#  [5.6 1.8]
#  [5.8 2.2]
#  [6.6 2.1]
#  [4.5 1.7]
#  [6.3 1.8]
#  [5.8 1.8]
#  [6.1 2.5]
#  [5.1 2. ]
#  [5.3 1.9]
#  [5.5 2.1]
#  [5.  2. ]
#  [5.1 2.4]
#  [5.3 2.3]
#  [5.5 1.8]
#  [6.7 2.2]
#  [6.9 2.3]
#  [5.  1.5]
#  [5.7 2.3]
#  [4.9 2. ]
#  [6.7 2. ]
#  [4.9 1.8]
#  [5.7 2.1]
#  [6.  1.8]
#  [4.8 1.8]
#  [4.9 1.8]
#  [5.6 2.1]
#  [5.8 1.6]
#  [6.1 1.9]
#  [6.4 2. ]
#  [5.6 2.2]
#  [5.1 1.5]
#  [5.6 1.4]
#  [6.1 2.3]
#  [5.6 2.4]
#  [5.5 1.8]
#  [4.8 1.8]
#  [5.4 2.1]
#  [5.6 2.4]
#  [5.1 2.3]
#  [5.1 1.9]
#  [5.9 2.3]
#  [5.7 2.5]
#  [5.2 2.3]
#  [5.  1.9]
#  [5.2 2. ]
#  [5.4 2.3]
#  [5.1 1.8]]
