# %% [markdown]
# [Reference](https://pub.towardsai.net/this-is-why-you-should-read-this-before-using-pandas-in-data-cleaning-f70aea580c78)

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris_bunch = load_iris()
iris = pd.DataFrame(data=iris_bunch.data, columns=iris_bunch.feature_names)
iris['species'] = iris_bunch.target
iris['species'] = iris['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
