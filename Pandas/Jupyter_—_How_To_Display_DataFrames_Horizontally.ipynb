# %% [markdown]
# [Reference](https://medium.com/geekculture/jupyter-how-to-display-dataframes-horizontally-d8e8769f4fa6)

# %%
import pandas as pd
from IPython.display import HTML

def horizontal(dfs):
    html = '<div style="display:flex">'
    for df in dfs:
        html += '<div style="margin-right: 32px">'
        html += df.to_html()
        html += '</div>'
    html += '</div>'
    display(HTML(html))

# %%
a = pd.DataFrame([
    ['apple', 4],
    ['orange', 5],
    ['pear', 6],
], columns=['fruit', 'price'])

b = pd.DataFrame([
    ['apple', 100],
    ['samsung', 200],
    ['nokia', 300],
], columns=['brand', 'inventory'])

c = pd.DataFrame([
    ['A',1,2,3],
    ['B',4,5,6],
    ['C',7,8,9],
    ['D',1,2,3],
    ['E',2,4,6],
    ['F',3,6,9],
], columns=['letter', 'n', 'm', 'o'])

d = pd.DataFrame([
    ['apple', 'apple', 'orange'],
    ['pineapple', 'apple', 'orange'],
    ['apple', 'durian', 'orange'],
    ['pear', 'apple', 'orange'],
], columns=['fruit1', 'fruit2', 'fruit3'])

# %%
horizontal([a, b, c, d])
# Out:
# <div style="display:flex"><div style="margin-right: 32px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fruit</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>apple</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>orange</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>pear</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 32px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>brand</th>
#       <th>inventory</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>apple</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>samsung</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>nokia</td>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 32px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>letter</th>
#       <th>n</th>
#       <th>m</th>
#       <th>o</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>7</td>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>D</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>E</td>
#       <td>2</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F</td>
#       <td>3</td>
#       <td>6</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 32px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fruit1</th>
#       <th>fruit2</th>
#       <th>fruit3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>apple</td>
#       <td>apple</td>
#       <td>orange</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pineapple</td>
#       <td>apple</td>
#       <td>orange</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>apple</td>
#       <td>durian</td>
#       <td>orange</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pear</td>
#       <td>apple</td>
#       <td>orange</td>
#     </tr>
#   </tbody>
# </table></div></div>

# %%
import pandas as pd
from IPython.display import HTML

def horizontal(dfs):
    # display: flex in CSS means that
    # stuff added to this div is added sideways
    html = '<div style="display:flex">'

    for df in dfs:
        # adding our dataframe HTMLs as child elements
        # margin: 32px forces a 32 pixel spacing between dataframes
        html += '<div style="margin-right: 32px">'
        html += df.to_html()
        html += '</div>'
    html += '</div>'

    # converting our html string to actual HTML so that we can display() it
    display(HTML(html))
