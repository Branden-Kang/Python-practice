# %% [markdown]
# [Reference](https://medium.com/analytics-vidhya/basic-dataframe-manipulation-using-pandas-221e12db08b6)

# %%
import pandas as pd

team1 = pd.DataFrame({"PLAYER": ["Magic Johnson", "Michael Jordan", 
                                 "Lebron James", "Kevin Durant", 
                                 "Shaquille O’Neal", "James Harden"], 
                      'PPG':[19.50, 30.14, 27.10, 27.00, 23.70, 25.20]})

team1 # calling the dataframe just created
# Out:
#              PLAYER    PPG
# 0     Magic Johnson  19.50
# 1    Michael Jordan  30.14
# 2      Lebron James  27.10
# 3      Kevin Durant  27.00
# 4  Shaquille O’Neal  23.70
# 5      James Harden  25.20

# %%
# Second Dataframe creation
team2 = pd.DataFrame({"PLAYER": ["Isiah Thomas", "Kobe Bryant", "Tracy McGrady", "Tim Duncan", "Hakeem Olajuwon", "Karl Malone"], "PPG": [19.20, 25.0, 19.60, 19.00, 21.80, 25.00]})
team2
# Out:
#             PLAYER   PPG
# 0     Isiah Thomas  19.2
# 1      Kobe Bryant  25.0
# 2    Tracy McGrady  19.6
# 3       Tim Duncan  19.0
# 4  Hakeem Olajuwon  21.8
# 5      Karl Malone  25.0

# %%
# Third Dataframe creation
team1_stats = pd.DataFrame({"PLAYER": ["Magic Johnson", "Michael Jordan", "Lebron James", "Kevin Durant", "Shaquille O’Neal", "James Harden"], "RPG": [7.20, 6.20,7.40,7.10, 10.90, 5.30]})
team1_stats
# Out:
#              PLAYER   RPG
# 0     Magic Johnson   7.2
# 1    Michael Jordan   6.2
# 2      Lebron James   7.4
# 3      Kevin Durant   7.1
# 4  Shaquille O’Neal  10.9
# 5      James Harden   5.3

# %%
# Forth Dataframe creation
team2_stats = pd.DataFrame({"PLAYEER": ["Isiah Thomas", "Kobe Bryant", "Tracy McGrady", "Tim Duncan", "Hakeem Olajuwon", "Karl Malone"], "RPG":[3.60, 5.20, 5.60, 10.80,11.10, 10.10]})
team2_stats
# Out:
#            PLAYEER   RPG
# 0     Isiah Thomas   3.6
# 1      Kobe Bryant   5.2
# 2    Tracy McGrady   5.6
# 3       Tim Duncan  10.8
# 4  Hakeem Olajuwon  11.1
# 5      Karl Malone  10.1

# %%
team1.loc[::-1].reset_index(drop=True).head(6) # Reseting the index

team1.loc[:, ::-1].head() # reserving the columns
# Out:
#      PPG            PLAYER
# 0  19.50     Magic Johnson
# 1  30.14    Michael Jordan
# 2  27.10      Lebron James
# 3  27.00      Kevin Durant
# 4  23.70  Shaquille O’Neal

# %% [markdown]
# # Renaming Column(s)

# %%
team2_stats = team2_stats.rename({"PLAYEER":"PLAYER"}, axis='columns')
team2_stats
# Out:
#             PLAYER   RPG
# 0     Isiah Thomas   3.6
# 1      Kobe Bryant   5.2
# 2    Tracy McGrady   5.6
# 3       Tim Duncan  10.8
# 4  Hakeem Olajuwon  11.1
# 5      Karl Malone  10.1

# %% [markdown]
# # Reversing All Rows

# %%
team1 # Quick display of the dataframe to be able to compare it with the results
# Out:
#              PLAYER    PPG
# 0     Magic Johnson  19.50
# 1    Michael Jordan  30.14
# 2      Lebron James  27.10
# 3      Kevin Durant  27.00
# 4  Shaquille O’Neal  23.70
# 5      James Harden  25.20

# %%
team1.loc[::-1].head(6)
# Out:
#              PLAYER    PPG
# 5      James Harden  25.20
# 4  Shaquille O’Neal  23.70
# 3      Kevin Durant  27.00
# 2      Lebron James  27.10
# 1    Michael Jordan  30.14
# 0     Magic Johnson  19.50

# %%
team1.loc[::-1].reset_index(drop=True).head(6)
# Out:
#              PLAYER    PPG
# 0      James Harden  25.20
# 1  Shaquille O’Neal  23.70
# 2      Kevin Durant  27.00
# 3      Lebron James  27.10
# 4    Michael Jordan  30.14
# 5     Magic Johnson  19.50

# %% [markdown]
# # Reverse All Columns

# %%
team1.loc[:, ::-1].head()
# Out:
#      PPG            PLAYER
# 0  19.50     Magic Johnson
# 1  30.14    Michael Jordan
# 2  27.10      Lebron James
# 3  27.00      Kevin Durant
# 4  23.70  Shaquille O’Neal

# %% [markdown]
# # Merging Dataframes

# %%
TEAM_1 = pd.merge(team1, team1_stats, on='PLAYER')
TEAM_1.head(2) # The 2 is to display only the first 2 rows
# Out:
#            PLAYER    PPG  RPG
# 0   Magic Johnson  19.50  7.2
# 1  Michael Jordan  30.14  6.2

# %%
TEAM_2 = pd.merge(team2, team2_stats, on='PLAYER')
TEAM_2.head(2)
# Out:
#          PLAYER   PPG  RPG
# 0  Isiah Thomas  19.2  3.6
# 1   Kobe Bryant  25.0  5.2

# %% [markdown]
# # Appending Dataframes

# %%
TEAM = TEAM_1.append(TEAM_2, ignore_index=True)
TEAM.shape
# Out:
# (12, 3)

# %%
TEAM.head(12)
# Out:
#               PLAYER    PPG   RPG
# 0      Magic Johnson  19.50   7.2
# 1     Michael Jordan  30.14   6.2
# 2       Lebron James  27.10   7.4
# 3       Kevin Durant  27.00   7.1
# 4   Shaquille O’Neal  23.70  10.9
# 5       James Harden  25.20   5.3
# 6       Isiah Thomas  19.20   3.6
# 7        Kobe Bryant  25.00   5.2
# 8      Tracy McGrady  19.60   5.6
# 9         Tim Duncan  19.00  10.8
# 10   Hakeem Olajuwon  21.80  11.1
# 11       Karl Malone  25.00  10.1

# %% [markdown]
# # Highlighting Min and Max Column Values

# %%
format_dict = {'PPG':'{:.2f}'}

# %%
TEAM.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5c2b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PLAYER</th>
#       <th class="col_heading level0 col1" >PPG</th>
#       <th class="col_heading level0 col2" >RPG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5c2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5c2b_row0_col0" class="data row0 col0" >Magic Johnson</td>
#       <td id="T_b5c2b_row0_col1" class="data row0 col1" >19.50</td>
#       <td id="T_b5c2b_row0_col2" class="data row0 col2" >7.200000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5c2b_row1_col0" class="data row1 col0" >Michael Jordan</td>
#       <td id="T_b5c2b_row1_col1" class="data row1 col1" >30.14</td>
#       <td id="T_b5c2b_row1_col2" class="data row1 col2" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b5c2b_row2_col0" class="data row2 col0" >Lebron James</td>
#       <td id="T_b5c2b_row2_col1" class="data row2 col1" >27.10</td>
#       <td id="T_b5c2b_row2_col2" class="data row2 col2" >7.400000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b5c2b_row3_col0" class="data row3 col0" >Kevin Durant</td>
#       <td id="T_b5c2b_row3_col1" class="data row3 col1" >27.00</td>
#       <td id="T_b5c2b_row3_col2" class="data row3 col2" >7.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b5c2b_row4_col0" class="data row4 col0" >Shaquille O’Neal</td>
#       <td id="T_b5c2b_row4_col1" class="data row4 col1" >23.70</td>
#       <td id="T_b5c2b_row4_col2" class="data row4 col2" >10.900000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b5c2b_row5_col0" class="data row5 col0" >James Harden</td>
#       <td id="T_b5c2b_row5_col1" class="data row5 col1" >25.20</td>
#       <td id="T_b5c2b_row5_col2" class="data row5 col2" >5.300000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b5c2b_row6_col0" class="data row6 col0" >Isiah Thomas</td>
#       <td id="T_b5c2b_row6_col1" class="data row6 col1" >19.20</td>
#       <td id="T_b5c2b_row6_col2" class="data row6 col2" >3.600000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b5c2b_row7_col0" class="data row7 col0" >Kobe Bryant</td>
#       <td id="T_b5c2b_row7_col1" class="data row7 col1" >25.00</td>
#       <td id="T_b5c2b_row7_col2" class="data row7 col2" >5.200000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b5c2b_row8_col0" class="data row8 col0" >Tracy McGrady</td>
#       <td id="T_b5c2b_row8_col1" class="data row8 col1" >19.60</td>
#       <td id="T_b5c2b_row8_col2" class="data row8 col2" >5.600000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b5c2b_row9_col0" class="data row9 col0" >Tim Duncan</td>
#       <td id="T_b5c2b_row9_col1" class="data row9 col1" >19.00</td>
#       <td id="T_b5c2b_row9_col2" class="data row9 col2" >10.800000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b5c2b_row10_col0" class="data row10 col0" >Hakeem Olajuwon</td>
#       <td id="T_b5c2b_row10_col1" class="data row10 col1" >21.80</td>
#       <td id="T_b5c2b_row10_col2" class="data row10 col2" >11.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c2b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b5c2b_row11_col0" class="data row11 col0" >Karl Malone</td>
#       <td id="T_b5c2b_row11_col1" class="data row11 col1" >25.00</td>
#       <td id="T_b5c2b_row11_col2" class="data row11 col2" >10.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
(TEAM.style.format(format_dict)
.highlight_min('PPG', color='red')
.highlight_max('PPG', color='lightgreen'))
# Out:
# <style type="text/css">
# #T_2c32f_row1_col1 {
#   background-color: lightgreen;
# }
# #T_2c32f_row9_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_2c32f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PLAYER</th>
#       <th class="col_heading level0 col1" >PPG</th>
#       <th class="col_heading level0 col2" >RPG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c32f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c32f_row0_col0" class="data row0 col0" >Magic Johnson</td>
#       <td id="T_2c32f_row0_col1" class="data row0 col1" >19.50</td>
#       <td id="T_2c32f_row0_col2" class="data row0 col2" >7.200000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c32f_row1_col0" class="data row1 col0" >Michael Jordan</td>
#       <td id="T_2c32f_row1_col1" class="data row1 col1" >30.14</td>
#       <td id="T_2c32f_row1_col2" class="data row1 col2" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c32f_row2_col0" class="data row2 col0" >Lebron James</td>
#       <td id="T_2c32f_row2_col1" class="data row2 col1" >27.10</td>
#       <td id="T_2c32f_row2_col2" class="data row2 col2" >7.400000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c32f_row3_col0" class="data row3 col0" >Kevin Durant</td>
#       <td id="T_2c32f_row3_col1" class="data row3 col1" >27.00</td>
#       <td id="T_2c32f_row3_col2" class="data row3 col2" >7.100000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c32f_row4_col0" class="data row4 col0" >Shaquille O’Neal</td>
#       <td id="T_2c32f_row4_col1" class="data row4 col1" >23.70</td>
#       <td id="T_2c32f_row4_col2" class="data row4 col2" >10.900000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c32f_row5_col0" class="data row5 col0" >James Harden</td>
#       <td id="T_2c32f_row5_col1" class="data row5 col1" >25.20</td>
#       <td id="T_2c32f_row5_col2" class="data row5 col2" >5.300000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c32f_row6_col0" class="data row6 col0" >Isiah Thomas</td>
#       <td id="T_2c32f_row6_col1" class="data row6 col1" >19.20</td>
#       <td id="T_2c32f_row6_col2" class="data row6 col2" >3.600000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c32f_row7_col0" class="data row7 col0" >Kobe Bryant</td>
#       <td id="T_2c32f_row7_col1" class="data row7 col1" >25.00</td>
#       <td id="T_2c32f_row7_col2" class="data row7 col2" >5.200000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c32f_row8_col0" class="data row8 col0" >Tracy McGrady</td>
#       <td id="T_2c32f_row8_col1" class="data row8 col1" >19.60</td>
#       <td id="T_2c32f_row8_col2" class="data row8 col2" >5.600000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c32f_row9_col0" class="data row9 col0" >Tim Duncan</td>
#       <td id="T_2c32f_row9_col1" class="data row9 col1" >19.00</td>
#       <td id="T_2c32f_row9_col2" class="data row9 col2" >10.800000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c32f_row10_col0" class="data row10 col0" >Hakeem Olajuwon</td>
#       <td id="T_2c32f_row10_col1" class="data row10 col1" >21.80</td>
#       <td id="T_2c32f_row10_col2" class="data row10 col2" >11.100000</td>
#     </tr>
#     <tr>
#       <th id="T_2c32f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c32f_row11_col0" class="data row11 col0" >Karl Malone</td>
#       <td id="T_2c32f_row11_col1" class="data row11 col1" >25.00</td>
#       <td id="T_2c32f_row11_col2" class="data row11 col2" >10.100000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Adding a Column from a List

# %%
POS = ['PG', 'SG', 'SF', 'SF', 'C', 'SG', 'PG', 'SG', 'SF', 'PF', 'C', 'PF']
ASS = [11.20, 5.30, 7.40, 4.10, 2.50, 6.3, 9.30, 4.70, 4.40, 3.00, 2.50, 3.60]

# %%
TEAM['POS'] = POS
TEAM['ASS'] = ASS
TEAM.head()
# Out:
#              PLAYER    PPG   RPG POS   ASS
# 0     Magic Johnson  19.50   7.2  PG  11.2
# 1    Michael Jordan  30.14   6.2  SG   5.3
# 2      Lebron James  27.10   7.4  SF   7.4
# 3      Kevin Durant  27.00   7.1  SF   4.1
# 4  Shaquille O’Neal  23.70  10.9   C   2.5

# %% [markdown]
# # Re-organizing Columns

# %%
TEAM = TEAM[['PLAYER', 'POS', 'PPG', 'ASS', 'RPG']]
TEAM
# Out:
#               PLAYER POS    PPG   ASS   RPG
# 0      Magic Johnson  PG  19.50  11.2   7.2
# 1     Michael Jordan  SG  30.14   5.3   6.2
# 2       Lebron James  SF  27.10   7.4   7.4
# 3       Kevin Durant  SF  27.00   4.1   7.1
# 4   Shaquille O’Neal   C  23.70   2.5  10.9
# 5       James Harden  SG  25.20   6.3   5.3
# 6       Isiah Thomas  PG  19.20   9.3   3.6
# 7        Kobe Bryant  SG  25.00   4.7   5.2
# 8      Tracy McGrady  SF  19.60   4.4   5.6
# 9         Tim Duncan  PF  19.00   3.0  10.8
# 10   Hakeem Olajuwon   C  21.80   2.5  11.1
# 11       Karl Malone  PF  25.00   3.6  10.1

# %% [markdown]
# # Sorting Dataframes by Column Values

# %%
TEAM = TEAM.sort_values(by=['PPG'], ascending=False) 
# If you want ascending simply change False to True
TEAM
# Out:
#               PLAYER POS    PPG   ASS   RPG
# 1     Michael Jordan  SG  30.14   5.3   6.2
# 2       Lebron James  SF  27.10   7.4   7.4
# 3       Kevin Durant  SF  27.00   4.1   7.1
# 5       James Harden  SG  25.20   6.3   5.3
# 7        Kobe Bryant  SG  25.00   4.7   5.2
# 11       Karl Malone  PF  25.00   3.6  10.1
# 4   Shaquille O’Neal   C  23.70   2.5  10.9
# 10   Hakeem Olajuwon   C  21.80   2.5  11.1
# 8      Tracy McGrady  SF  19.60   4.4   5.6
# 0      Magic Johnson  PG  19.50  11.2   7.2
# 6       Isiah Thomas  PG  19.20   9.3   3.6
# 9         Tim Duncan  PF  19.00   3.0  10.8

# %%
TEAM = TEAM.loc[::1].reset_index(drop=True)
TEAM
# Out:
#               PLAYER POS    PPG   ASS   RPG
# 0     Michael Jordan  SG  30.14   5.3   6.2
# 1       Lebron James  SF  27.10   7.4   7.4
# 2       Kevin Durant  SF  27.00   4.1   7.1
# 3       James Harden  SG  25.20   6.3   5.3
# 4        Kobe Bryant  SG  25.00   4.7   5.2
# 5        Karl Malone  PF  25.00   3.6  10.1
# 6   Shaquille O’Neal   C  23.70   2.5  10.9
# 7    Hakeem Olajuwon   C  21.80   2.5  11.1
# 8      Tracy McGrady  SF  19.60   4.4   5.6
# 9      Magic Johnson  PG  19.50  11.2   7.2
# 10      Isiah Thomas  PG  19.20   9.3   3.6
# 11        Tim Duncan  PF  19.00   3.0  10.8

# %%
(TEAM.style.format(format_dict)
.background_gradient(subset='PPG', cmap='Greens'))
# Out:
# <style type="text/css">
# #T_3296a_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3296a_row1_col2 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_3296a_row2_col2 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_3296a_row3_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_3296a_row4_col2, #T_3296a_row5_col2 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_3296a_row6_col2 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_3296a_row7_col2 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_3296a_row8_col2 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_3296a_row9_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_3296a_row10_col2 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_3296a_row11_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_3296a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PLAYER</th>
#       <th class="col_heading level0 col1" >POS</th>
#       <th class="col_heading level0 col2" >PPG</th>
#       <th class="col_heading level0 col3" >ASS</th>
#       <th class="col_heading level0 col4" >RPG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3296a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3296a_row0_col0" class="data row0 col0" >Michael Jordan</td>
#       <td id="T_3296a_row0_col1" class="data row0 col1" >SG</td>
#       <td id="T_3296a_row0_col2" class="data row0 col2" >30.14</td>
#       <td id="T_3296a_row0_col3" class="data row0 col3" >5.300000</td>
#       <td id="T_3296a_row0_col4" class="data row0 col4" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3296a_row1_col0" class="data row1 col0" >Lebron James</td>
#       <td id="T_3296a_row1_col1" class="data row1 col1" >SF</td>
#       <td id="T_3296a_row1_col2" class="data row1 col2" >27.10</td>
#       <td id="T_3296a_row1_col3" class="data row1 col3" >7.400000</td>
#       <td id="T_3296a_row1_col4" class="data row1 col4" >7.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3296a_row2_col0" class="data row2 col0" >Kevin Durant</td>
#       <td id="T_3296a_row2_col1" class="data row2 col1" >SF</td>
#       <td id="T_3296a_row2_col2" class="data row2 col2" >27.00</td>
#       <td id="T_3296a_row2_col3" class="data row2 col3" >4.100000</td>
#       <td id="T_3296a_row2_col4" class="data row2 col4" >7.100000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3296a_row3_col0" class="data row3 col0" >James Harden</td>
#       <td id="T_3296a_row3_col1" class="data row3 col1" >SG</td>
#       <td id="T_3296a_row3_col2" class="data row3 col2" >25.20</td>
#       <td id="T_3296a_row3_col3" class="data row3 col3" >6.300000</td>
#       <td id="T_3296a_row3_col4" class="data row3 col4" >5.300000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3296a_row4_col0" class="data row4 col0" >Kobe Bryant</td>
#       <td id="T_3296a_row4_col1" class="data row4 col1" >SG</td>
#       <td id="T_3296a_row4_col2" class="data row4 col2" >25.00</td>
#       <td id="T_3296a_row4_col3" class="data row4 col3" >4.700000</td>
#       <td id="T_3296a_row4_col4" class="data row4 col4" >5.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3296a_row5_col0" class="data row5 col0" >Karl Malone</td>
#       <td id="T_3296a_row5_col1" class="data row5 col1" >PF</td>
#       <td id="T_3296a_row5_col2" class="data row5 col2" >25.00</td>
#       <td id="T_3296a_row5_col3" class="data row5 col3" >3.600000</td>
#       <td id="T_3296a_row5_col4" class="data row5 col4" >10.100000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3296a_row6_col0" class="data row6 col0" >Shaquille O’Neal</td>
#       <td id="T_3296a_row6_col1" class="data row6 col1" >C</td>
#       <td id="T_3296a_row6_col2" class="data row6 col2" >23.70</td>
#       <td id="T_3296a_row6_col3" class="data row6 col3" >2.500000</td>
#       <td id="T_3296a_row6_col4" class="data row6 col4" >10.900000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3296a_row7_col0" class="data row7 col0" >Hakeem Olajuwon</td>
#       <td id="T_3296a_row7_col1" class="data row7 col1" >C</td>
#       <td id="T_3296a_row7_col2" class="data row7 col2" >21.80</td>
#       <td id="T_3296a_row7_col3" class="data row7 col3" >2.500000</td>
#       <td id="T_3296a_row7_col4" class="data row7 col4" >11.100000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3296a_row8_col0" class="data row8 col0" >Tracy McGrady</td>
#       <td id="T_3296a_row8_col1" class="data row8 col1" >SF</td>
#       <td id="T_3296a_row8_col2" class="data row8 col2" >19.60</td>
#       <td id="T_3296a_row8_col3" class="data row8 col3" >4.400000</td>
#       <td id="T_3296a_row8_col4" class="data row8 col4" >5.600000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3296a_row9_col0" class="data row9 col0" >Magic Johnson</td>
#       <td id="T_3296a_row9_col1" class="data row9 col1" >PG</td>
#       <td id="T_3296a_row9_col2" class="data row9 col2" >19.50</td>
#       <td id="T_3296a_row9_col3" class="data row9 col3" >11.200000</td>
#       <td id="T_3296a_row9_col4" class="data row9 col4" >7.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3296a_row10_col0" class="data row10 col0" >Isiah Thomas</td>
#       <td id="T_3296a_row10_col1" class="data row10 col1" >PG</td>
#       <td id="T_3296a_row10_col2" class="data row10 col2" >19.20</td>
#       <td id="T_3296a_row10_col3" class="data row10 col3" >9.300000</td>
#       <td id="T_3296a_row10_col4" class="data row10 col4" >3.600000</td>
#     </tr>
#     <tr>
#       <th id="T_3296a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3296a_row11_col0" class="data row11 col0" >Tim Duncan</td>
#       <td id="T_3296a_row11_col1" class="data row11 col1" >PF</td>
#       <td id="T_3296a_row11_col2" class="data row11 col2" >19.00</td>
#       <td id="T_3296a_row11_col3" class="data row11 col3" >3.000000</td>
#       <td id="T_3296a_row11_col4" class="data row11 col4" >10.800000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Column & Row Slicing

# %%
TEAM.iloc[:, 1:3].head(3)
# Out:
#   POS    PPG
# 0  SG  30.14
# 1  SF  27.10
# 2  SF  27.00

# %%
TEAM.loc[2:5]
# Out:
#          PLAYER POS   PPG  ASS   RPG
# 2  Kevin Durant  SF  27.0  4.1   7.1
# 3  James Harden  SG  25.2  6.3   5.3
# 4   Kobe Bryant  SG  25.0  4.7   5.2
# 5   Karl Malone  PF  25.0  3.6  10.1

# %%
TEAM.iloc[2:6]
# Out:
#          PLAYER POS   PPG  ASS   RPG
# 2  Kevin Durant  SF  27.0  4.1   7.1
# 3  James Harden  SG  25.2  6.3   5.3
# 4   Kobe Bryant  SG  25.0  4.7   5.2
# 5   Karl Malone  PF  25.0  3.6  10.1

# %% [markdown]
# # Adding Row(s)

# %%
# First we add the row
TEAM.loc[7] = ['Stephen Curry', 'PG', 23.50, 6.60, 4.50] 
# I put him below thee 7th player to respect the coring average (PPG) sorting

# Then, we shift the index by 1
TEAM.index = TEAM.index + 1 

# We sort the index
TEAM = TEAM.sort_index()

# Display the results for QC purposes
TEAM
# Out:
#               PLAYER POS    PPG   ASS   RPG
# 1     Michael Jordan  SG  30.14   5.3   6.2
# 2       Lebron James  SF  27.10   7.4   7.4
# 3       Kevin Durant  SF  27.00   4.1   7.1
# 4       James Harden  SG  25.20   6.3   5.3
# 5        Kobe Bryant  SG  25.00   4.7   5.2
# 6        Karl Malone  PF  25.00   3.6  10.1
# 7   Shaquille O’Neal   C  23.70   2.5  10.9
# 8      Stephen Curry  PG  23.50   6.6   4.5
# 9      Tracy McGrady  SF  19.60   4.4   5.6
# 10     Magic Johnson  PG  19.50  11.2   7.2
# 11      Isiah Thomas  PG  19.20   9.3   3.6
# 12        Tim Duncan  PF  19.00   3.0  10.8

# %% [markdown]
# # Profiling Dataframe(s)

# %%
import numpy as np

# %%
NaN = np.nan
TEAM["FGP"] = NaN
TEAM
# Out:
#               PLAYER POS    PPG   ASS   RPG  FGP
# 1     Michael Jordan  SG  30.14   5.3   6.2  NaN
# 2       Lebron James  SF  27.10   7.4   7.4  NaN
# 3       Kevin Durant  SF  27.00   4.1   7.1  NaN
# 4       James Harden  SG  25.20   6.3   5.3  NaN
# 5        Kobe Bryant  SG  25.00   4.7   5.2  NaN
# 6        Karl Malone  PF  25.00   3.6  10.1  NaN
# 7   Shaquille O’Neal   C  23.70   2.5  10.9  NaN
# 8      Stephen Curry  PG  23.50   6.6   4.5  NaN
# 9      Tracy McGrady  SF  19.60   4.4   5.6  NaN
# 10     Magic Johnson  PG  19.50  11.2   7.2  NaN
# 11      Isiah Thomas  PG  19.20   9.3   3.6  NaN
# 12        Tim Duncan  PF  19.00   3.0  10.8  NaN

# %%
import pandas_profiling

# %%
# pandas_profiling.ProfileReport(TEAM)

# %% [markdown]
# # Dropping Column(s) & Row(s)

# %%
TEAM.isna().sum()
# Out:
# PLAYER     0
# POS        0
# PPG        0
# ASS        0
# RPG        0
# FGP       12
# dtype: int64

# %%
TEAM = TEAM.drop('FGP', 1)
TEAM.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#            PLAYER POS    PPG  ASS  RPG
# 1  Michael Jordan  SG  30.14  5.3  6.2
# 2    Lebron James  SF  27.10  7.4  7.4
# 3    Kevin Durant  SF  27.00  4.1  7.1
# 4    James Harden  SG  25.20  6.3  5.3
# 5     Kobe Bryant  SG  25.00  4.7  5.2

# %% [markdown]
# # Generating Descriptive Statistics

# %%
TEAM.describe()
# Out:
#              PPG        ASS        RPG
# count  12.000000  12.000000  12.000000
# mean   23.661667   5.700000   6.991667
# std     3.647739   2.604541   2.449660
# min    19.000000   2.500000   3.600000
# 25%    19.575000   3.975000   5.275000
# 50%    24.350000   5.000000   6.650000
# 75%    25.650000   6.800000   8.075000
# max    30.140000  11.200000  10.900000

# %% [markdown]
# # Basic Visualizing With Plotly

# %%
import plotly.express as px

df = TEAM
fig = px.bar(TEAM, x="PPG", y="PLAYER", orientation='h', color='PPG', title="Top Scorers")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="edfdb8aa-a61c-4934-b1a0-7822659039a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edfdb8aa-a61c-4934-b1a0-7822659039a1")) {                    Plotly.newPlot(                        "edfdb8aa-a61c-4934-b1a0-7822659039a1",                        [{"alignmentgroup":"True","hovertemplate":"PPG=%{marker.color}<br>PLAYER=%{y}<extra></extra>","legendgroup":"","marker":{"color":[30.14,27.1,27.0,25.2,25.0,25.0,23.7,23.5,19.6,19.5,19.2,19.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[30.14,27.1,27.0,25.2,25.0,25.0,23.7,23.5,19.6,19.5,19.2,19.0],"xaxis":"x","y":["Michael Jordan","Lebron James","Kevin Durant","James Harden","Kobe Bryant","Karl Malone","Shaquille O\u2019Neal","Stephen Curry","Tracy McGrady","Magic Johnson","Isiah Thomas","Tim Duncan"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outline ...

# %%
df = TEAM
fig = px.bar(TEAM, x="RPG", y="PLAYER", orientation='h', color='POS', title="Top Rebounders")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bc8603c7-4131-41d3-bb8b-40384a32abeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc8603c7-4131-41d3-bb8b-40384a32abeb")) {                    Plotly.newPlot(                        "bc8603c7-4131-41d3-bb8b-40384a32abeb",                        [{"alignmentgroup":"True","hovertemplate":"POS=SG<br>RPG=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"SG","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SG","offsetgroup":"SG","orientation":"h","showlegend":true,"textposition":"auto","x":[6.2,5.3,5.2],"xaxis":"x","y":["Michael Jordan","James Harden","Kobe Bryant"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=SF<br>RPG=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"SF","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SF","offsetgroup":"SF","orientation":"h","showlegend":true,"textposition":"auto","x":[7.4,7.1,5.6],"xaxis":"x","y":["Lebron James","Kevin Durant","Tracy McGrady"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=PF<br>RPG=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"PF","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"PF","offsetgroup":"PF","orientation":"h","showlegend":true,"textposition":"auto","x":[10.1,10.8],"xaxis":"x","y":["Karl Malone","Tim Duncan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=C<br>RPG=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"C","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"C","offsetgroup":"C","orientation":"h","showlegend":true,"textposition":"auto","x":[10.9],"xaxis":"x","y":["Shaquille O\u2019Neal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=PG<br>RPG=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"PG","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"PG","offsetgroup":"PG","orientation":"h","showlegend":true,"textposition":"auto","x":[4.5,7.2,3.6],"xaxis":"x","y":["Stephen Curry","Magic Johnson","Isiah Thomas"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %%
df = TEAM
fig = px.bar(TEAM, x="ASS", y="PLAYER", orientation='h', color='POS', title="Assist Leaders")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8b37505e-4706-4246-a82f-10ac8b521119" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b37505e-4706-4246-a82f-10ac8b521119")) {                    Plotly.newPlot(                        "8b37505e-4706-4246-a82f-10ac8b521119",                        [{"alignmentgroup":"True","hovertemplate":"POS=SG<br>ASS=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"SG","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SG","offsetgroup":"SG","orientation":"h","showlegend":true,"textposition":"auto","x":[5.3,6.3,4.7],"xaxis":"x","y":["Michael Jordan","James Harden","Kobe Bryant"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=SF<br>ASS=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"SF","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SF","offsetgroup":"SF","orientation":"h","showlegend":true,"textposition":"auto","x":[7.4,4.1,4.4],"xaxis":"x","y":["Lebron James","Kevin Durant","Tracy McGrady"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=PF<br>ASS=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"PF","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"PF","offsetgroup":"PF","orientation":"h","showlegend":true,"textposition":"auto","x":[3.6,3.0],"xaxis":"x","y":["Karl Malone","Tim Duncan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=C<br>ASS=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"C","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"C","offsetgroup":"C","orientation":"h","showlegend":true,"textposition":"auto","x":[2.5],"xaxis":"x","y":["Shaquille O\u2019Neal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"POS=PG<br>ASS=%{x}<br>PLAYER=%{y}<extra></extra>","legendgroup":"PG","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"PG","offsetgroup":"PG","orientation":"h","showlegend":true,"textposition":"auto","x":[6.6,11.2,9.3],"xaxis":"x","y":["Stephen Curry","Magic Johnson","Isiah Thomas"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3 ...
