# %% [markdown]
# [Reference](https://medium.com/@francescofranco_39234/the-softmax-activation-function-137c321461ca)

# %%
'''
  Keras model to demonstrate Softmax activation function.
'''
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs

# Configuration options
num_samples_total = 1000
training_split = 250
cluster_centers = [(15,0), (15,15), (0,15), (30,15)]
num_classes = len(cluster_centers)
loss_function_used = 'categorical_crossentropy'

# Generate data
X, targets = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_classes, center_box=(0, 1), cluster_std = 1.5)
categorical_targets = to_categorical(targets)
X_training = X[training_split:, :]
X_testing = X[:training_split, :]
Targets_training = categorical_targets[training_split:]
Targets_testing = categorical_targets[:training_split].astype(np.integer)

# Set shape based on data
feature_vector_length = len(X_training[0])
input_shape = (feature_vector_length,)
print(f'Feature shape: {input_shape}')

# Generate scatter plot for training data
plt.scatter(X_training[:,0], X_training[:,1])
plt.title('Nonlinear data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# Create the model
model = Sequential()
model.add(Dense(12, input_shape=input_shape, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(8, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(num_classes, activation='softmax'))

# Configure the model and start training
model.compile(loss=loss_function_used, optimizer=tf.keras.optimizers.Adam(lr=0.001), metrics=['accuracy'])
history = model.fit(X_training, Targets_training, epochs=30, batch_size=5, verbose=1, validation_split=0.2)

# Test the model after training
test_results = model.evaluate(X_testing, Targets_testing, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# <ipython-input-4-bab0da064f30>:26: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   Targets_testing = categorical_targets[:training_split].astype(np.integer)
# Feature shape: (2,)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 120/120 [==============================] - 2s 4ms/step - loss: 9.2802 - accuracy: 0.0150 - val_loss: 1.7562 - val_accuracy: 0.2133
# Epoch 2/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.8483 - val_loss: 0.1689 - val_accuracy: 1.0000
# Epoch 3/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.9967 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 4/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9967 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 5/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9967 - val_loss: 0.0469 - val_accuracy: 1.0000
# Epoch 6/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9967 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 7/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9967 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 8/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9967 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 9/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9967 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 10/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9967 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 11/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9967 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 12/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 0.9967 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 13/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9967 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 14/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9967 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 15/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9967 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 16/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9983 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 17/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9967 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 18/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9983 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 19/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 20/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9967 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 21/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9967 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 22/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 23/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9983 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 24/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 25/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 26/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 27/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9983 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 28/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 29/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 30/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0039 - val_accuracy: 1.0000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Test results - Loss: 0.003402919275686145 - Accuracy: 100.0%
