# %% [markdown]
# [Reference](https://blog.stackademic.com/uv-in-python-the-fastest-package-project-manager-complete-guide-example-project-91e6a6048e80)

# %% [markdown]
# # macOS / Linux
# ```
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# # Windows (PowerShell)
# ```
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
# ```

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.9.12 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv --version
# Out:
# uv 0.9.12

# %% [markdown]
# # 1. Automatic project environments
#
# ```
# uv run python script.py
# ```
#
# # 2. Lockfiles for reproducibility
# uv lock creates a fully reproducible set of package versions.
#
# # 3. Python version management
# uv can download and manage multiple Python versions (like pyenv).
#
# # Speed
# Everything is written in Rust.
# Dependency resolution, installation, venv creation — all extremely fast.

# %%
# !uv init
# Out:
# Initialized project `content`

# %%
# !uv add fastapi uvicorn
# !uv add "requests>=2.30"
# Out:
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 16 packages in 362ms
# Prepared 14 packages in 167ms
# Installed 14 packages in 13ms
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.11.0
#  + click==8.3.1
#  + fastapi==0.122.0
#  + h11==0.16.0
#  + idna==3.11
#  + pydantic==2.12.4
#  + pydantic-core==2.41.5
#  + sniffio==1.3.1
#  + starlette==0.50.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + uvicorn==0.38.0
# Resolved 20 packages in 152ms
# Prepared 4 packages in 86ms
# Installed 4 packages in 5ms
#  + certifi==2025.11.12
#  + charset-normalizer==3.4.4
#  + requests==2.32.5
#  + urllib3==2.5.0

# %%
# !uv add --dev pytest black ruff
# Out:
# Resolved 31 packages in 262ms
# Prepared 11 packages in 457ms
# Installed 11 packages in 17ms
#  + black==25.11.0
#  + iniconfig==2.3.0
#  + mypy-extensions==1.1.0
#  + packaging==25.0
#  + pathspec==0.12.1
#  + platformdirs==4.5.0
#  + pluggy==1.6.0
#  + pygments==2.19.2
#  + pytest==9.0.1
#  + pytokens==0.3.0
#  + ruff==0.14.6

# %%
# !uv remove requests
# Out:
# Resolved 27 packages in 48ms
# Uninstalled 4 packages in 2ms
#  - certifi==2025.11.12
#  - charset-normalizer==3.4.4
#  - requests==2.32.5
#  - urllib3==2.5.0

# %%
# !uv lock
# Out:
# Resolved 27 packages in 1ms

# %%
# !uv sync
# Out:
# Resolved 27 packages in 0.88ms
# Audited 25 packages in 0.41ms

# %% [markdown]
# ```
# uv run python main.py
# uv run pytest
# uv run uvicorn app.main:app --reload
# ```

# %% [markdown]
# ```
# uv run --python 3.10 script.py
# ```

# %% [markdown]
# ```
# uv python install 3.12
# uv python list
# ```

# %% [markdown]
# ```
# uv pip install httpx
# uv pip uninstall httpx
# uv pip list
# uv pip freeze
# uv pip install -r requirements.txt
# ```

# %% [markdown]
# ```
# uv tool install nox[uv]
# uv tool install httpie
# ```

# %% [markdown]
# ```
# uvx pycowsay "hello world"
# ```

# %% [markdown]
# ```
# uv build
# ```

# %% [markdown]
# ```
# uv publish
# ```
