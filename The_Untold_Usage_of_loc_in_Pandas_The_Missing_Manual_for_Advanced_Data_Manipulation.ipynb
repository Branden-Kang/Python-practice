# %% [markdown]
# [Reference](https://medium.com/ai-science/the-untold-usage-of-loc-in-pandas-the-missing-manual-for-advanced-data-manipulation-330316e0e22e)

# %%
# Import the required packages
import numpy as np
import pandas as pd
import seaborn as sns

# Load the Tips dataset from seaborn
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Select the first row of the dataframe
first_row = df.loc[0]
first_row
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
# Select the first five rows and columns 'total_bill' and 'tip'
selected_data = df.loc[:4, ['total_bill', 'tip']]
selected_data
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
# Filtering
dinner_data = df.loc[df['time'] == 'Dinner']
dinner_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
mask = df['day'] == 'Sat'
saturday_tips = df.loc[mask]
saturday_tips
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
saturday_total_bill = df.loc[mask, 'total_bill']
saturday_total_bill
# Out:
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
#        ...
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# Name: total_bill, Length: 87, dtype: float64

# %%
# assign a new value of 10 to the 'tip' column for the rows
# where the 'total_bill' is greater than 40
df.loc[df['total_bill'] > 40, 'tip'] = 10

df[df.total_bill > 40]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 59        48.27  10.0    Male     No   Sat  Dinner     4
# 95        40.17  10.0    Male    Yes   Fri  Dinner     4
# 102       44.30  10.0  Female    Yes   Sat  Dinner     3
# 142       41.19  10.0    Male     No  Thur   Lunch     5
# 156       48.17  10.0    Male     No   Sun  Dinner     6
# 170       50.81  10.0    Male    Yes   Sat  Dinner     3
# 182       45.35  10.0    Male    Yes   Sun  Dinner     3
# 184       40.55  10.0    Male    Yes   Sun  Dinner     2
# 197       43.11  10.0  Female    Yes  Thur   Lunch     4
# 212       48.33  10.0    Male     No   Sat  Dinner     4

# %%
df.loc[df['day'].isin(['saturday', 'sunday']), 'weekend'] = True
df.loc[~df['day'].isin(['saturday', 'sunday']), 'weekend'] = False
df
# Out:
#      total_bill   tip     sex smoker   day    time  size weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2   False
# 1         10.34  1.66    Male     No   Sun  Dinner     3   False
# 2         21.01  3.50    Male     No   Sun  Dinner     3   False
# 3         23.68  3.31    Male     No   Sun  Dinner     2   False
# 4         24.59  3.61  Female     No   Sun  Dinner     4   False
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   False
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   False
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   False
# 242       17.82  1.75    Male     No   Sat  Dinner     2   False
# 243       18.78  3.00  Female     No  Thur  Dinner     2   False
#
# [244 rows x 8 columns]

# %%
df.loc[:, 'tip_percentage'] = df.loc[:, ['tip', 'total_bill']].apply(lambda x: x['tip'] / x['total_bill'] * 100, axis=1)

df
# Out:
#      total_bill   tip     sex smoker   day    time  size weekend  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2   False
# 1         10.34  1.66    Male     No   Sun  Dinner     3   False
# 2         21.01  3.50    Male     No   Sun  Dinner     3   False
# 3         23.68  3.31    Male     No   Sun  Dinner     2   False
# 4         24.59  3.61  Female     No   Sun  Dinner     4   False
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   False
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   False
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   False
# 242       17.82  1.75    Male     No   Sat  Dinner     2   False
# 243       18.78  3.00  Female     No  Thur  Dinner     2   False
#
#      tip_percentage
# 0          5.944673
# 1         16.054159
# 2         16.658734
# 3         13.978041
# 4         14.680765
# ..              ...
# 239       20.392697
# 240        7.358352
# 241        8.822232
# 242        9.820426
# 243       15.974441
#
# [244 rows x 9 columns]

# %%
def func(x):
    # Your function logic here
    pass

mask = df['day'] == 'Sat'
df.loc[mask, 'new_column'] = df[mask].apply(func, axis=1)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size weekend  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2   False
# 1         10.34  1.66    Male     No   Sun  Dinner     3   False
# 2         21.01  3.50    Male     No   Sun  Dinner     3   False
# 3         23.68  3.31    Male     No   Sun  Dinner     2   False
# 4         24.59  3.61  Female     No   Sun  Dinner     4   False
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   False
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   False
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   False
# 242       17.82  1.75    Male     No   Sat  Dinner     2   False
# 243       18.78  3.00  Female     No  Thur  Dinner     2   False
#
#      tip_percentage new_column
# 0          5.944673        NaN
# 1         16.054159        NaN
# 2         16.658734        NaN
# 3         13.978041        NaN
# 4         14.680765        NaN
# ..              ...        ...
# 239       20.392697       None
# 240        7.358352       None
# 241        8.822232       None
# 242        9.820426       None
# 243       15.974441       None
#
# [244 rows x 10 columns]

# %%
# Inserting null values for the next example
# Affecting 10 rows
mask = df.total_bill > 40
df.loc[mask, 'tip'] = np.nan

# To display the missing values
df[df.total_bill> 38]
# Out:
#      total_bill   tip     sex smoker   day    time  size weekend  \
# 23        39.42  7.58    Male     No   Sat  Dinner     4   False
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4   False
# 59        48.27   NaN    Male     No   Sat  Dinner     4   False
# 95        40.17   NaN    Male    Yes   Fri  Dinner     4   False
# 102       44.30   NaN  Female    Yes   Sat  Dinner     3   False
# 112       38.07  4.00    Male     No   Sun  Dinner     3   False
# 142       41.19   NaN    Male     No  Thur   Lunch     5   False
# 156       48.17   NaN    Male     No   Sun  Dinner     6   False
# 170       50.81   NaN    Male    Yes   Sat  Dinner     3   False
# 182       45.35   NaN    Male    Yes   Sun  Dinner     3   False
# 184       40.55   NaN    Male    Yes   Sun  Dinner     2   False
# 197       43.11   NaN  Female    Yes  Thur   Lunch     4   False
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4   False
# 212       48.33   NaN    Male     No   Sat  Dinner     4   False
#
#      tip_percentage new_column
# 23        19.228818       None
# 56         7.892660       None
# 59        20.716801       None
# 95        24.894200        NaN
# 102       22.573363       None
# 112       10.506961        NaN
# 142       24.277737        NaN
# 156       20.759809        NaN
# 170       19.681165       None
# 182       22.050717        NaN
# 184       24.660912        NaN
# 197       23.196474        NaN
# 207        7.745933       None
# 212       20.691082       None

# %%
mask = df.tip.isnull()
df.loc[mask, 'tip'] = df.groupby(['time', 'sex'])['tip'].transform('mean')

# To filled missing values
df[df.total_bill> 38]
# Out:
#      total_bill       tip     sex smoker   day    time  size weekend  \
# 23        39.42  7.580000    Male     No   Sat  Dinner     4   False
# 56        38.01  3.000000    Male    Yes   Sat  Dinner     4   False
# 59        48.27  2.974359    Male     No   Sat  Dinner     4   False
# 95        40.17  2.974359    Male    Yes   Fri  Dinner     4   False
# 102       44.30  3.011961  Female    Yes   Sat  Dinner     3   False
# 112       38.07  4.000000    Male     No   Sun  Dinner     3   False
# 142       41.19  2.815937    Male     No  Thur   Lunch     5   False
# 156       48.17  2.974359    Male     No   Sun  Dinner     6   False
# 170       50.81  2.974359    Male    Yes   Sat  Dinner     3   False
# 182       45.35  2.974359    Male    Yes   Sun  Dinner     3   False
# 184       40.55  2.974359    Male    Yes   Sun  Dinner     2   False
# 197       43.11  2.511765  Female    Yes  Thur   Lunch     4   False
# 207       38.73  3.000000    Male    Yes   Sat  Dinner     4   False
# 212       48.33  2.974359    Male     No   Sat  Dinner     4   False
#
#      tip_percentage new_column
# 23        19.228818       None
# 56         7.892660       None
# 59        20.716801       None
# 95        24.894200        NaN
# 102       22.573363       None
# 112       10.506961        NaN
# 142       24.277737        NaN
# 156       20.759809        NaN
# 170       19.681165       None
# 182       22.050717        NaN
# 184       24.660912        NaN
# 197       23.196474        NaN
# 207        7.745933       None
# 212       20.691082       None

# %%
# First we calculate the average tip by different time and gender
average_tip_by_time_sex = df.groupby(['time', 'sex'], as_index=False)['tip'].mean()
average_tip_by_time_sex
# Out:
#      time     sex       tip
# 0   Lunch    Male  2.815937
# 1   Lunch  Female  2.511765
# 2  Dinner    Male  2.974359
# 3  Dinner  Female  3.011961

# %%
# Create our function to fill up missing value
# based on the same `time` and `sex`
# For non-missing values, the original values are kept as it is
def get_avg_tip_by_time_sex(row):
    time = row['time']
    sex = row['sex']
    tip_value = row['tip']

    # if row['tip'] is a missing value
    if np.isnan(row['tip']):
        # find the record from the calculated average from the groupby result
        selected_rows = average_tip_by_time_sex[(average_tip_by_time_sex.time == time) & (average_tip_by_time_sex.sex == sex)]
        tip_value = selected_rows.tip.iloc[0]
    return tip_value


df.apply(get_avg_tip_by_time_sex, axis=1)
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Length: 244, dtype: float64

# %%
mask = df.tip.isnull()
df.loc[mask, 'tip'] = df.groupby(['time', 'sex'])['tip'].transform('mean')
