# %% [markdown]
# [Reference](https://medium.com/@knoldus/how-to-find-correlation-value-of-categorical-variables-23de7e7a9e26)

# %% [markdown]
# # Installation

# %%
# !pip install dython
# conda install -c conda-forge dython
# pip install git+https://github.com/shakedzy/dython.git`
# Out:
# Collecting dython
#   Downloading dython-0.7.1.post3-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from dython) (1.21.5)
# Collecting scipy>=1.7.1
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 279 kB/s
# Collecting matplotlib>=3.4.3
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 53.9 MB/s
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from dython) (0.11.2)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from dython) (1.0.2)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from dython) (1.3.5)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.1-py3-none-any.whl (899 kB)
#      |████████████████████████████████| 899 kB 50.0 MB/s
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.3->dython) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3.2->dython) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->dython) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->dython) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->dython) (1.1.0)
# Installing collected packages: scipy, fonttools, matplotlib, scikit-plot, dython
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed dython-0.7.1.post3 fonttools-4.31.1 matplotlib-3.5.1 scikit-plot-0.3.7 scipy-1.7.3

# %% [markdown]
# # Importing Neccessary Library

# %%
import pandas as pd
from dython.nominal import associations

# %% [markdown]
# # Loading Dataset

# %%
URL ='https://raw.githubusercontent.com/adamerose/datasets/master/pokemon.csv'
df= pd.read_csv(URL)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Indentifying the Categorical Variables

# %%
from dython.nominal import identify_nominal_columns
categorical_features=identify_nominal_columns(df)
categorical_features
# Out:
# ['Name', 'Type 1', 'Type 2']

# %% [markdown]
# # Generating Correlation Matrix and Heat-Map

# %%
complete_correlation= associations(df, filename= 'complete_correlation.png', figsize=(10,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/dython/nominal.py:139: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False
#   RuntimeWarning)

# %%
complete_correlation
# Out:
# {'ax': <AxesSubplot:>,
#  'corr':                    #  Name    Type 1    Type 2     Total        HP    Attack  \
#  #           1.000000   1.0  0.299379  0.335811  0.119813  0.097614  0.102298
#  Name        1.000000   1.0  0.000000  0.000000  1.000000  1.000000  1.000000
#  Type 1      0.299379   0.0  1.000000  0.199522  0.302663  0.247128  0.341423
#  Type 2      0.335811   0.0  0.199522  1.000000  0.299830  0.229100  0.330608
#  Total       0.119813   1.0  0.302663  0.299830  1.000000  0.618748  0.736211
#  HP          0.097614   1.0  0.247128  0.229100  0.618748  1.000000  0.422386
#  Attack      0.102298   1.0  0.341423  0.330608  0.736211  0.422386  1.000000
#  Defense     0.094786   1.0  0.437300  0.382557  0.612787  0.239622  0.438687
#  Sp. Atk     0.088759   1.0  0.445656  0.287475  0.747250  0.362380  0.396362
#  Sp. Def     0.085817   1.0  0.266332  0.230671  0.717609  0.378718  0.263990
#  Speed       0.010733   1.0  0.310062  0.346004  0.575943  0.175952  0.381240
#  Generation  0.982516   1.0  0.252065  0.313809  0.048384  0.058683  0.051451
#  Legendary   0.153396   1.0  0.336193  0.198048  0.501758  0.273620  0.345408
#
#               Defense   Sp. Atk   Sp. Def     Speed  Generation  Legendary
#  #           0.094786  0.088759  0.085817  0.010733    0.982516   0.153396
#  Name        1.000000  1.000000  1.000000  1.000000    1.000000   1.000000
#  Type 1      0.437300  0.445656  0.266332  0.310062    0.252065   0.336193
#  Type 2      0.382557  0.287475  0.230671  0.346004    0.313809   0.198048
#  Total       0.612787  0.747250  0.717609  0.575943    0.048384   0.501758
col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_577d5_row3_col11, #T_577d5_row11_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_577d5_row4_col5, #T_577d5_row5_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_577d5_row4_col6, #T_577d5_row6_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_577d5_row4_col7, #T_577d5_row7_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_577d5_row4_col8, #T_577d5_row8_col4 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_577d5_row4_col9, #T_577d5_row9_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_577d5_row4_col10, #T_577d5_row10_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_577d5_row4_col11, #T_577d5_row11_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_577d5_row4_col12, #T_577d5_row12_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_577d5_row5_col6, #T_577d5_row6_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_577d5_row5_col7, #T_577d5_row7_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_577d5_row5_col8, #T_577d5_row8_col5, #T_577d5_row9_col12, #T_577d5_row12_col9 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_577d5_row5_col9, #T_577d5_row9_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_577d5_row5_col10, #T_577d5_row10_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_577d5_row5_col11, #T_577d5_row11_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_577d5_row5_col12, #T_577d5_row12_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_577d5_row6_col8, #T_577d5_row8_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_577d5_row6_col9, #T_577d5_row9_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_577d5_row6_col11, #T_577d5_row11_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_577d5_row7_col8, #T_577d5_row8_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_577d5_row7_col9, #T_577d5_row9_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_577d5_row7_col10, #T_577d5_row10_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_577d5_row7_col11, #T_577d5_row11_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_577d5_row8_col9, #T_577d5_row9_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_577d5_row8_col10, #T_577d5_row10_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_577d5_row8_col11, #T_577d5_row11_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_577d5_row8_col12, #T_577d5_row12_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_577d5_row9_col10, #T_577d5_row10_col9 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_577d5_row9_col11, #T_577d5_row11_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_577d5_row10_col11, #T_577d5_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_577d5_row10_col12, #T_577d5_row12_col10 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_577d5_row11_col12, #T_577d5_row12_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_577d5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >#</th>
#       <th class="col_heading level0 col1" >Name</th>
#       <th class="col_heading level0 col2" >Type 1</th>
#       <th class="col_heading level0 col3" >Type 2</th>
#       <th class="col_heading level0 col4" >Total</th>
#       <th class="col_heading level0 col5" >HP</th>
#       <th class="col_heading level0 col6" >Attack</th>
#       <th class="col_heading level0 col7" >Defense</th>
#       <th class="col_heading level0 col8" >Sp. Atk</th>
#       <th class="col_heading level0 col9" >Sp. Def</th>
#       <th class="col_heading level0 col10" >Speed</th>
#       <th class="col_heading level0 col11" >Generation</th>
#       <th class="col_heading level0 col12" >Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_577d5_level0_row0" class="row_heading level0 row0" >#</th>
#       <td id="T_577d5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_577d5_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_577d5_row0_col2" class="data row0 col2" >0.30</td>
#       <td id="T_577d5_row0_col3" class="data row0 col3" >0.34</td>
#       <td id="T_577d5_row0_col4" class="data row0 col4" >0.12</td>
#       <td id="T_577d5_row0_col5" class="data row0 col5" >0.10</td>
#       <td id="T_577d5_row0_col6" class="data row0 col6" >0.10</td>
#       <td id="T_577d5_row0_col7" class="data row0 col7" >0.09</td>
#       <td id="T_577d5_row0_col8" class="data row0 col8" >0.09</td>
#       <td id="T_577d5_row0_col9" class="data row0 col9" >0.09</td>

# %% [markdown]
# # Heat Map Of Complete Dataset

# %%
selected_column= df[categorical_features]
categorical_df = selected_column.copy()

# %%
categorical_correlation= associations(categorical_df, filename= 'categorical_correlation.png', figsize=(10,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/dython/nominal.py:139: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False
#   RuntimeWarning)
